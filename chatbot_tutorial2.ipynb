# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals
from pre_process import *
from model3 import EncoderRNN, Attn, LuongAttnDecoderRNN, BidirRecurrentModel

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import random
import os


USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")
# Out:
# b'{"id": "L1045", "conversation_id": "L1044", "text": "They do not!", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "not", "tag": "RB", "dep": "neg", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L1044", "timestamp": null, "vectors": []}\n'
# b'{"id": "L1044", "conversation_id": "L1044", "text": "They do to!", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "to", "tag": "TO", "dep": "dobj", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L985", "conversation_id": "L984", "text": "I hope so.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "hope", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "so", "tag": "RB", "dep": "advmod", "up": 1, "dn": []}, {"tok": ".", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L984", "timestamp": null, "vectors": []}\n'
# b'{"id": "L984", "conversation_id": "L984", "text": "She okay?", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "She", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "okay", "tag": "RB", "dep": "ROOT", "dn": [0, 2]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L925", "conversation_id": "L924", "text": "Let\'s go.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Let", "tag": "VB", "dep": "ROOT", "dn": [2, 3]}, {"tok": "\'s", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "go", "tag": "VB", "dep": "ccomp", "up": 0, "dn": [1]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L924", "timestamp": null, "vectors": []}\n'
# b'{"id": "L924", "conversation_id": "L924", "text": "Wow", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Wow", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L872", "conversation_id": "L870", "text": "Okay -- you\'re gonna need to learn how to lie.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 4, "toks": [{"tok": "Okay", "tag": "UH", "dep": "intj", "up": 4, "dn": []}, {"tok": "--", "tag": ":", "dep": "punct", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "\'re", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "gon", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 2, 3, 6, 12]}, {"tok": "na", "tag": "TO", "dep": "aux", "up": 6, "dn": []}, {"tok": "need", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 8]}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 8, "dn": []}, {"tok": "learn", "tag": "VB", "dep": "xcomp", "up": 6, "dn": [7, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 11, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 11, "dn": []}, {"tok": "lie", "tag": "VB", "dep": "xcomp", "up": 8, "dn": [9, 10]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": "L871", "timestamp": null, "vectors": []}\n'
# b'{"id": "L871", "conversation_id": "L870", "text": "No", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "No", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": "L870", "timestamp": null, "vectors": []}\n'
# b'{"id": "L870", "conversation_id": "L870", "text": "I\'m kidding.  You know how sometimes you just become this \\"persona\\"?  And you don\'t know how to quit?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 2, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "\'m", "tag": "VBP", "dep": "aux", "up": 2, "dn": []}, {"tok": "kidding", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 3]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 2, "dn": [4]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 3, "dn": []}]}, {"rt": 1, "toks": [{"tok": "You", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "know", "tag": "VBP", "dep": "ROOT", "dn": [0, 6, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 3, "dn": []}, {"tok": "sometimes", "tag": "RB", "dep": "advmod", "up": 6, "dn": [2]}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 6, "dn": []}, {"tok": "just", "tag": "RB", "dep": "advmod", "up": 6, "dn": []}, {"tok": "become", "tag": "VBP", "dep": "ccomp", "up": 1, "dn": [3, 4, 5, 9]}, {"tok": "this", "tag": "DT", "dep": "det", "up": 9, "dn": []}, {"tok": "\\"", "tag": "``", "dep": "punct", "up": 9, "dn": []}, {"tok": "persona", "tag": "NN", "dep": "attr", "up": 6, "dn": [7, 8, 10]}, {"tok": "\\"", "tag": "\'\'", "dep": "punct", "up": 9, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": [12]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 11, "dn": []}]}, {"rt": 4, "toks": [{"tok": "And", "tag": "CC", "dep": "cc", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "n\'t", "tag": "RB", "dep": "neg", "up": 4, "dn": []}, {"tok": "know", "tag": "VB", "dep": "ROOT", "dn": [0, 1, 2, 3, 7, 8]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 7, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 7, "dn": []}, {"tok": "quit", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 6]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L869", "conversation_id": "L866", "text": "Like my fear of wearing pastels?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Like", "tag": "IN", "dep": "ROOT", "dn": [2, 6]}, {"tok": "my", "tag": "PRP$", "dep": "poss", "up": 2, "dn": []}, {"tok": "fear", "tag": "NN", "dep": "pobj", "up": 0, "dn": [1, 3]}, {"tok": "of", "tag": "IN", "dep": "prep", "up": 2, "dn": [4]}, {"tok": "wearing", "tag": "VBG", "dep": "pcomp", "up": 3, "dn": [5]}, {"tok": "pastels", "tag": "NNS", "dep": "dobj", "up": 4, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L868", "timestamp": null, "vectors": []}\n'
#
# Processing corpus into lines and conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# b'They do to!\tThey do not!\n'
# b'She okay?\tI hope so.\n'
# b"Wow\tLet's go.\n"
# b'"I\'m kidding.  You know how sometimes you just become this ""persona""?  And you don\'t know how to quit?"\tNo\n'
# b"No\tOkay -- you're gonna need to learn how to lie.\n"
# b"I figured you'd get to the good stuff eventually.\tWhat good stuff?\n"
# b'What good stuff?\t"The ""real you""."\n'
# b'"The ""real you""."\tLike my fear of wearing pastels?\n'
# b'do you listen to this crap?\tWhat crap?\n'
# b"What crap?\tMe.  This endless ...blonde babble. I'm like, boring myself.\n"
# Start preparing training data ...
# Reading lines...
# Read 221282 sentence pairs
# Trimmed to 64313 sentence pairs
# Counting words...
# Counted words: 18082
#
# pairs:
# ['they do to !', 'they do not !']
# ['she okay ?', 'i hope so .']
# ['wow', 'let s go .']
# ['what good stuff ?', 'the real you .']
# ['the real you .', 'like my fear of wearing pastels ?']
# ['do you listen to this crap ?', 'what crap ?']
# ['well no . . .', 'then that s all you had to say .']
# ['then that s all you had to say .', 'but']
# ['but', 'you always been this selfish ?']
# ['have fun tonight ?', 'tons']
# keep_words 7833 / 18079 = 0.4333
# Trimmed from 64313 pairs to 53131, 0.8261 of total
# input_variable: tensor([[ 616,   77,   24,  128,   93],
#         [  85,   24, 1826,   20, 5855],
#         [  52,   18,   36,   14,   14],
#         [4814,    5,   10,    2,    2],
#         [  28,  141,    2,    0,    0],
#         [1925,   10,    0,    0,    0],
#         [  14,    2,    0,    0,    0],
#         [   2,    0,    0,    0,    0]])
# lengths: tensor([8, 7, 5, 4, 4])
# target_variable: tensor([[ 313,  280,  234,  162,   99],
#         [  24,   14,   59,   14,   22],
#         [  38,    2,   14,    2,  774],
#         [   5,    0,   11,    0, 4892],
#         [1204,    0,  105,    0,   61],
#         [ 466,    0, 3214,    0, 4642],
#         [  28,    0,   84,    0,   14],
#         [ 461,    0,   24,    0,    2],
#         [  14,    0,   14,    0,    0],
#         [   2,    0,    2,    0,    0]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True, False,  True, False,  True],
#         [ True, False,  True, False,  True],
#         [ True, False,  True, False,  True],
#         [ True, False,  True, False,  True],
#         [ True, False,  True, False,  True],
#         [ True, False,  True, False, False],
#         [ True, False,  True, False, False]])
# max_target_len: 10

# %%
######################################################################
# Define Training Procedure
# -------------------------
#
# Masked loss
# ~~~~~~~~~~~
#
# Since we are dealing with batches of padded sequences, we cannot simply
# consider all elements of the tensor when calculating loss. We define
# ``maskNLLLoss`` to calculate our loss based on our decoder’s output
# tensor, the target tensor, and a binary mask tensor describing the
# padding of the target tensor. This loss function calculates the average
# negative log likelihood of the elements that correspond to a *1* in the
# mask tensor.
#

def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()


######################################################################
# Single training iteration
# ~~~~~~~~~~~~~~~~~~~~~~~~~
#
# The ``train`` function contains the algorithm for a single training
# iteration (a single batch of inputs).
#
# We will use a couple of clever tricks to aid in convergence:
#
# -  The first trick is using **teacher forcing**. This means that at some
#    probability, set by ``teacher_forcing_ratio``, we use the current
#    target word as the decoder’s next input rather than using the
#    decoder’s current guess. This technique acts as training wheels for
#    the decoder, aiding in more efficient training. However, teacher
#    forcing can lead to model instability during inference, as the
#    decoder may not have a sufficient chance to truly craft its own
#    output sequences during training. Thus, we must be mindful of how we
#    are setting the ``teacher_forcing_ratio``, and not be fooled by fast
#    convergence.
#
# -  The second trick that we implement is **gradient clipping**. This is
#    a commonly used technique for countering the “exploding gradient”
#    problem. In essence, by clipping or thresholding gradients to a
#    maximum value, we prevent the gradients from growing exponentially
#    and either overflow (NaN), or overshoot steep cliffs in the cost
#    function.
#
# .. figure:: /_static/img/chatbot/grad_clip.png
#    :align: center
#    :width: 60%
#    :alt: grad_clip
#
# Image source: Goodfellow et al. *Deep Learning*. 2016. https://www.deeplearningbook.org/
#
# **Sequence of Operations:**
#
#    1) Forward pass entire input batch through encoder.
#    2) Initialize decoder inputs as SOS_token, and hidden state as the encoder's final hidden state.
#    3) Forward input batch sequence through decoder one time step at a time.
#    4) If teacher forcing: set next decoder input as the current target; else: set next decoder input as current decoder output.
#    5) Calculate and accumulate loss.
#    6) Perform backpropagation.
#    7) Clip gradients.
#    8) Update encoder and decoder model parameters.
#
#
# .. Note ::
#
#   PyTorch’s RNN modules (``RNN``, ``LSTM``, ``GRU``) can be used like any
#   other non-recurrent layers by simply passing them the entire input
#   sequence (or batch of sequences). We use the ``GRU`` layer like this in
#   the ``encoder``. The reality is that under the hood, there is an
#   iterative process looping over each time step calculating hidden states.
#   Alternatively, you can run these modules one time-step at a time. In
#   this case, we manually loop over the sequences during the training
#   process like we must do for the ``decoder`` model. As long as you
#   maintain the correct conceptual model of these modules, implementing
#   sequential models can be very straightforward.
#
#


def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding, batch_size, clip, max_length=MAX_LENGTH):
    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for rnn packing should always be on the cpu
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropatation
    loss.backward()

        # Initialize optimizers
    #print('Building optimizers ...')
    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)


    # If you have cuda, configure cuda to call
    for state in encoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()

    for state in decoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()

    # Zero gradients
    #encoder_optimizer.zero_grad()
    #decoder_optimizer.zero_grad()
    
    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals


######################################################################
# Training iterations
# ~~~~~~~~~~~~~~~~~~~
#
# It is finally time to tie the full training procedure together with the
# data. The ``trainIters`` function is responsible for running
# ``n_iterations`` of training given the passed models, optimizers, data,
# etc. This function is quite self explanatory, as we have done the heavy
# lifting with the ``train`` function.
#
# One thing to note is that when we save our model, we save a tarball
# containing the encoder and decoder state_dicts (parameters), the
# optimizers’ state_dicts, the loss, the iteration, etc. Saving the model
# in this way will give us the ultimate flexibility with the checkpoint.
# After loading a checkpoint, we will be able to use the model parameters
# to run inference, or we can continue training right where we left off.
#

def trainIters(model_name, voc, pairs, encoder, decoder, embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, clip, corpus_name, loadFilename):

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, batch_size, clip)
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg))
            print_loss = 0


######################################################################
# Run Model
# ---------
#
# Finally, it is time to run our model!
#
# Regardless of whether we want to train or test the chatbot model, we
# must initialize the individual encoder and decoder models. In the
# following block, we set our desired configurations, choose to start from
# scratch or set a checkpoint to load from, and build and initialize the
# models. Feel free to play with different model configurations to
# optimize performance.
#

# Configure models
model_name = 'cb_model'
attn_model = 'dot'
#attn_model = 'general'
#attn_model = 'concat'
encode_hidden_size = 50
decode_hidden_size = 50
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 4000
#loadFilename = os.path.join(save_dir, model_name, corpus_name,
#                            '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
#                            '{}_checkpoint.tar'.format(checkpoint_iter))


# Load model if a loadFilename is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, decode_hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(encode_hidden_size, voc.num_words, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, decode_hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')


######################################################################
# Run Training
# ~~~~~~~~~~~~
#
# Run the following block if you want to train the model.
#
# First we set training parameters, then we initialize our optimizers, and
# finally we call the ``trainIters`` function to run our training
# iterations.
#

# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 4000
#n_iteration = 1  #just used for test
print_every = 1
save_every = 4000

# Ensure dropout layers are in train mode
encoder.train()
decoder.train()



# Run training iterations
print("Starting Training!")
trainIters(model_name, voc, pairs, encoder, decoder, embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name, loadFilename)
# Out:
# Building encoder and decoder ...
# Models built and ready to go!
# Starting Training!
# Initializing ...
# Training...
# Building optimizers ...
# Iteration: 1; Percent complete: 0.0%; Average loss: 8.9822
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/optim/adam.py:137: UserWarning: optimizer contains a parameter group with duplicate parameters; in future, this will cause an error; see github.com/pytorch/pytorch/issues/40967 for more information
#   super(Adam, self).__init__(params, defaults)
# Building optimizers ...
# Iteration: 2; Percent complete: 0.1%; Average loss: 8.9628
# Building optimizers ...
# Iteration: 3; Percent complete: 0.1%; Average loss: 8.9649
# Building optimizers ...
# Iteration: 4; Percent complete: 0.1%; Average loss: 8.9530
# Building optimizers ...
# Iteration: 5; Percent complete: 0.1%; Average loss: 8.9466
# Building optimizers ...
# Iteration: 6; Percent complete: 0.1%; Average loss: 8.9350
# Building optimizers ...
# Iteration: 7; Percent complete: 0.2%; Average loss: 8.9232
# Building optimizers ...
# Iteration: 8; Percent complete: 0.2%; Average loss: 8.9184
# Building optimizers ...
# Iteration: 9; Percent complete: 0.2%; Average loss: 8.9111
# Building optimizers ...
# Iteration: 10; Percent complete: 0.2%; Average loss: 8.8961
# Building optimizers ...
# Iteration: 11; Percent complete: 0.3%; Average loss: 8.8842
# Building optimizers ...
# Iteration: 12; Percent complete: 0.3%; Average loss: 8.8780
# Building optimizers ...
# Iteration: 13; Percent complete: 0.3%; Average loss: 8.8630
# Building optimizers ...
# Iteration: 14; Percent complete: 0.4%; Average loss: 8.8582
# Building optimizers ...
# Iteration: 15; Percent complete: 0.4%; Average loss: 8.8497
# Building optimizers ...
# Iteration: 16; Percent complete: 0.4%; Average loss: 8.8243
# Building optimizers ...
# Iteration: 17; Percent complete: 0.4%; Average loss: 8.8213
# Building optimizers ...
# Iteration: 18; Percent complete: 0.4%; Average loss: 8.8022
# Building optimizers ...
# Iteration: 19; Percent complete: 0.5%; Average loss: 8.7804
# Building optimizers ...
# Iteration: 20; Percent complete: 0.5%; Average loss: 8.7595
# Building optimizers ...
# Iteration: 21; Percent complete: 0.5%; Average loss: 8.7342
# Building optimizers ...
# Iteration: 22; Percent complete: 0.5%; Average loss: 8.7152
# Building optimizers ...
# Iteration: 23; Percent complete: 0.6%; Average loss: 8.7036
# Building optimizers ...
# Iteration: 24; Percent complete: 0.6%; Average loss: 8.6911
# Building optimizers ...
# Iteration: 25; Percent complete: 0.6%; Average loss: 8.6627
# Building optimizers ...
# Iteration: 26; Percent complete: 0.7%; Average loss: 8.6080
# Building optimizers ...
# Iteration: 27; Percent complete: 0.7%; Average loss: 8.5695
# Building optimizers ...
# Iteration: 28; Percent complete: 0.7%; Average loss: 8.5679
# Building optimizers ...
# Iteration: 29; Percent complete: 0.7%; Average loss: 8.5494
# Building optimizers ...
# Iteration: 30; Percent complete: 0.8%; Average loss: 8.4771
# Building optimizers ...
# Iteration: 31; Percent complete: 0.8%; Average loss: 8.4659
# Building optimizers ...
# Iteration: 32; Percent complete: 0.8%; Average loss: 8.4391
# Building optimizers ...
# Iteration: 33; Percent complete: 0.8%; Average loss: 8.3387
# Building optimizers ...
# Iteration: 34; Percent complete: 0.9%; Average loss: 8.3048
# Building optimizers ...
# Iteration: 35; Percent complete: 0.9%; Average loss: 8.2858
# Building optimizers ...
# Iteration: 36; Percent complete: 0.9%; Average loss: 8.2704
# Building optimizers ...
# Iteration: 37; Percent complete: 0.9%; Average loss: 8.2422
# Building optimizers ...
# Iteration: 38; Percent complete: 0.9%; Average loss: 8.1200
# Building optimizers ...
# Iteration: 39; Percent complete: 1.0%; Average loss: 8.0704
# Building optimizers ...
# Iteration: 40; Percent complete: 1.0%; Average loss: 8.0181
# Building optimizers ...
# Iteration: 41; Percent complete: 1.0%; Average loss: 8.0058
# Building optimizers ...
# Iteration: 42; Percent complete: 1.1%; Average loss: 7.9677
# Building optimizers ...
# Iteration: 43; Percent complete: 1.1%; Average loss: 7.8115
# Building optimizers ...
# Iteration: 44; Percent complete: 1.1%; Average loss: 7.7798
# Building optimizers ...
# Iteration: 45; Percent complete: 1.1%; Average loss: 7.7349
# Building optimizers ...
# Iteration: 46; Percent complete: 1.1%; Average loss: 7.6776
# Building optimizers ...
# Iteration: 47; Percent complete: 1.2%; Average loss: 7.6595
# Building optimizers ...
# Iteration: 48; Percent complete: 1.2%; Average loss: 7.5952
# Building optimizers ...
# Iteration: 49; Percent complete: 1.2%; Average loss: 7.6001
# Building optimizers ...
# Iteration: 50; Percent complete: 1.2%; Average loss: 7.3939
# Building optimizers ...
# Iteration: 51; Percent complete: 1.3%; Average loss: 7.3915
# Building optimizers ...
# Iteration: 52; Percent complete: 1.3%; Average loss: 7.3278
# Building optimizers ...
# Iteration: 53; Percent complete: 1.3%; Average loss: 7.2939
# Building optimizers ...
# Iteration: 54; Percent complete: 1.4%; Average loss: 7.2529
# Building optimizers ...
# Iteration: 55; Percent complete: 1.4%; Average loss: 7.2153
# Building optimizers ...
# Iteration: 56; Percent complete: 1.4%; Average loss: 7.1668
# Building optimizers ...
# Iteration: 57; Percent complete: 1.4%; Average loss: 7.1167
# Building optimizers ...
# Iteration: 58; Percent complete: 1.5%; Average loss: 7.0512
# Building optimizers ...
# Iteration: 59; Percent complete: 1.5%; Average loss: 6.9599
# Building optimizers ...
# Iteration: 60; Percent complete: 1.5%; Average loss: 6.9627
# Building optimizers ...
# Iteration: 61; Percent complete: 1.5%; Average loss: 6.9000
# Building optimizers ...
# Iteration: 62; Percent complete: 1.6%; Average loss: 6.8345
# Building optimizers ...
# Iteration: 63; Percent complete: 1.6%; Average loss: 6.8507
# Building optimizers ...
# Iteration: 64; Percent complete: 1.6%; Average loss: 6.7743
# Building optimizers ...
# Iteration: 65; Percent complete: 1.6%; Average loss: 6.7120
# Building optimizers ...
# Iteration: 66; Percent complete: 1.7%; Average loss: 6.7781
# Building optimizers ...
# Iteration: 67; Percent complete: 1.7%; Average loss: 6.6638
# Building optimizers ...
# Iteration: 68; Percent complete: 1.7%; Average loss: 6.4889
# Building optimizers ...
# Iteration: 69; Percent complete: 1.7%; Average loss: 6.5539
# Building optimizers ...
# Iteration: 70; Percent complete: 1.8%; Average loss: 6.5158
# Building optimizers ...
# Iteration: 71; Percent complete: 1.8%; Average loss: 6.4976
# Building optimizers ...
# Iteration: 72; Percent complete: 1.8%; Average loss: 6.4609
# Building optimizers ...
# Iteration: 73; Percent complete: 1.8%; Average loss: 6.3370
# Building optimizers ...
# Iteration: 74; Percent complete: 1.8%; Average loss: 6.4022
# Building optimizers ...
# Iteration: 75; Percent complete: 1.9%; Average loss: 6.3933
# Building optimizers ...
# Iteration: 76; Percent complete: 1.9%; Average loss: 6.3674
# Building optimizers ...
# Iteration: 77; Percent complete: 1.9%; Average loss: 6.2362
# Building optimizers ...
# Iteration: 78; Percent complete: 1.9%; Average loss: 6.2070
# Building optimizers ...
# Iteration: 79; Percent complete: 2.0%; Average loss: 6.2578
# Building optimizers ...
# Iteration: 80; Percent complete: 2.0%; Average loss: 6.1129
# Building optimizers ...
# Iteration: 81; Percent complete: 2.0%; Average loss: 6.1748
# Building optimizers ...
# Iteration: 82; Percent complete: 2.1%; Average loss: 6.0936
# Building optimizers ...
# Iteration: 83; Percent complete: 2.1%; Average loss: 6.1702
# Building optimizers ...
# Iteration: 84; Percent complete: 2.1%; Average loss: 5.9299
# Building optimizers ...
# Iteration: 85; Percent complete: 2.1%; Average loss: 5.9255
# Building optimizers ...
# Iteration: 86; Percent complete: 2.1%; Average loss: 5.9408
# Building optimizers ...
# Iteration: 87; Percent complete: 2.2%; Average loss: 5.9611
# Building optimizers ...
# Iteration: 88; Percent complete: 2.2%; Average loss: 5.9301
# Building optimizers ...
# Iteration: 89; Percent complete: 2.2%; Average loss: 5.9718
# Building optimizers ...
# Iteration: 90; Percent complete: 2.2%; Average loss: 5.8794
# Building optimizers ...
# Iteration: 91; Percent complete: 2.3%; Average loss: 5.8237
# Building optimizers ...
# Iteration: 92; Percent complete: 2.3%; Average loss: 5.8691
# Building optimizers ...
# Iteration: 93; Percent complete: 2.3%; Average loss: 5.6782
# Building optimizers ...
# Iteration: 94; Percent complete: 2.4%; Average loss: 5.7801
# Building optimizers ...
# Iteration: 95; Percent complete: 2.4%; Average loss: 5.7494
# Building optimizers ...
# Iteration: 96; Percent complete: 2.4%; Average loss: 5.8645
# Building optimizers ...
# Iteration: 97; Percent complete: 2.4%; Average loss: 5.7585
# Building optimizers ...
# Iteration: 98; Percent complete: 2.5%; Average loss: 5.6359
# Building optimizers ...
# Iteration: 99; Percent complete: 2.5%; Average loss: 5.6958
# Building optimizers ...
# Iteration: 100; Percent complete: 2.5%; Average loss: 5.6460
# Building optimizers ...
# Iteration: 101; Percent complete: 2.5%; Average loss: 5.5936
# Building optimizers ...
# Iteration: 102; Percent complete: 2.5%; Average loss: 5.6092
# Building optimizers ...
# Iteration: 103; Percent complete: 2.6%; Average loss: 5.6435
# Building optimizers ...
# Iteration: 104; Percent complete: 2.6%; Average loss: 5.6066
# Building optimizers ...
# Iteration: 105; Percent complete: 2.6%; Average loss: 5.4922
# Building optimizers ...
# Iteration: 106; Percent complete: 2.6%; Average loss: 5.6031
# Building optimizers ...
# Iteration: 107; Percent complete: 2.7%; Average loss: 5.4675
# Building optimizers ...
# Iteration: 108; Percent complete: 2.7%; Average loss: 5.4460
# Building optimizers ...
# Iteration: 109; Percent complete: 2.7%; Average loss: 5.4921
# Building optimizers ...
# Iteration: 110; Percent complete: 2.8%; Average loss: 5.5501
# Building optimizers ...
# Iteration: 111; Percent complete: 2.8%; Average loss: 5.6395
# Building optimizers ...
# Iteration: 112; Percent complete: 2.8%; Average loss: 5.3472
# Building optimizers ...
# Iteration: 113; Percent complete: 2.8%; Average loss: 5.3502
# Building optimizers ...
# Iteration: 114; Percent complete: 2.9%; Average loss: 5.3728
# Building optimizers ...
# Iteration: 115; Percent complete: 2.9%; Average loss: 5.4731
# Building optimizers ...
# Iteration: 116; Percent complete: 2.9%; Average loss: 5.3183
# Building optimizers ...
# Iteration: 117; Percent complete: 2.9%; Average loss: 5.5048
# Building optimizers ...
# Iteration: 118; Percent complete: 2.9%; Average loss: 5.4050
# Building optimizers ...
# Iteration: 119; Percent complete: 3.0%; Average loss: 5.2756
# Building optimizers ...
# Iteration: 120; Percent complete: 3.0%; Average loss: 5.3012
# Building optimizers ...
# Iteration: 121; Percent complete: 3.0%; Average loss: 5.1726
# Building optimizers ...
# Iteration: 122; Percent complete: 3.0%; Average loss: 5.3891
# Building optimizers ...
# Iteration: 123; Percent complete: 3.1%; Average loss: 5.2153
# Building optimizers ...
# Iteration: 124; Percent complete: 3.1%; Average loss: 5.3569
# Building optimizers ...
# Iteration: 125; Percent complete: 3.1%; Average loss: 5.2914
# Building optimizers ...
# Iteration: 126; Percent complete: 3.1%; Average loss: 5.4024
# Building optimizers ...
# Iteration: 127; Percent complete: 3.2%; Average loss: 5.3254
# Building optimizers ...
# Iteration: 128; Percent complete: 3.2%; Average loss: 5.2144
# Building optimizers ...
# Iteration: 129; Percent complete: 3.2%; Average loss: 5.3170
# Building optimizers ...
# Iteration: 130; Percent complete: 3.2%; Average loss: 5.2143
# Building optimizers ...
# Iteration: 131; Percent complete: 3.3%; Average loss: 5.2322
# Building optimizers ...
# Iteration: 132; Percent complete: 3.3%; Average loss: 5.2462
# Building optimizers ...
# Iteration: 133; Percent complete: 3.3%; Average loss: 5.1106
# Building optimizers ...
# Iteration: 134; Percent complete: 3.4%; Average loss: 5.1828
# Building optimizers ...
# Iteration: 135; Percent complete: 3.4%; Average loss: 5.2683
# Building optimizers ...
# Iteration: 136; Percent complete: 3.4%; Average loss: 5.1342
# Building optimizers ...
# Iteration: 137; Percent complete: 3.4%; Average loss: 5.4264
# Building optimizers ...
# Iteration: 138; Percent complete: 3.5%; Average loss: 5.1162
# Building optimizers ...
# Iteration: 139; Percent complete: 3.5%; Average loss: 5.1055
# Building optimizers ...
# Iteration: 140; Percent complete: 3.5%; Average loss: 5.3389
# Building optimizers ...
# Iteration: 141; Percent complete: 3.5%; Average loss: 5.0958
# Building optimizers ...
# Iteration: 142; Percent complete: 3.5%; Average loss: 5.2078
# Building optimizers ...
# Iteration: 143; Percent complete: 3.6%; Average loss: 4.9576
# Building optimizers ...
# Iteration: 144; Percent complete: 3.6%; Average loss: 5.1597
# Building optimizers ...
# Iteration: 145; Percent complete: 3.6%; Average loss: 5.1339
# Building optimizers ...
# Iteration: 146; Percent complete: 3.6%; Average loss: 5.1996
# Building optimizers ...
# Iteration: 147; Percent complete: 3.7%; Average loss: 5.1604
# Building optimizers ...
# Iteration: 148; Percent complete: 3.7%; Average loss: 5.0758
# Building optimizers ...
# Iteration: 149; Percent complete: 3.7%; Average loss: 5.1007
# Building optimizers ...
# Iteration: 150; Percent complete: 3.8%; Average loss: 5.2338
# Building optimizers ...
# Iteration: 151; Percent complete: 3.8%; Average loss: 5.1064
# Building optimizers ...
# Iteration: 152; Percent complete: 3.8%; Average loss: 5.0419
# Building optimizers ...
# Iteration: 153; Percent complete: 3.8%; Average loss: 5.2183
# Building optimizers ...
# Iteration: 154; Percent complete: 3.9%; Average loss: 5.2802
# Building optimizers ...
# Iteration: 155; Percent complete: 3.9%; Average loss: 5.0471
# Building optimizers ...
# Iteration: 156; Percent complete: 3.9%; Average loss: 5.0048
# Building optimizers ...
# Iteration: 157; Percent complete: 3.9%; Average loss: 5.1574
# Building optimizers ...
# Iteration: 158; Percent complete: 4.0%; Average loss: 5.1428
# Building optimizers ...
# Iteration: 159; Percent complete: 4.0%; Average loss: 5.0839
# Building optimizers ...
# Iteration: 160; Percent complete: 4.0%; Average loss: 5.1047
# Building optimizers ...
# Iteration: 161; Percent complete: 4.0%; Average loss: 5.2580
# Building optimizers ...
# Iteration: 162; Percent complete: 4.0%; Average loss: 5.0614
# Building optimizers ...
# Iteration: 163; Percent complete: 4.1%; Average loss: 4.8497
# Building optimizers ...
# Iteration: 164; Percent complete: 4.1%; Average loss: 5.1361
# Building optimizers ...
# Iteration: 165; Percent complete: 4.1%; Average loss: 5.2046
# Building optimizers ...
# Iteration: 166; Percent complete: 4.2%; Average loss: 5.1473
# Building optimizers ...
# Iteration: 167; Percent complete: 4.2%; Average loss: 5.1424
# Building optimizers ...
# Iteration: 168; Percent complete: 4.2%; Average loss: 5.0900
# Building optimizers ...
# Iteration: 169; Percent complete: 4.2%; Average loss: 5.0106
# Building optimizers ...
# Iteration: 170; Percent complete: 4.2%; Average loss: 4.9401
# Building optimizers ...
# Iteration: 171; Percent complete: 4.3%; Average loss: 5.2399
# Building optimizers ...
# Iteration: 172; Percent complete: 4.3%; Average loss: 5.1016
# Building optimizers ...
# Iteration: 173; Percent complete: 4.3%; Average loss: 5.2009
# Building optimizers ...
# Iteration: 174; Percent complete: 4.3%; Average loss: 5.0382
# Building optimizers ...
# Iteration: 175; Percent complete: 4.4%; Average loss: 5.1651
# Building optimizers ...
# Iteration: 176; Percent complete: 4.4%; Average loss: 4.9636
# Building optimizers ...
# Iteration: 177; Percent complete: 4.4%; Average loss: 5.1372
# Building optimizers ...
# Iteration: 178; Percent complete: 4.5%; Average loss: 4.9663
# Building optimizers ...
# Iteration: 179; Percent complete: 4.5%; Average loss: 5.1265
# Building optimizers ...
# Iteration: 180; Percent complete: 4.5%; Average loss: 4.9737
# Building optimizers ...
# Iteration: 181; Percent complete: 4.5%; Average loss: 4.9866
# Building optimizers ...
# Iteration: 182; Percent complete: 4.5%; Average loss: 4.9308
# Building optimizers ...
# Iteration: 183; Percent complete: 4.6%; Average loss: 5.2378
# Building optimizers ...
# Iteration: 184; Percent complete: 4.6%; Average loss: 4.9160
# Building optimizers ...
# Iteration: 185; Percent complete: 4.6%; Average loss: 4.9836
# Building optimizers ...
# Iteration: 186; Percent complete: 4.7%; Average loss: 4.9281
# Building optimizers ...
# Iteration: 187; Percent complete: 4.7%; Average loss: 5.0086
# Building optimizers ...
# Iteration: 188; Percent complete: 4.7%; Average loss: 5.0743
# Building optimizers ...
# Iteration: 189; Percent complete: 4.7%; Average loss: 5.0163
# Building optimizers ...
# Iteration: 190; Percent complete: 4.8%; Average loss: 4.9563
# Building optimizers ...
# Iteration: 191; Percent complete: 4.8%; Average loss: 5.2312
# Building optimizers ...
# Iteration: 192; Percent complete: 4.8%; Average loss: 4.9438
# Building optimizers ...
# Iteration: 193; Percent complete: 4.8%; Average loss: 5.0723
# Building optimizers ...
# Iteration: 194; Percent complete: 4.9%; Average loss: 4.9420
# Building optimizers ...
# Iteration: 195; Percent complete: 4.9%; Average loss: 4.8132
# Building optimizers ...
# Iteration: 196; Percent complete: 4.9%; Average loss: 4.9613
# Building optimizers ...
# Iteration: 197; Percent complete: 4.9%; Average loss: 5.3166
# Building optimizers ...
# Iteration: 198; Percent complete: 5.0%; Average loss: 5.0333
# Building optimizers ...
# Iteration: 199; Percent complete: 5.0%; Average loss: 5.0317
# Building optimizers ...
# Iteration: 200; Percent complete: 5.0%; Average loss: 4.9405
# Building optimizers ...
# Iteration: 201; Percent complete: 5.0%; Average loss: 5.1637
# Building optimizers ...
# Iteration: 202; Percent complete: 5.1%; Average loss: 5.1431
# Building optimizers ...
# Iteration: 203; Percent complete: 5.1%; Average loss: 5.1537
# Building optimizers ...
# Iteration: 204; Percent complete: 5.1%; Average loss: 5.0359
# Building optimizers ...
# Iteration: 205; Percent complete: 5.1%; Average loss: 5.0422
# Building optimizers ...
# Iteration: 206; Percent complete: 5.1%; Average loss: 4.9237
# Building optimizers ...
# Iteration: 207; Percent complete: 5.2%; Average loss: 5.1464
# Building optimizers ...
# Iteration: 208; Percent complete: 5.2%; Average loss: 4.8069
# Building optimizers ...
# Iteration: 209; Percent complete: 5.2%; Average loss: 5.0058
# Building optimizers ...
# Iteration: 210; Percent complete: 5.2%; Average loss: 5.1884
# Building optimizers ...
# Iteration: 211; Percent complete: 5.3%; Average loss: 5.1682
# Building optimizers ...
# Iteration: 212; Percent complete: 5.3%; Average loss: 4.7446
# Building optimizers ...
# Iteration: 213; Percent complete: 5.3%; Average loss: 4.9237
# Building optimizers ...
# Iteration: 214; Percent complete: 5.3%; Average loss: 5.1551
# Building optimizers ...
# Iteration: 215; Percent complete: 5.4%; Average loss: 5.0458
# Building optimizers ...
# Iteration: 216; Percent complete: 5.4%; Average loss: 4.9970
# Building optimizers ...
# Iteration: 217; Percent complete: 5.4%; Average loss: 5.0607
# Building optimizers ...
# Iteration: 218; Percent complete: 5.5%; Average loss: 4.8429
# Building optimizers ...
# Iteration: 219; Percent complete: 5.5%; Average loss: 5.3116
# Building optimizers ...
# Iteration: 220; Percent complete: 5.5%; Average loss: 5.1440
# Building optimizers ...
# Iteration: 221; Percent complete: 5.5%; Average loss: 5.0791
# Building optimizers ...
# Iteration: 222; Percent complete: 5.5%; Average loss: 4.8925
# Building optimizers ...
# Iteration: 223; Percent complete: 5.6%; Average loss: 5.1125
# Building optimizers ...
# Iteration: 224; Percent complete: 5.6%; Average loss: 4.9322
# Building optimizers ...
# Iteration: 225; Percent complete: 5.6%; Average loss: 4.8059
# Building optimizers ...
# Iteration: 226; Percent complete: 5.7%; Average loss: 5.1973
# Building optimizers ...
# Iteration: 227; Percent complete: 5.7%; Average loss: 5.0313
# Building optimizers ...
# Iteration: 228; Percent complete: 5.7%; Average loss: 5.0964
# Building optimizers ...
# Iteration: 229; Percent complete: 5.7%; Average loss: 4.8168
# Building optimizers ...
# Iteration: 230; Percent complete: 5.8%; Average loss: 5.3710
# Building optimizers ...
# Iteration: 231; Percent complete: 5.8%; Average loss: 5.1043
# Building optimizers ...
# Iteration: 232; Percent complete: 5.8%; Average loss: 4.9534
# Building optimizers ...
# Iteration: 233; Percent complete: 5.8%; Average loss: 5.0191
# Building optimizers ...
# Iteration: 234; Percent complete: 5.9%; Average loss: 4.8051
# Building optimizers ...
# Iteration: 235; Percent complete: 5.9%; Average loss: 5.1122
# Building optimizers ...
# Iteration: 236; Percent complete: 5.9%; Average loss: 4.9902
# Building optimizers ...
# Iteration: 237; Percent complete: 5.9%; Average loss: 4.8913
# Building optimizers ...
# Iteration: 238; Percent complete: 5.9%; Average loss: 5.0399
# Building optimizers ...
# Iteration: 239; Percent complete: 6.0%; Average loss: 4.8652
# Building optimizers ...
# Iteration: 240; Percent complete: 6.0%; Average loss: 5.1126
# Building optimizers ...
# Iteration: 241; Percent complete: 6.0%; Average loss: 4.8085
# Building optimizers ...
# Iteration: 242; Percent complete: 6.0%; Average loss: 4.7825
# Building optimizers ...
# Iteration: 243; Percent complete: 6.1%; Average loss: 4.9508
# Building optimizers ...
# Iteration: 244; Percent complete: 6.1%; Average loss: 4.9193
# Building optimizers ...
# Iteration: 245; Percent complete: 6.1%; Average loss: 4.8622
# Building optimizers ...
# Iteration: 246; Percent complete: 6.2%; Average loss: 5.0666
# Building optimizers ...
# Iteration: 247; Percent complete: 6.2%; Average loss: 4.9862
# Building optimizers ...
# Iteration: 248; Percent complete: 6.2%; Average loss: 4.8147
# Building optimizers ...
# Iteration: 249; Percent complete: 6.2%; Average loss: 5.0714
# Building optimizers ...
# Iteration: 250; Percent complete: 6.2%; Average loss: 4.8991
# Building optimizers ...
# Iteration: 251; Percent complete: 6.3%; Average loss: 5.0442
# Building optimizers ...
# Iteration: 252; Percent complete: 6.3%; Average loss: 5.0106
# Building optimizers ...
# Iteration: 253; Percent complete: 6.3%; Average loss: 5.0658
# Building optimizers ...
# Iteration: 254; Percent complete: 6.3%; Average loss: 4.8583
# Building optimizers ...
# Iteration: 255; Percent complete: 6.4%; Average loss: 4.9875
# Building optimizers ...
# Iteration: 256; Percent complete: 6.4%; Average loss: 5.0522
# Building optimizers ...
# Iteration: 257; Percent complete: 6.4%; Average loss: 5.1029
# Building optimizers ...
# Iteration: 258; Percent complete: 6.5%; Average loss: 4.9519
# Building optimizers ...
# Iteration: 259; Percent complete: 6.5%; Average loss: 5.0798
# Building optimizers ...
# Iteration: 260; Percent complete: 6.5%; Average loss: 4.8931
# Building optimizers ...
# Iteration: 261; Percent complete: 6.5%; Average loss: 5.1317
# Building optimizers ...
# Iteration: 262; Percent complete: 6.6%; Average loss: 5.1582
# Building optimizers ...
# Iteration: 263; Percent complete: 6.6%; Average loss: 5.0383
# Building optimizers ...
# Iteration: 264; Percent complete: 6.6%; Average loss: 4.8255
# Building optimizers ...
# Iteration: 265; Percent complete: 6.6%; Average loss: 5.0317
# Building optimizers ...
# Iteration: 266; Percent complete: 6.7%; Average loss: 4.8834
# Building optimizers ...
# Iteration: 267; Percent complete: 6.7%; Average loss: 4.8167
# Building optimizers ...
# Iteration: 268; Percent complete: 6.7%; Average loss: 5.0072
# Building optimizers ...
# Iteration: 269; Percent complete: 6.7%; Average loss: 4.8759
# Building optimizers ...
# Iteration: 270; Percent complete: 6.8%; Average loss: 5.1152
# Building optimizers ...
# Iteration: 271; Percent complete: 6.8%; Average loss: 4.9034
# Building optimizers ...
# Iteration: 272; Percent complete: 6.8%; Average loss: 5.0026
# Building optimizers ...
# Iteration: 273; Percent complete: 6.8%; Average loss: 4.9041
# Building optimizers ...
# Iteration: 274; Percent complete: 6.9%; Average loss: 4.8296
# Building optimizers ...
# Iteration: 275; Percent complete: 6.9%; Average loss: 4.7159
# Building optimizers ...
# Iteration: 276; Percent complete: 6.9%; Average loss: 4.9333
# Building optimizers ...
# Iteration: 277; Percent complete: 6.9%; Average loss: 4.8430
# Building optimizers ...
# Iteration: 278; Percent complete: 7.0%; Average loss: 4.8983
# Building optimizers ...
# Iteration: 279; Percent complete: 7.0%; Average loss: 4.8868
# Building optimizers ...
# Iteration: 280; Percent complete: 7.0%; Average loss: 4.8931
# Building optimizers ...
# Iteration: 281; Percent complete: 7.0%; Average loss: 4.6141
# Building optimizers ...
# Iteration: 282; Percent complete: 7.0%; Average loss: 4.7565
# Building optimizers ...
# Iteration: 283; Percent complete: 7.1%; Average loss: 4.8769
# Building optimizers ...
# Iteration: 284; Percent complete: 7.1%; Average loss: 5.0385
# Building optimizers ...
# Iteration: 285; Percent complete: 7.1%; Average loss: 5.0914
# Building optimizers ...
# Iteration: 286; Percent complete: 7.1%; Average loss: 4.8177
# Building optimizers ...
# Iteration: 287; Percent complete: 7.2%; Average loss: 4.7992
# Building optimizers ...
# Iteration: 288; Percent complete: 7.2%; Average loss: 4.9135
# Building optimizers ...
# Iteration: 289; Percent complete: 7.2%; Average loss: 5.0259
# Building optimizers ...
# Iteration: 290; Percent complete: 7.2%; Average loss: 4.7441
# Building optimizers ...
# Iteration: 291; Percent complete: 7.3%; Average loss: 4.7936
# Building optimizers ...
# Iteration: 292; Percent complete: 7.3%; Average loss: 4.7000
# Building optimizers ...
# Iteration: 293; Percent complete: 7.3%; Average loss: 4.7710
# Building optimizers ...
# Iteration: 294; Percent complete: 7.3%; Average loss: 4.9561
# Building optimizers ...
# Iteration: 295; Percent complete: 7.4%; Average loss: 5.0954
# Building optimizers ...
# Iteration: 296; Percent complete: 7.4%; Average loss: 5.0484
# Building optimizers ...
# Iteration: 297; Percent complete: 7.4%; Average loss: 4.8056
# Building optimizers ...
# Iteration: 298; Percent complete: 7.4%; Average loss: 4.8484
# Building optimizers ...
# Iteration: 299; Percent complete: 7.5%; Average loss: 4.8247
# Building optimizers ...
# Iteration: 300; Percent complete: 7.5%; Average loss: 4.8955
# Building optimizers ...
# Iteration: 301; Percent complete: 7.5%; Average loss: 4.8651
# Building optimizers ...
# Iteration: 302; Percent complete: 7.5%; Average loss: 4.7835
# Building optimizers ...
# Iteration: 303; Percent complete: 7.6%; Average loss: 4.7582
# Building optimizers ...
# Iteration: 304; Percent complete: 7.6%; Average loss: 4.7845
# Building optimizers ...
# Iteration: 305; Percent complete: 7.6%; Average loss: 5.0048
# Building optimizers ...
# Iteration: 306; Percent complete: 7.6%; Average loss: 4.8682
# Building optimizers ...
# Iteration: 307; Percent complete: 7.7%; Average loss: 4.6881
# Building optimizers ...
# Iteration: 308; Percent complete: 7.7%; Average loss: 4.6002
# Building optimizers ...
# Iteration: 309; Percent complete: 7.7%; Average loss: 4.9945
# Building optimizers ...
# Iteration: 310; Percent complete: 7.8%; Average loss: 4.9352
# Building optimizers ...
# Iteration: 311; Percent complete: 7.8%; Average loss: 4.7959
# Building optimizers ...
# Iteration: 312; Percent complete: 7.8%; Average loss: 4.6511
# Building optimizers ...
# Iteration: 313; Percent complete: 7.8%; Average loss: 4.7742
# Building optimizers ...
# Iteration: 314; Percent complete: 7.8%; Average loss: 4.8179
# Building optimizers ...
# Iteration: 315; Percent complete: 7.9%; Average loss: 4.6720
# Building optimizers ...
# Iteration: 316; Percent complete: 7.9%; Average loss: 4.8944
# Building optimizers ...
# Iteration: 317; Percent complete: 7.9%; Average loss: 4.8148
# Building optimizers ...
# Iteration: 318; Percent complete: 8.0%; Average loss: 4.8295
# Building optimizers ...
# Iteration: 319; Percent complete: 8.0%; Average loss: 4.7660
# Building optimizers ...
# Iteration: 320; Percent complete: 8.0%; Average loss: 4.6832
# Building optimizers ...
# Iteration: 321; Percent complete: 8.0%; Average loss: 5.0356
# Building optimizers ...
# Iteration: 322; Percent complete: 8.1%; Average loss: 4.8336
# Building optimizers ...
# Iteration: 323; Percent complete: 8.1%; Average loss: 4.8992
# Building optimizers ...
# Iteration: 324; Percent complete: 8.1%; Average loss: 4.7164
# Building optimizers ...
# Iteration: 325; Percent complete: 8.1%; Average loss: 4.8412
# Building optimizers ...
# Iteration: 326; Percent complete: 8.2%; Average loss: 4.9160
# Building optimizers ...
# Iteration: 327; Percent complete: 8.2%; Average loss: 4.8053
# Building optimizers ...
# Iteration: 328; Percent complete: 8.2%; Average loss: 4.8104
# Building optimizers ...
# Iteration: 329; Percent complete: 8.2%; Average loss: 4.9871
# Building optimizers ...
# Iteration: 330; Percent complete: 8.2%; Average loss: 4.9111
# Building optimizers ...
# Iteration: 331; Percent complete: 8.3%; Average loss: 4.7106
# Building optimizers ...
# Iteration: 332; Percent complete: 8.3%; Average loss: 4.8454
# Building optimizers ...
# Iteration: 333; Percent complete: 8.3%; Average loss: 4.6459
# Building optimizers ...
# Iteration: 334; Percent complete: 8.3%; Average loss: 4.6248
# Building optimizers ...
# Iteration: 335; Percent complete: 8.4%; Average loss: 4.7766
# Building optimizers ...
# Iteration: 336; Percent complete: 8.4%; Average loss: 4.8092
# Building optimizers ...
# Iteration: 337; Percent complete: 8.4%; Average loss: 4.7048
# Building optimizers ...
# Iteration: 338; Percent complete: 8.5%; Average loss: 4.6953
# Building optimizers ...
# Iteration: 339; Percent complete: 8.5%; Average loss: 4.7730
# Building optimizers ...
# Iteration: 340; Percent complete: 8.5%; Average loss: 4.6331
# Building optimizers ...
# Iteration: 341; Percent complete: 8.5%; Average loss: 4.6691
# Building optimizers ...
# Iteration: 342; Percent complete: 8.6%; Average loss: 4.8121
# Building optimizers ...
# Iteration: 343; Percent complete: 8.6%; Average loss: 4.6179
# Building optimizers ...
# Iteration: 344; Percent complete: 8.6%; Average loss: 4.8521
# Building optimizers ...
# Iteration: 345; Percent complete: 8.6%; Average loss: 4.7301
# Building optimizers ...
# Iteration: 346; Percent complete: 8.6%; Average loss: 4.5776
# Building optimizers ...
# Iteration: 347; Percent complete: 8.7%; Average loss: 4.5479
# Building optimizers ...
# Iteration: 348; Percent complete: 8.7%; Average loss: 4.7542
# Building optimizers ...
# Iteration: 349; Percent complete: 8.7%; Average loss: 4.5534
# Building optimizers ...
# Iteration: 350; Percent complete: 8.8%; Average loss: 4.6482
# Building optimizers ...
# Iteration: 351; Percent complete: 8.8%; Average loss: 4.5941
# Building optimizers ...
# Iteration: 352; Percent complete: 8.8%; Average loss: 4.6947
# Building optimizers ...
# Iteration: 353; Percent complete: 8.8%; Average loss: 4.7882
# Building optimizers ...
# Iteration: 354; Percent complete: 8.8%; Average loss: 4.8438
# Building optimizers ...
# Iteration: 355; Percent complete: 8.9%; Average loss: 4.8433
# Building optimizers ...
# Iteration: 356; Percent complete: 8.9%; Average loss: 4.4071
# Building optimizers ...
# Iteration: 357; Percent complete: 8.9%; Average loss: 4.7907
# Building optimizers ...
# Iteration: 358; Percent complete: 8.9%; Average loss: 4.4956
# Building optimizers ...
# Iteration: 359; Percent complete: 9.0%; Average loss: 4.7612
# Building optimizers ...
# Iteration: 360; Percent complete: 9.0%; Average loss: 4.8481
# Building optimizers ...
# Iteration: 361; Percent complete: 9.0%; Average loss: 4.6007
# Building optimizers ...
# Iteration: 362; Percent complete: 9.0%; Average loss: 4.5614
# Building optimizers ...
# Iteration: 363; Percent complete: 9.1%; Average loss: 4.6080
# Building optimizers ...
# Iteration: 364; Percent complete: 9.1%; Average loss: 4.4871
# Building optimizers ...
# Iteration: 365; Percent complete: 9.1%; Average loss: 4.5936
# Building optimizers ...
# Iteration: 366; Percent complete: 9.2%; Average loss: 4.6952
# Building optimizers ...
# Iteration: 367; Percent complete: 9.2%; Average loss: 4.5184
# Building optimizers ...
# Iteration: 368; Percent complete: 9.2%; Average loss: 4.7294
# Building optimizers ...
# Iteration: 369; Percent complete: 9.2%; Average loss: 4.6134
# Building optimizers ...
# Iteration: 370; Percent complete: 9.2%; Average loss: 4.4490
# Building optimizers ...
# Iteration: 371; Percent complete: 9.3%; Average loss: 4.7176
# Building optimizers ...
# Iteration: 372; Percent complete: 9.3%; Average loss: 4.4539
# Building optimizers ...
# Iteration: 373; Percent complete: 9.3%; Average loss: 4.5120
# Building optimizers ...
# Iteration: 374; Percent complete: 9.3%; Average loss: 4.5630
# Building optimizers ...
# Iteration: 375; Percent complete: 9.4%; Average loss: 4.4916
# Building optimizers ...
# Iteration: 376; Percent complete: 9.4%; Average loss: 4.6536
# Building optimizers ...
# Iteration: 377; Percent complete: 9.4%; Average loss: 4.5994
# Building optimizers ...
# Iteration: 378; Percent complete: 9.4%; Average loss: 4.5834
# Building optimizers ...
# Iteration: 379; Percent complete: 9.5%; Average loss: 4.4427
# Building optimizers ...
# Iteration: 380; Percent complete: 9.5%; Average loss: 4.6255
# Building optimizers ...
# Iteration: 381; Percent complete: 9.5%; Average loss: 4.6786
# Building optimizers ...
# Iteration: 382; Percent complete: 9.6%; Average loss: 4.5245
# Building optimizers ...
# Iteration: 383; Percent complete: 9.6%; Average loss: 4.3495
# Building optimizers ...
# Iteration: 384; Percent complete: 9.6%; Average loss: 4.7890
# Building optimizers ...
# Iteration: 385; Percent complete: 9.6%; Average loss: 4.6109
# Building optimizers ...
# Iteration: 386; Percent complete: 9.7%; Average loss: 4.6754
# Building optimizers ...
# Iteration: 387; Percent complete: 9.7%; Average loss: 4.8832
# Building optimizers ...
# Iteration: 388; Percent complete: 9.7%; Average loss: 4.6494
# Building optimizers ...
# Iteration: 389; Percent complete: 9.7%; Average loss: 4.9395
# Building optimizers ...
# Iteration: 390; Percent complete: 9.8%; Average loss: 4.2405
# Building optimizers ...
# Iteration: 391; Percent complete: 9.8%; Average loss: 4.5585
# Building optimizers ...
# Iteration: 392; Percent complete: 9.8%; Average loss: 4.4942
# Building optimizers ...
# Iteration: 393; Percent complete: 9.8%; Average loss: 4.6077
# Building optimizers ...
# Iteration: 394; Percent complete: 9.8%; Average loss: 4.5208
# Building optimizers ...
# Iteration: 395; Percent complete: 9.9%; Average loss: 4.5463
# Building optimizers ...
# Iteration: 396; Percent complete: 9.9%; Average loss: 4.6710
# Building optimizers ...
# Iteration: 397; Percent complete: 9.9%; Average loss: 4.7653
# Building optimizers ...
# Iteration: 398; Percent complete: 10.0%; Average loss: 4.5676
# Building optimizers ...
# Iteration: 399; Percent complete: 10.0%; Average loss: 4.5285
# Building optimizers ...
# Iteration: 400; Percent complete: 10.0%; Average loss: 4.6783
# Building optimizers ...
# Iteration: 401; Percent complete: 10.0%; Average loss: 4.6518
# Building optimizers ...
# Iteration: 402; Percent complete: 10.1%; Average loss: 4.4046
# Building optimizers ...
# Iteration: 403; Percent complete: 10.1%; Average loss: 4.5949
# Building optimizers ...
# Iteration: 404; Percent complete: 10.1%; Average loss: 4.6618
# Building optimizers ...
# Iteration: 405; Percent complete: 10.1%; Average loss: 4.6025
# Building optimizers ...
# Iteration: 406; Percent complete: 10.2%; Average loss: 4.5870
# Building optimizers ...
# Iteration: 407; Percent complete: 10.2%; Average loss: 4.4416
# Building optimizers ...
# Iteration: 408; Percent complete: 10.2%; Average loss: 4.5484
# Building optimizers ...
# Iteration: 409; Percent complete: 10.2%; Average loss: 4.6849
# Building optimizers ...
# Iteration: 410; Percent complete: 10.2%; Average loss: 4.4416
# Building optimizers ...
# Iteration: 411; Percent complete: 10.3%; Average loss: 4.5207
# Building optimizers ...
# Iteration: 412; Percent complete: 10.3%; Average loss: 4.7408
# Building optimizers ...
# Iteration: 413; Percent complete: 10.3%; Average loss: 4.6644
# Building optimizers ...
# Iteration: 414; Percent complete: 10.3%; Average loss: 4.8130
# Building optimizers ...
# Iteration: 415; Percent complete: 10.4%; Average loss: 4.5110
# Building optimizers ...
# Iteration: 416; Percent complete: 10.4%; Average loss: 4.5154
# Building optimizers ...
# Iteration: 417; Percent complete: 10.4%; Average loss: 4.7368
# Building optimizers ...
# Iteration: 418; Percent complete: 10.4%; Average loss: 4.7958
# Building optimizers ...
# Iteration: 419; Percent complete: 10.5%; Average loss: 4.3962
# Building optimizers ...
# Iteration: 420; Percent complete: 10.5%; Average loss: 4.6862
# Building optimizers ...
# Iteration: 421; Percent complete: 10.5%; Average loss: 4.5296
# Building optimizers ...
# Iteration: 422; Percent complete: 10.5%; Average loss: 4.5897
# Building optimizers ...
# Iteration: 423; Percent complete: 10.6%; Average loss: 4.5971
# Building optimizers ...
# Iteration: 424; Percent complete: 10.6%; Average loss: 4.4334
# Building optimizers ...
# Iteration: 425; Percent complete: 10.6%; Average loss: 4.4722
# Building optimizers ...
# Iteration: 426; Percent complete: 10.7%; Average loss: 4.6670
# Building optimizers ...
# Iteration: 427; Percent complete: 10.7%; Average loss: 4.4367
# Building optimizers ...
# Iteration: 428; Percent complete: 10.7%; Average loss: 4.5143
# Building optimizers ...
# Iteration: 429; Percent complete: 10.7%; Average loss: 4.6070
# Building optimizers ...
# Iteration: 430; Percent complete: 10.8%; Average loss: 4.4415
# Building optimizers ...
# Iteration: 431; Percent complete: 10.8%; Average loss: 4.5300
# Building optimizers ...
# Iteration: 432; Percent complete: 10.8%; Average loss: 4.3701
# Building optimizers ...
# Iteration: 433; Percent complete: 10.8%; Average loss: 4.3546
# Building optimizers ...
# Iteration: 434; Percent complete: 10.8%; Average loss: 4.7477
# Building optimizers ...
# Iteration: 435; Percent complete: 10.9%; Average loss: 4.5672
# Building optimizers ...
# Iteration: 436; Percent complete: 10.9%; Average loss: 4.4885
# Building optimizers ...
# Iteration: 437; Percent complete: 10.9%; Average loss: 4.6068
# Building optimizers ...
# Iteration: 438; Percent complete: 10.9%; Average loss: 4.6342
# Building optimizers ...
# Iteration: 439; Percent complete: 11.0%; Average loss: 4.5439
# Building optimizers ...
# Iteration: 440; Percent complete: 11.0%; Average loss: 4.4800
# Building optimizers ...
# Iteration: 441; Percent complete: 11.0%; Average loss: 4.5494
# Building optimizers ...
# Iteration: 442; Percent complete: 11.1%; Average loss: 4.6660
# Building optimizers ...
# Iteration: 443; Percent complete: 11.1%; Average loss: 4.5611
# Building optimizers ...
# Iteration: 444; Percent complete: 11.1%; Average loss: 4.3235
# Building optimizers ...
# Iteration: 445; Percent complete: 11.1%; Average loss: 4.7320
# Building optimizers ...
# Iteration: 446; Percent complete: 11.2%; Average loss: 4.3840
# Building optimizers ...
# Iteration: 447; Percent complete: 11.2%; Average loss: 4.3705
# Building optimizers ...
# Iteration: 448; Percent complete: 11.2%; Average loss: 4.4320
# Building optimizers ...
# Iteration: 449; Percent complete: 11.2%; Average loss: 4.4751
# Building optimizers ...
# Iteration: 450; Percent complete: 11.2%; Average loss: 4.5530
# Building optimizers ...
# Iteration: 451; Percent complete: 11.3%; Average loss: 4.4811
# Building optimizers ...
# Iteration: 452; Percent complete: 11.3%; Average loss: 4.4268
# Building optimizers ...
# Iteration: 453; Percent complete: 11.3%; Average loss: 4.4664
# Building optimizers ...
# Iteration: 454; Percent complete: 11.3%; Average loss: 4.6378
# Building optimizers ...
# Iteration: 455; Percent complete: 11.4%; Average loss: 4.3211
# Building optimizers ...
# Iteration: 456; Percent complete: 11.4%; Average loss: 4.2163
# Building optimizers ...
# Iteration: 457; Percent complete: 11.4%; Average loss: 4.5036
# Building optimizers ...
# Iteration: 458; Percent complete: 11.5%; Average loss: 4.4666
# Building optimizers ...
# Iteration: 459; Percent complete: 11.5%; Average loss: 4.4777
# Building optimizers ...
# Iteration: 460; Percent complete: 11.5%; Average loss: 4.4577
# Building optimizers ...
# Iteration: 461; Percent complete: 11.5%; Average loss: 4.4347
# Building optimizers ...
# Iteration: 462; Percent complete: 11.6%; Average loss: 4.6867
# Building optimizers ...
# Iteration: 463; Percent complete: 11.6%; Average loss: 4.4787
# Building optimizers ...
# Iteration: 464; Percent complete: 11.6%; Average loss: 4.4744
# Building optimizers ...
# Iteration: 465; Percent complete: 11.6%; Average loss: 4.5023
# Building optimizers ...
# Iteration: 466; Percent complete: 11.7%; Average loss: 4.4384
# Building optimizers ...
# Iteration: 467; Percent complete: 11.7%; Average loss: 4.4745
# Building optimizers ...
# Iteration: 468; Percent complete: 11.7%; Average loss: 4.5109
# Building optimizers ...
# Iteration: 469; Percent complete: 11.7%; Average loss: 4.4834
# Building optimizers ...
# Iteration: 470; Percent complete: 11.8%; Average loss: 4.6773
# Building optimizers ...
# Iteration: 471; Percent complete: 11.8%; Average loss: 4.5870
# Building optimizers ...
# Iteration: 472; Percent complete: 11.8%; Average loss: 4.4615
# Building optimizers ...
# Iteration: 473; Percent complete: 11.8%; Average loss: 4.4122
# Building optimizers ...
# Iteration: 474; Percent complete: 11.8%; Average loss: 4.4223
# Building optimizers ...
# Iteration: 475; Percent complete: 11.9%; Average loss: 4.7023
# Building optimizers ...
# Iteration: 476; Percent complete: 11.9%; Average loss: 4.4836
# Building optimizers ...
# Iteration: 477; Percent complete: 11.9%; Average loss: 4.6735
# Building optimizers ...
# Iteration: 478; Percent complete: 11.9%; Average loss: 4.4121
# Building optimizers ...
# Iteration: 479; Percent complete: 12.0%; Average loss: 4.5800
# Building optimizers ...
# Iteration: 480; Percent complete: 12.0%; Average loss: 4.3849
# Building optimizers ...
# Iteration: 481; Percent complete: 12.0%; Average loss: 4.2896
# Building optimizers ...
# Iteration: 482; Percent complete: 12.0%; Average loss: 4.5030
# Building optimizers ...
# Iteration: 483; Percent complete: 12.1%; Average loss: 4.2589
# Building optimizers ...
# Iteration: 484; Percent complete: 12.1%; Average loss: 4.5469
# Building optimizers ...
# Iteration: 485; Percent complete: 12.1%; Average loss: 4.6253
# Building optimizers ...
# Iteration: 486; Percent complete: 12.2%; Average loss: 4.4171
# Building optimizers ...
# Iteration: 487; Percent complete: 12.2%; Average loss: 4.6088
# Building optimizers ...
# Iteration: 488; Percent complete: 12.2%; Average loss: 4.3726
# Building optimizers ...
# Iteration: 489; Percent complete: 12.2%; Average loss: 4.3102
# Building optimizers ...
# Iteration: 490; Percent complete: 12.2%; Average loss: 4.4960
# Building optimizers ...
# Iteration: 491; Percent complete: 12.3%; Average loss: 4.5537
# Building optimizers ...
# Iteration: 492; Percent complete: 12.3%; Average loss: 4.4489
# Building optimizers ...
# Iteration: 493; Percent complete: 12.3%; Average loss: 4.5038
# Building optimizers ...
# Iteration: 494; Percent complete: 12.3%; Average loss: 4.3706
# Building optimizers ...
# Iteration: 495; Percent complete: 12.4%; Average loss: 4.5995
# Building optimizers ...
# Iteration: 496; Percent complete: 12.4%; Average loss: 4.7418
# Building optimizers ...
# Iteration: 497; Percent complete: 12.4%; Average loss: 4.3230
# Building optimizers ...
# Iteration: 498; Percent complete: 12.4%; Average loss: 4.5404
# Building optimizers ...
# Iteration: 499; Percent complete: 12.5%; Average loss: 4.5495
# Building optimizers ...
# Iteration: 500; Percent complete: 12.5%; Average loss: 4.5920
# Building optimizers ...
# Iteration: 501; Percent complete: 12.5%; Average loss: 4.6850
# Building optimizers ...
# Iteration: 502; Percent complete: 12.6%; Average loss: 4.3721
# Building optimizers ...
# Iteration: 503; Percent complete: 12.6%; Average loss: 4.4695
# Building optimizers ...
# Iteration: 504; Percent complete: 12.6%; Average loss: 4.4644
# Building optimizers ...
# Iteration: 505; Percent complete: 12.6%; Average loss: 4.3931
# Building optimizers ...
# Iteration: 506; Percent complete: 12.7%; Average loss: 4.5206
# Building optimizers ...
# Iteration: 507; Percent complete: 12.7%; Average loss: 4.2210
# Building optimizers ...
# Iteration: 508; Percent complete: 12.7%; Average loss: 4.5976
# Building optimizers ...
# Iteration: 509; Percent complete: 12.7%; Average loss: 4.4877
# Building optimizers ...
# Iteration: 510; Percent complete: 12.8%; Average loss: 4.5693
# Building optimizers ...
# Iteration: 511; Percent complete: 12.8%; Average loss: 4.5484
# Building optimizers ...
# Iteration: 512; Percent complete: 12.8%; Average loss: 4.5094
# Building optimizers ...
# Iteration: 513; Percent complete: 12.8%; Average loss: 4.5741
# Building optimizers ...
# Iteration: 514; Percent complete: 12.8%; Average loss: 4.5011
# Building optimizers ...
# Iteration: 515; Percent complete: 12.9%; Average loss: 4.5323
# Building optimizers ...
# Iteration: 516; Percent complete: 12.9%; Average loss: 4.4999
# Building optimizers ...
# Iteration: 517; Percent complete: 12.9%; Average loss: 4.6712
# Building optimizers ...
# Iteration: 518; Percent complete: 13.0%; Average loss: 4.4441
# Building optimizers ...
# Iteration: 519; Percent complete: 13.0%; Average loss: 4.5507
# Building optimizers ...
# Iteration: 520; Percent complete: 13.0%; Average loss: 4.5174
# Building optimizers ...
# Iteration: 521; Percent complete: 13.0%; Average loss: 4.6011
# Building optimizers ...
# Iteration: 522; Percent complete: 13.1%; Average loss: 4.3444
# Building optimizers ...
# Iteration: 523; Percent complete: 13.1%; Average loss: 4.6520
# Building optimizers ...
# Iteration: 524; Percent complete: 13.1%; Average loss: 4.7309
# Building optimizers ...
# Iteration: 525; Percent complete: 13.1%; Average loss: 4.2182
# Building optimizers ...
# Iteration: 526; Percent complete: 13.2%; Average loss: 4.4676
# Building optimizers ...
# Iteration: 527; Percent complete: 13.2%; Average loss: 4.4258
# Building optimizers ...
# Iteration: 528; Percent complete: 13.2%; Average loss: 4.2411
# Building optimizers ...
# Iteration: 529; Percent complete: 13.2%; Average loss: 4.3223
# Building optimizers ...
# Iteration: 530; Percent complete: 13.2%; Average loss: 4.5801
# Building optimizers ...
# Iteration: 531; Percent complete: 13.3%; Average loss: 4.5184
# Building optimizers ...
# Iteration: 532; Percent complete: 13.3%; Average loss: 4.5327
# Building optimizers ...
# Iteration: 533; Percent complete: 13.3%; Average loss: 4.5782
# Building optimizers ...
# Iteration: 534; Percent complete: 13.4%; Average loss: 4.3767
# Building optimizers ...
# Iteration: 535; Percent complete: 13.4%; Average loss: 4.4360
# Building optimizers ...
# Iteration: 536; Percent complete: 13.4%; Average loss: 4.5626
# Building optimizers ...
# Iteration: 537; Percent complete: 13.4%; Average loss: 4.2284
# Building optimizers ...
# Iteration: 538; Percent complete: 13.5%; Average loss: 4.5678
# Building optimizers ...
# Iteration: 539; Percent complete: 13.5%; Average loss: 4.5284
# Building optimizers ...
# Iteration: 540; Percent complete: 13.5%; Average loss: 4.4128
# Building optimizers ...
# Iteration: 541; Percent complete: 13.5%; Average loss: 4.5219
# Building optimizers ...
# Iteration: 542; Percent complete: 13.6%; Average loss: 4.6035
# Building optimizers ...
# Iteration: 543; Percent complete: 13.6%; Average loss: 4.3666
# Building optimizers ...
# Iteration: 544; Percent complete: 13.6%; Average loss: 4.5370
# Building optimizers ...
# Iteration: 545; Percent complete: 13.6%; Average loss: 4.2988
# Building optimizers ...
# Iteration: 546; Percent complete: 13.7%; Average loss: 4.4771
# Building optimizers ...
# Iteration: 547; Percent complete: 13.7%; Average loss: 4.4754
# Building optimizers ...
# Iteration: 548; Percent complete: 13.7%; Average loss: 4.4493
# Building optimizers ...
# Iteration: 549; Percent complete: 13.7%; Average loss: 4.3797
# Building optimizers ...
# Iteration: 550; Percent complete: 13.8%; Average loss: 4.3936
# Building optimizers ...
# Iteration: 551; Percent complete: 13.8%; Average loss: 4.6535
# Building optimizers ...
# Iteration: 552; Percent complete: 13.8%; Average loss: 4.1202
# Building optimizers ...
# Iteration: 553; Percent complete: 13.8%; Average loss: 4.3406
# Building optimizers ...
# Iteration: 554; Percent complete: 13.9%; Average loss: 4.5385
# Building optimizers ...
# Iteration: 555; Percent complete: 13.9%; Average loss: 4.2872
# Building optimizers ...
# Iteration: 556; Percent complete: 13.9%; Average loss: 4.6659
# Building optimizers ...
# Iteration: 557; Percent complete: 13.9%; Average loss: 4.4319
# Building optimizers ...
# Iteration: 558; Percent complete: 14.0%; Average loss: 4.6606
# Building optimizers ...
# ...
# Iteration: 3817; Percent complete: 95.4%; Average loss: 3.4828
# Building optimizers ...
# Iteration: 3818; Percent complete: 95.5%; Average loss: 3.9189
# Building optimizers ...
# Iteration: 3819; Percent complete: 95.5%; Average loss: 3.8091
# Building optimizers ...
# Iteration: 3820; Percent complete: 95.5%; Average loss: 3.6953
# Building optimizers ...
# Iteration: 3821; Percent complete: 95.5%; Average loss: 3.7833
# Building optimizers ...
# Iteration: 3822; Percent complete: 95.5%; Average loss: 3.4863
# Building optimizers ...
# Iteration: 3823; Percent complete: 95.6%; Average loss: 3.5247
# Building optimizers ...
# Iteration: 3824; Percent complete: 95.6%; Average loss: 3.7978
# Building optimizers ...
# Iteration: 3825; Percent complete: 95.6%; Average loss: 3.8260
# Building optimizers ...
# Iteration: 3826; Percent complete: 95.7%; Average loss: 3.5790
# Building optimizers ...
# Iteration: 3827; Percent complete: 95.7%; Average loss: 3.6212
# Building optimizers ...
# Iteration: 3828; Percent complete: 95.7%; Average loss: 3.4412
# Building optimizers ...
# Iteration: 3829; Percent complete: 95.7%; Average loss: 3.4841
# Building optimizers ...
# Iteration: 3830; Percent complete: 95.8%; Average loss: 3.6807
# Building optimizers ...
# Iteration: 3831; Percent complete: 95.8%; Average loss: 3.5166
# Building optimizers ...
# Iteration: 3832; Percent complete: 95.8%; Average loss: 3.6059
# Building optimizers ...
# Iteration: 3833; Percent complete: 95.8%; Average loss: 3.3399
# Building optimizers ...
# Iteration: 3834; Percent complete: 95.9%; Average loss: 3.6628
# Building optimizers ...
# Iteration: 3835; Percent complete: 95.9%; Average loss: 3.7209
# Building optimizers ...
# Iteration: 3836; Percent complete: 95.9%; Average loss: 3.5789
# Building optimizers ...
# Iteration: 3837; Percent complete: 95.9%; Average loss: 3.7786
# Building optimizers ...
# Iteration: 3838; Percent complete: 96.0%; Average loss: 3.6896
# Building optimizers ...
# Iteration: 3839; Percent complete: 96.0%; Average loss: 3.2714
# Building optimizers ...
# Iteration: 3840; Percent complete: 96.0%; Average loss: 3.3644
# Building optimizers ...
# Iteration: 3841; Percent complete: 96.0%; Average loss: 3.5655
# Building optimizers ...
# Iteration: 3842; Percent complete: 96.0%; Average loss: 3.4595
# Building optimizers ...
# Iteration: 3843; Percent complete: 96.1%; Average loss: 3.6407
# Building optimizers ...
# Iteration: 3844; Percent complete: 96.1%; Average loss: 3.6837
# Building optimizers ...
# Iteration: 3845; Percent complete: 96.1%; Average loss: 3.5295
# Building optimizers ...
# Iteration: 3846; Percent complete: 96.2%; Average loss: 3.4151
# Building optimizers ...
# Iteration: 3847; Percent complete: 96.2%; Average loss: 3.7013
# Building optimizers ...
# Iteration: 3848; Percent complete: 96.2%; Average loss: 4.0663
# Building optimizers ...
# Iteration: 3849; Percent complete: 96.2%; Average loss: 4.0096
# Building optimizers ...
# Iteration: 3850; Percent complete: 96.2%; Average loss: 4.0670
# Building optimizers ...
# Iteration: 3851; Percent complete: 96.3%; Average loss: 3.7366
# Building optimizers ...
# Iteration: 3852; Percent complete: 96.3%; Average loss: 3.4257
# Building optimizers ...
# Iteration: 3853; Percent complete: 96.3%; Average loss: 3.6543
# Building optimizers ...
# Iteration: 3854; Percent complete: 96.4%; Average loss: 3.5819
# Building optimizers ...
# Iteration: 3855; Percent complete: 96.4%; Average loss: 3.7113
# Building optimizers ...
# Iteration: 3856; Percent complete: 96.4%; Average loss: 3.3390
# Building optimizers ...
# Iteration: 3857; Percent complete: 96.4%; Average loss: 3.7046
# Building optimizers ...
# Iteration: 3858; Percent complete: 96.5%; Average loss: 3.4596
# Building optimizers ...
# Iteration: 3859; Percent complete: 96.5%; Average loss: 3.6292
# Building optimizers ...
# Iteration: 3860; Percent complete: 96.5%; Average loss: 3.5085
# Building optimizers ...
# Iteration: 3861; Percent complete: 96.5%; Average loss: 3.5795
# Building optimizers ...
# Iteration: 3862; Percent complete: 96.5%; Average loss: 3.5102
# Building optimizers ...
# Iteration: 3863; Percent complete: 96.6%; Average loss: 3.4885
# Building optimizers ...
# Iteration: 3864; Percent complete: 96.6%; Average loss: 3.3995
# Building optimizers ...
# Iteration: 3865; Percent complete: 96.6%; Average loss: 3.4501
# Building optimizers ...
# Iteration: 3866; Percent complete: 96.7%; Average loss: 3.4815
# Building optimizers ...
# Iteration: 3867; Percent complete: 96.7%; Average loss: 3.6724
# Building optimizers ...
# Iteration: 3868; Percent complete: 96.7%; Average loss: 3.6533
# Building optimizers ...
# Iteration: 3869; Percent complete: 96.7%; Average loss: 3.7799
# Building optimizers ...
# Iteration: 3870; Percent complete: 96.8%; Average loss: 3.6169
# Building optimizers ...
# Iteration: 3871; Percent complete: 96.8%; Average loss: 3.8235
# Building optimizers ...
# Iteration: 3872; Percent complete: 96.8%; Average loss: 3.5284
# Building optimizers ...
# Iteration: 3873; Percent complete: 96.8%; Average loss: 3.6184
# Building optimizers ...
# Iteration: 3874; Percent complete: 96.9%; Average loss: 3.6649
# Building optimizers ...
# Iteration: 3875; Percent complete: 96.9%; Average loss: 3.6048
# Building optimizers ...
# Iteration: 3876; Percent complete: 96.9%; Average loss: 3.4870
# Building optimizers ...
# Iteration: 3877; Percent complete: 96.9%; Average loss: 3.4754
# Building optimizers ...
# Iteration: 3878; Percent complete: 97.0%; Average loss: 3.7081
# Building optimizers ...
# Iteration: 3879; Percent complete: 97.0%; Average loss: 3.6385
# Building optimizers ...
# Iteration: 3880; Percent complete: 97.0%; Average loss: 3.7555
# Building optimizers ...
# Iteration: 3881; Percent complete: 97.0%; Average loss: 3.5764
# Building optimizers ...
# Iteration: 3882; Percent complete: 97.0%; Average loss: 3.6741
# Building optimizers ...
# Iteration: 3883; Percent complete: 97.1%; Average loss: 3.8004
# Building optimizers ...
# Iteration: 3884; Percent complete: 97.1%; Average loss: 3.6094
# Building optimizers ...
# Iteration: 3885; Percent complete: 97.1%; Average loss: 3.8357
# Building optimizers ...
# Iteration: 3886; Percent complete: 97.2%; Average loss: 3.7397
# Building optimizers ...
# Iteration: 3887; Percent complete: 97.2%; Average loss: 3.5601
# Building optimizers ...
# Iteration: 3888; Percent complete: 97.2%; Average loss: 3.5212
# Building optimizers ...
# Iteration: 3889; Percent complete: 97.2%; Average loss: 3.6382
# Building optimizers ...
# Iteration: 3890; Percent complete: 97.2%; Average loss: 3.6384
# Building optimizers ...
# Iteration: 3891; Percent complete: 97.3%; Average loss: 3.7854
# Building optimizers ...
# Iteration: 3892; Percent complete: 97.3%; Average loss: 3.6924
# Building optimizers ...
# Iteration: 3893; Percent complete: 97.3%; Average loss: 3.6921
# Building optimizers ...
# Iteration: 3894; Percent complete: 97.4%; Average loss: 3.7755
# Building optimizers ...
# Iteration: 3895; Percent complete: 97.4%; Average loss: 3.4496
# Building optimizers ...
# Iteration: 3896; Percent complete: 97.4%; Average loss: 3.4967
# Building optimizers ...
# Iteration: 3897; Percent complete: 97.4%; Average loss: 3.5734
# Building optimizers ...
# Iteration: 3898; Percent complete: 97.5%; Average loss: 3.3971
# Building optimizers ...
# Iteration: 3899; Percent complete: 97.5%; Average loss: 3.6186
# Building optimizers ...
# Iteration: 3900; Percent complete: 97.5%; Average loss: 3.8905
# Building optimizers ...
# Iteration: 3901; Percent complete: 97.5%; Average loss: 3.5778
# Building optimizers ...
# Iteration: 3902; Percent complete: 97.5%; Average loss: 3.6633
# Building optimizers ...
# Iteration: 3903; Percent complete: 97.6%; Average loss: 3.6961
# Building optimizers ...
# Iteration: 3904; Percent complete: 97.6%; Average loss: 3.7406
# Building optimizers ...
# Iteration: 3905; Percent complete: 97.6%; Average loss: 3.6745
# Building optimizers ...
# Iteration: 3906; Percent complete: 97.7%; Average loss: 3.4844
# Building optimizers ...
# Iteration: 3907; Percent complete: 97.7%; Average loss: 3.5984
# Building optimizers ...
# Iteration: 3908; Percent complete: 97.7%; Average loss: 3.4858
# Building optimizers ...
# Iteration: 3909; Percent complete: 97.7%; Average loss: 3.6308
# Building optimizers ...
# Iteration: 3910; Percent complete: 97.8%; Average loss: 3.7830
# Building optimizers ...
# Iteration: 3911; Percent complete: 97.8%; Average loss: 3.3512
# Building optimizers ...
# Iteration: 3912; Percent complete: 97.8%; Average loss: 3.5428
# Building optimizers ...
# Iteration: 3913; Percent complete: 97.8%; Average loss: 3.5469
# Building optimizers ...
# Iteration: 3914; Percent complete: 97.9%; Average loss: 3.5187
# Building optimizers ...
# Iteration: 3915; Percent complete: 97.9%; Average loss: 3.5957
# Building optimizers ...
# Iteration: 3916; Percent complete: 97.9%; Average loss: 3.6669
# Building optimizers ...
# Iteration: 3917; Percent complete: 97.9%; Average loss: 3.7725
# Building optimizers ...
# Iteration: 3918; Percent complete: 98.0%; Average loss: 3.7000
# Building optimizers ...
# Iteration: 3919; Percent complete: 98.0%; Average loss: 3.7459
# Building optimizers ...
# Iteration: 3920; Percent complete: 98.0%; Average loss: 3.5675
# Building optimizers ...
# Iteration: 3921; Percent complete: 98.0%; Average loss: 3.4654
# Building optimizers ...
# Iteration: 3922; Percent complete: 98.0%; Average loss: 3.7368
# Building optimizers ...
# Iteration: 3923; Percent complete: 98.1%; Average loss: 3.4268
# Building optimizers ...
# Iteration: 3924; Percent complete: 98.1%; Average loss: 3.6451
# Building optimizers ...
# Iteration: 3925; Percent complete: 98.1%; Average loss: 3.6971
# Building optimizers ...
# Iteration: 3926; Percent complete: 98.2%; Average loss: 3.4226
# Building optimizers ...
# Iteration: 3927; Percent complete: 98.2%; Average loss: 3.4954
# Building optimizers ...
# Iteration: 3928; Percent complete: 98.2%; Average loss: 3.7999
# Building optimizers ...
# Iteration: 3929; Percent complete: 98.2%; Average loss: 3.4526
# Building optimizers ...
# Iteration: 3930; Percent complete: 98.2%; Average loss: 3.4334
# Building optimizers ...
# Iteration: 3931; Percent complete: 98.3%; Average loss: 3.5832
# Building optimizers ...
# Iteration: 3932; Percent complete: 98.3%; Average loss: 3.5838
# Building optimizers ...
# Iteration: 3933; Percent complete: 98.3%; Average loss: 3.3713
# Building optimizers ...
# Iteration: 3934; Percent complete: 98.4%; Average loss: 4.0374
# Building optimizers ...
# Iteration: 3935; Percent complete: 98.4%; Average loss: 3.6181
# Building optimizers ...
# Iteration: 3936; Percent complete: 98.4%; Average loss: 3.7510
# Building optimizers ...
# Iteration: 3937; Percent complete: 98.4%; Average loss: 3.6023
# Building optimizers ...
# Iteration: 3938; Percent complete: 98.5%; Average loss: 3.3137
# Building optimizers ...
# Iteration: 3939; Percent complete: 98.5%; Average loss: 3.6228
# Building optimizers ...
# Iteration: 3940; Percent complete: 98.5%; Average loss: 3.6103
# Building optimizers ...
# Iteration: 3941; Percent complete: 98.5%; Average loss: 3.5644
# Building optimizers ...
# Iteration: 3942; Percent complete: 98.6%; Average loss: 3.6573
# Building optimizers ...
# Iteration: 3943; Percent complete: 98.6%; Average loss: 3.4845
# Building optimizers ...
# Iteration: 3944; Percent complete: 98.6%; Average loss: 3.5514
# Building optimizers ...
# Iteration: 3945; Percent complete: 98.6%; Average loss: 3.5538
# Building optimizers ...
# Iteration: 3946; Percent complete: 98.7%; Average loss: 3.5084
# Building optimizers ...
# Iteration: 3947; Percent complete: 98.7%; Average loss: 3.8281
# Building optimizers ...
# Iteration: 3948; Percent complete: 98.7%; Average loss: 3.6166
# Building optimizers ...
# Iteration: 3949; Percent complete: 98.7%; Average loss: 3.6419
# Building optimizers ...
# Iteration: 3950; Percent complete: 98.8%; Average loss: 3.5977
# Building optimizers ...
# Iteration: 3951; Percent complete: 98.8%; Average loss: 3.6535
# Building optimizers ...
# Iteration: 3952; Percent complete: 98.8%; Average loss: 3.7243
# Building optimizers ...
# Iteration: 3953; Percent complete: 98.8%; Average loss: 3.5967
# Building optimizers ...
# Iteration: 3954; Percent complete: 98.9%; Average loss: 3.6887
# Building optimizers ...
# Iteration: 3955; Percent complete: 98.9%; Average loss: 3.6029
# Building optimizers ...
# Iteration: 3956; Percent complete: 98.9%; Average loss: 3.6578
# Building optimizers ...
# Iteration: 3957; Percent complete: 98.9%; Average loss: 3.5859
# Building optimizers ...
# Iteration: 3958; Percent complete: 99.0%; Average loss: 3.3597
# Building optimizers ...
# Iteration: 3959; Percent complete: 99.0%; Average loss: 3.7542
# Building optimizers ...
# Iteration: 3960; Percent complete: 99.0%; Average loss: 3.4527
# Building optimizers ...
# Iteration: 3961; Percent complete: 99.0%; Average loss: 3.7990
# Building optimizers ...
# Iteration: 3962; Percent complete: 99.1%; Average loss: 3.7200
# Building optimizers ...
# Iteration: 3963; Percent complete: 99.1%; Average loss: 3.5496
# Building optimizers ...
# Iteration: 3964; Percent complete: 99.1%; Average loss: 3.7270
# Building optimizers ...
# Iteration: 3965; Percent complete: 99.1%; Average loss: 3.6000
# Building optimizers ...
# Iteration: 3966; Percent complete: 99.2%; Average loss: 3.7631
# Building optimizers ...
# Iteration: 3967; Percent complete: 99.2%; Average loss: 3.6846
# Building optimizers ...
# Iteration: 3968; Percent complete: 99.2%; Average loss: 3.4372
# Building optimizers ...
# Iteration: 3969; Percent complete: 99.2%; Average loss: 3.6328
# Building optimizers ...
# Iteration: 3970; Percent complete: 99.2%; Average loss: 3.7694
# Building optimizers ...
# Iteration: 3971; Percent complete: 99.3%; Average loss: 3.8883
# Building optimizers ...
# Iteration: 3972; Percent complete: 99.3%; Average loss: 3.3824
# Building optimizers ...
# Iteration: 3973; Percent complete: 99.3%; Average loss: 3.5863
# Building optimizers ...
# Iteration: 3974; Percent complete: 99.4%; Average loss: 3.6315
# Building optimizers ...
# Iteration: 3975; Percent complete: 99.4%; Average loss: 3.5395
# Building optimizers ...
# Iteration: 3976; Percent complete: 99.4%; Average loss: 3.5424
# Building optimizers ...
# Iteration: 3977; Percent complete: 99.4%; Average loss: 3.5588
# Building optimizers ...
# Iteration: 3978; Percent complete: 99.5%; Average loss: 3.3930
# Building optimizers ...
# Iteration: 3979; Percent complete: 99.5%; Average loss: 3.4061
# Building optimizers ...
# Iteration: 3980; Percent complete: 99.5%; Average loss: 3.3935
# Building optimizers ...
# Iteration: 3981; Percent complete: 99.5%; Average loss: 3.6181
# Building optimizers ...
# Iteration: 3982; Percent complete: 99.6%; Average loss: 3.8949
# Building optimizers ...
# Iteration: 3983; Percent complete: 99.6%; Average loss: 3.4529
# Building optimizers ...
# Iteration: 3984; Percent complete: 99.6%; Average loss: 3.8842
# Building optimizers ...
# Iteration: 3985; Percent complete: 99.6%; Average loss: 3.6366
# Building optimizers ...
# Iteration: 3986; Percent complete: 99.7%; Average loss: 3.5335
# Building optimizers ...
# Iteration: 3987; Percent complete: 99.7%; Average loss: 3.6582
# Building optimizers ...
# Iteration: 3988; Percent complete: 99.7%; Average loss: 3.5649
# Building optimizers ...
# Iteration: 3989; Percent complete: 99.7%; Average loss: 3.6757
# Building optimizers ...
# Iteration: 3990; Percent complete: 99.8%; Average loss: 3.6487
# Building optimizers ...
# Iteration: 3991; Percent complete: 99.8%; Average loss: 3.9090
# Building optimizers ...
# Iteration: 3992; Percent complete: 99.8%; Average loss: 3.2369
# Building optimizers ...
# Iteration: 3993; Percent complete: 99.8%; Average loss: 3.6275
# Building optimizers ...
# Iteration: 3994; Percent complete: 99.9%; Average loss: 3.5237
# Building optimizers ...
# Iteration: 3995; Percent complete: 99.9%; Average loss: 3.6732
# Building optimizers ...
# Iteration: 3996; Percent complete: 99.9%; Average loss: 3.5280
# Building optimizers ...
# Iteration: 3997; Percent complete: 99.9%; Average loss: 3.7091
# Building optimizers ...
# Iteration: 3998; Percent complete: 100.0%; Average loss: 3.4595
# Building optimizers ...
# Iteration: 3999; Percent complete: 100.0%; Average loss: 3.7839
# Building optimizers ...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 3.6492

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores


def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to("cpu")
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            print(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            print(output_words)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

searcher = GreedySearchDecoder(encoder, decoder)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# hello
# ['i', 'm', 'not', 'a', 'half', '.', 'EOS', '.', 'EOS', '.']
# Bot: i m not a half . . .
# how are you ?
# ['i', 'm', 'not', 'sure', '.', 'EOS', '.', 'EOS', '.', 'EOS']
# Bot: i m not sure . . .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/kinbunhua/cds522/groupproject/chatbot_tutorial2.ipynb 单元格 3 in <cell line: 72>()
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial2.ipynb#W2sZmlsZQ%3D%3D?line=68'>69</a>             print("Error: Encountered unknown word.")
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial2.ipynb#W2sZmlsZQ%3D%3D?line=70'>71</a> searcher = GreedySearchDecoder(encoder, decoder)
# ---> <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial2.ipynb#W2sZmlsZQ%3D%3D?line=71'>72</a> evaluateInput(encoder, decoder, searcher, voc)
#
# /Users/kinbunhua/cds522/groupproject/chatbot_tutorial2.ipynb 单元格 3 in evaluateInput(encoder, decoder, searcher, voc)
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial2.ipynb#W2sZmlsZQ%3D%3D?line=51'>52</a> while(1):
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial2.ipynb#W2sZmlsZQ%3D%3D?line=52'>53</a>     try:
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial2.ipynb#W2sZmlsZQ%3D%3D?line=53'>54</a>         # Get input sentence
# ---> <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial2.ipynb#W2sZmlsZQ%3D%3D?line=54'>55</a>         input_sentence = input('> ')
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial2.ipynb#W2sZmlsZQ%3D%3D?line=55'>56</a>         # Check if it is quit case
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial2.ipynb#W2sZmlsZQ%3D%3D?line=56'>57</a>         if input_sentence == 'q' or input_sentence == 'quit': break
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ipykernel/kernelbase.py:1161, in Kernel.raw_input(self, prompt)
#    1157 if not self._allow_stdin:
#    1158     raise StdinNotImplementedError(
#    1159         "raw_input was called, but this frontend does not support input requests."
#    1160     )
# -> 1161 return self._input_request(
#    1162     str(prompt),
#    1163     self._parent_ident["shell"],
#    1164     self.get_parent("shell"),
#    1165     password=False,
#    1166 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ipykernel/kernelbase.py:1205, in Kernel._input_request(self, prompt, ident, parent, password)
#    1202             break
#    1203 except KeyboardInterrupt:
#    1204     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1205     raise KeyboardInterrupt("Interrupted by user") from None
#    1206 except Exception:
#    1207     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
