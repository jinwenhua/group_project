# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals
from pre_process import *

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import random
import os


USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")
# Out:
# b'{"id": "L1045", "conversation_id": "L1044", "text": "They do not!", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "not", "tag": "RB", "dep": "neg", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L1044", "timestamp": null, "vectors": []}\n'
# b'{"id": "L1044", "conversation_id": "L1044", "text": "They do to!", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "to", "tag": "TO", "dep": "dobj", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L985", "conversation_id": "L984", "text": "I hope so.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "hope", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "so", "tag": "RB", "dep": "advmod", "up": 1, "dn": []}, {"tok": ".", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L984", "timestamp": null, "vectors": []}\n'
# b'{"id": "L984", "conversation_id": "L984", "text": "She okay?", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "She", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "okay", "tag": "RB", "dep": "ROOT", "dn": [0, 2]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L925", "conversation_id": "L924", "text": "Let\'s go.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Let", "tag": "VB", "dep": "ROOT", "dn": [2, 3]}, {"tok": "\'s", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "go", "tag": "VB", "dep": "ccomp", "up": 0, "dn": [1]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L924", "timestamp": null, "vectors": []}\n'
# b'{"id": "L924", "conversation_id": "L924", "text": "Wow", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Wow", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L872", "conversation_id": "L870", "text": "Okay -- you\'re gonna need to learn how to lie.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 4, "toks": [{"tok": "Okay", "tag": "UH", "dep": "intj", "up": 4, "dn": []}, {"tok": "--", "tag": ":", "dep": "punct", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "\'re", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "gon", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 2, 3, 6, 12]}, {"tok": "na", "tag": "TO", "dep": "aux", "up": 6, "dn": []}, {"tok": "need", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 8]}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 8, "dn": []}, {"tok": "learn", "tag": "VB", "dep": "xcomp", "up": 6, "dn": [7, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 11, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 11, "dn": []}, {"tok": "lie", "tag": "VB", "dep": "xcomp", "up": 8, "dn": [9, 10]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": "L871", "timestamp": null, "vectors": []}\n'
# b'{"id": "L871", "conversation_id": "L870", "text": "No", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "No", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": "L870", "timestamp": null, "vectors": []}\n'
# b'{"id": "L870", "conversation_id": "L870", "text": "I\'m kidding.  You know how sometimes you just become this \\"persona\\"?  And you don\'t know how to quit?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 2, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "\'m", "tag": "VBP", "dep": "aux", "up": 2, "dn": []}, {"tok": "kidding", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 3]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 2, "dn": [4]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 3, "dn": []}]}, {"rt": 1, "toks": [{"tok": "You", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "know", "tag": "VBP", "dep": "ROOT", "dn": [0, 6, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 3, "dn": []}, {"tok": "sometimes", "tag": "RB", "dep": "advmod", "up": 6, "dn": [2]}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 6, "dn": []}, {"tok": "just", "tag": "RB", "dep": "advmod", "up": 6, "dn": []}, {"tok": "become", "tag": "VBP", "dep": "ccomp", "up": 1, "dn": [3, 4, 5, 9]}, {"tok": "this", "tag": "DT", "dep": "det", "up": 9, "dn": []}, {"tok": "\\"", "tag": "``", "dep": "punct", "up": 9, "dn": []}, {"tok": "persona", "tag": "NN", "dep": "attr", "up": 6, "dn": [7, 8, 10]}, {"tok": "\\"", "tag": "\'\'", "dep": "punct", "up": 9, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": [12]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 11, "dn": []}]}, {"rt": 4, "toks": [{"tok": "And", "tag": "CC", "dep": "cc", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "n\'t", "tag": "RB", "dep": "neg", "up": 4, "dn": []}, {"tok": "know", "tag": "VB", "dep": "ROOT", "dn": [0, 1, 2, 3, 7, 8]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 7, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 7, "dn": []}, {"tok": "quit", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 6]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L869", "conversation_id": "L866", "text": "Like my fear of wearing pastels?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Like", "tag": "IN", "dep": "ROOT", "dn": [2, 6]}, {"tok": "my", "tag": "PRP$", "dep": "poss", "up": 2, "dn": []}, {"tok": "fear", "tag": "NN", "dep": "pobj", "up": 0, "dn": [1, 3]}, {"tok": "of", "tag": "IN", "dep": "prep", "up": 2, "dn": [4]}, {"tok": "wearing", "tag": "VBG", "dep": "pcomp", "up": 3, "dn": [5]}, {"tok": "pastels", "tag": "NNS", "dep": "dobj", "up": 4, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L868", "timestamp": null, "vectors": []}\n'
#
# Processing corpus into lines and conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# b'They do to!\tThey do not!\n'
# b'She okay?\tI hope so.\n'
# b"Wow\tLet's go.\n"
# b'"I\'m kidding.  You know how sometimes you just become this ""persona""?  And you don\'t know how to quit?"\tNo\n'
# b"No\tOkay -- you're gonna need to learn how to lie.\n"
# b"I figured you'd get to the good stuff eventually.\tWhat good stuff?\n"
# b'What good stuff?\t"The ""real you""."\n'
# b'"The ""real you""."\tLike my fear of wearing pastels?\n'
# b'do you listen to this crap?\tWhat crap?\n'
# b"What crap?\tMe.  This endless ...blonde babble. I'm like, boring myself.\n"
# Start preparing training data ...
# Reading lines...
# Read 221282 sentence pairs
# Trimmed to 64313 sentence pairs
# Counting words...
# Counted words: 18082
#
# pairs:
# ['they do to !', 'they do not !']
# ['she okay ?', 'i hope so .']
# ['wow', 'let s go .']
# ['what good stuff ?', 'the real you .']
# ['the real you .', 'like my fear of wearing pastels ?']
# ['do you listen to this crap ?', 'what crap ?']
# ['well no . . .', 'then that s all you had to say .']
# ['then that s all you had to say .', 'but']
# ['but', 'you always been this selfish ?']
# ['have fun tonight ?', 'tons']
# keep_words 7833 / 18079 = 0.4333
# Trimmed from 64313 pairs to 53131, 0.8261 of total
# input_variable: tensor([[  35,    4,   11,   77, 7128],
#         [  36,  377,  200,   24,   72],
#         [  17, 1026,  663,  547,   14],
#         [  22,   36,  997,  370,    2],
#         [ 488,   24,   14,   10,    0],
#         [ 101,   77,    2,    2,    0],
#         [ 380,   33,    0,    0,    0],
#         [   6,   10,    0,    0,    0],
#         [   2,    2,    0,    0,    0]])
# lengths: tensor([9, 9, 6, 6, 4])
# target_variable: tensor([[7300,   34,  223,   11,    8],
#         [ 101,   14,    4,  208, 2252],
#         [ 380,    2,   24,  135,   14],
#         [   6,    0,   18,   25,    2],
#         [   2,    0,   92,    5,    0],
#         [   0,    0,   10,  523,    0],
#         [   0,    0,    2,   84,    0],
#         [   0,    0,    0,   36,    0],
#         [   0,    0,    0,   14,    0],
#         [   0,    0,    0,    2,    0]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True, False,  True,  True,  True],
#         [ True, False,  True,  True, False],
#         [False, False,  True,  True, False],
#         [False, False,  True,  True, False],
#         [False, False, False,  True, False],
#         [False, False, False,  True, False],
#         [False, False, False,  True, False]])
# max_target_len: 10

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import torch
import torch.nn as nn
from torch.autograd import Variable
import numpy as np
import math


class GRUCell(nn.Module):
    def __init__(self, input_size, hidden_size, bias=True):
        super(GRUCell, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.bias = bias

        self.x2h = nn.Linear(input_size, 3 * hidden_size, bias=bias)
        self.h2h = nn.Linear(hidden_size, 3 * hidden_size, bias=bias)

        self.reset_parameters()


    def reset_parameters(self):
        std = 1.0 / np.sqrt(self.hidden_size)
        for w in self.parameters():
            w.data.uniform_(-std, std)

    def forward(self, input, hx=None):

        # Inputs:
        #       input: of shape (batch_size, input_size)
        #       hx: of shape (batch_size, hidden_size)
        # Output:
        #       hy: of shape (batch_size, hidden_size)

        if hx is None:
            hx = Variable(input.new_zeros(input.size(0), self.hidden_size))

        x_t = self.x2h(input)
        h_t = self.h2h(hx)


        x_reset, x_upd, x_new = x_t.chunk(3, 0)
        h_reset, h_upd, h_new = h_t.chunk(3, 0)

        reset_gate = torch.sigmoid(x_reset + h_reset)
        update_gate = torch.sigmoid(x_upd + h_upd)
        new_gate = torch.tanh(x_new + (reset_gate * h_new))

        hy = update_gate * hx + (1 - update_gate) * new_gate

        return hy



class BidirRecurrentModel(nn.Module):
    def __init__(self, mode, input_size, hidden_size, num_layers, output_size = 0, bias = True):
        super(BidirRecurrentModel, self).__init__()
        self.mode = mode
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.bias = bias
        #self.output_size = output_size

        self.rnn_cell_list = nn.ModuleList()

        for _ in range(100):
            self.rnn_cell_list.append(GRUCell(self.input_size,
                                                self.hidden_size,
                                                self.bias))
            for l in range(1, self.num_layers):
                self.rnn_cell_list.append(GRUCell(self.hidden_size,
                                                    self.hidden_size,
                                                    self.bias))



        #self.fc = nn.Linear(self.hidden_size * 2, self.output_size)

    def forward(self, input, input_seq=None, merge_mode = 'ave'):

        # Input of shape (batch_size, sequence length, input_size)
        #
        # Output of shape (batch_size, output_size)

        if torch.cuda.is_available():
            h0 = Variable(torch.zeros(self.num_layers, input.size(1), self.hidden_size).cuda())
        else:
            h0 = Variable(torch.zeros(self.num_layers, input.size(1), self.hidden_size))


        outs = []
        outs_rev = []

        hidden_forward = list()
        for layer in range(self.num_layers):
            if self.mode == 'LSTM':
                hidden_forward.append((h0[layer, :, :], h0[layer, :, :]))
            else:
                hidden_forward.append(h0[layer, :, :])

        for t in range(input.shape[0]):
            for layer in range(self.num_layers):
                # If RNN{_TANH/_RELU} / GRU
                '''
                if layer == 0:
                    # Forward net
                    h_forward_l = self.rnn_cell_list[layer](input[t, :, :], hidden_forward[layer])

                else:
                    # Forward net
                    h_forward_l = self.rnn_cell_list[layer](hidden_forward[layer - 1], hidden_forward[layer])
                '''
                if torch.cuda.is_available():
                    h_forward_l = Variable(torch.zeros(input.size(1), self.hidden_size).cuda())
                else:
                    h_forward_l = Variable(torch.zeros( input.size(1), self.hidden_size))
                for i in range(input.size(1)):
                    cell_id = math.floor(input_seq[t, i] / 88) * self.num_layers 
                    if layer == 0:
                        # Forward net
                        h_forward_l[i] = self.rnn_cell_list[cell_id + layer](input[t, i, :], hidden_forward[layer][i])
                    else:
                        # Forward net
                        h_forward_l[i] = self.rnn_cell_list[cell_id + layer](hidden_forward[layer - 1][i], hidden_forward[layer][i])
                
                

                hidden_forward[layer] = h_forward_l

            if self.mode == 'LSTM':

                outs.append(h_forward_l[0])

            else:
                outs.append(h_forward_l)

        output = []


        if torch.cuda.is_available():
            output = torch.tensor([item.detach().numpy() for item in outs]).cuda()
        else:
            output = torch.tensor([item.detach().numpy() for item in outs])

        '''
        out = outs[-1].squeeze()
        out_rev = outs_rev[0].squeeze()
        out = torch.cat((out, out_rev), 1)
        '''

        for layer in range(self.num_layers):
            h0[layer] = torch.tensor([item.detach().numpy() for item in hidden_forward[layer]])
                
        
        #out = self.fc(out)
        return output, h0
        
######################################################################
# Define Encoder
# --------------
#
# We implement our encoder’s RNN with the ``torch.nn.GRU`` module which we
# feed a batch of sentences (vectors of word embeddings) and it internally
# iterates through the sentences one token at a time calculating the
# hidden states. We initialize this module to be bidirectional, meaning
# that we have two independent GRUs: one that iterates through the
# sequences in chronological order, and another that iterates in reverse
# order. We ultimately return the sum of these two GRUs’ outputs. Since
# our model was trained using batching, our ``EncoderRNN`` model’s
# ``forward`` function expects a padded input batch. To batch
# variable-length sentences, we allow a maximum of *MAX_LENGTH* tokens in
# a sentence, and all sentences in the batch that have less than
# *MAX_LENGTH* tokens are padded at the end with our dedicated *PAD_token*
# tokens. To use padded batches with a PyTorch RNN module, we must wrap
# the forward pass call with ``torch.nn.utils.rnn.pack_padded_sequence``
# and ``torch.nn.utils.rnn.pad_packed_sequence`` data transformations.
# Note that the ``forward`` function also takes an ``input_lengths`` list,
# which contains the length of each sentence in the batch. This input is
# used by the ``torch.nn.utils.rnn.pack_padded_sequence`` function when
# padding.
#
# TorchScript Notes:
# ~~~~~~~~~~~~~~~~~~~~~~
#
# Since the encoder’s ``forward`` function does not contain any
# data-dependent control flow, we will use **tracing** to convert it to
# script mode. When tracing a module, we can leave the module definition
# as-is. We will initialize all models towards the end of this document
# before we run evaluations.
#

class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size params are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = BidirRecurrentModel("GRU", hidden_size, hidden_size, n_layers)
        #self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # type: (Tensor, Tensor, Optional[Tensor]) -> Tuple[Tensor, Tensor]
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        outputs, hidden = self.gru(embedded, input_seq)
        '''
        # Pack padded batch of sequences for RNN module
        packed = torch.nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = torch.nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        '''
        
        # Return output and final hidden state
        return outputs, hidden

    ######################################################################
# Define Decoder’s Attention Module
# ---------------------------------
#
# Next, we’ll define our attention module (``Attn``). Note that this
# module will be used as a submodule in our decoder model. Luong et
# al. consider various “score functions”, which take the current decoder
# RNN output and the entire encoder output, and return attention
# “energies”. This attention energies tensor is the same size as the
# encoder output, and the two are ultimately multiplied, resulting in a
# weighted tensor whose largest values represent the most important parts
# of the query sentence at a particular time-step of decoding.
#

# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))
    
    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)


######################################################################
# Define Decoder
# --------------
#
# Similarly to the ``EncoderRNN``, we use the ``torch.nn.GRU`` module for
# our decoder’s RNN. This time, however, we use a unidirectional GRU. It
# is important to note that unlike the encoder, we will feed the decoder
# RNN one word at a time. We start by getting the embedding of the current
# word and applying a
# `dropout <https://pytorch.org/docs/stable/nn.html?highlight=dropout#torch.nn.Dropout>`__.
# Next, we forward the embedding and the last hidden state to the GRU and
# obtain a current GRU output and hidden state. We then use our ``Attn``
# module as a layer to obtain the attention weights, which we multiply by
# the encoder’s output to obtain our attended encoder output. We use this
# attended encoder output as our ``context`` tensor, which represents a
# weighted sum indicating what parts of the encoder’s output to pay
# attention to. From here, we use a linear layer and softmax normalization
# to select the next word in the output sequence.

# TorchScript Notes:
# ~~~~~~~~~~~~~~~~~~~~~~
#
# Similarly to the ``EncoderRNN``, this module does not contain any
# data-dependent control flow. Therefore, we can once again use
# **tracing** to convert this model to TorchScript after it
# is initialized and its parameters are loaded.
#

class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %%
######################################################################
# Define Training Procedure
# -------------------------
#
# Masked loss
# ~~~~~~~~~~~
#
# Since we are dealing with batches of padded sequences, we cannot simply
# consider all elements of the tensor when calculating loss. We define
# ``maskNLLLoss`` to calculate our loss based on our decoder’s output
# tensor, the target tensor, and a binary mask tensor describing the
# padding of the target tensor. This loss function calculates the average
# negative log likelihood of the elements that correspond to a *1* in the
# mask tensor.
#

def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()


######################################################################
# Single training iteration
# ~~~~~~~~~~~~~~~~~~~~~~~~~
#
# The ``train`` function contains the algorithm for a single training
# iteration (a single batch of inputs).
#
# We will use a couple of clever tricks to aid in convergence:
#
# -  The first trick is using **teacher forcing**. This means that at some
#    probability, set by ``teacher_forcing_ratio``, we use the current
#    target word as the decoder’s next input rather than using the
#    decoder’s current guess. This technique acts as training wheels for
#    the decoder, aiding in more efficient training. However, teacher
#    forcing can lead to model instability during inference, as the
#    decoder may not have a sufficient chance to truly craft its own
#    output sequences during training. Thus, we must be mindful of how we
#    are setting the ``teacher_forcing_ratio``, and not be fooled by fast
#    convergence.
#
# -  The second trick that we implement is **gradient clipping**. This is
#    a commonly used technique for countering the “exploding gradient”
#    problem. In essence, by clipping or thresholding gradients to a
#    maximum value, we prevent the gradients from growing exponentially
#    and either overflow (NaN), or overshoot steep cliffs in the cost
#    function.
#
# .. figure:: /_static/img/chatbot/grad_clip.png
#    :align: center
#    :width: 60%
#    :alt: grad_clip
#
# Image source: Goodfellow et al. *Deep Learning*. 2016. https://www.deeplearningbook.org/
#
# **Sequence of Operations:**
#
#    1) Forward pass entire input batch through encoder.
#    2) Initialize decoder inputs as SOS_token, and hidden state as the encoder's final hidden state.
#    3) Forward input batch sequence through decoder one time step at a time.
#    4) If teacher forcing: set next decoder input as the current target; else: set next decoder input as current decoder output.
#    5) Calculate and accumulate loss.
#    6) Perform backpropagation.
#    7) Clip gradients.
#    8) Update encoder and decoder model parameters.
#
#
# .. Note ::
#
#   PyTorch’s RNN modules (``RNN``, ``LSTM``, ``GRU``) can be used like any
#   other non-recurrent layers by simply passing them the entire input
#   sequence (or batch of sequences). We use the ``GRU`` layer like this in
#   the ``encoder``. The reality is that under the hood, there is an
#   iterative process looping over each time step calculating hidden states.
#   Alternatively, you can run these modules one time-step at a time. In
#   this case, we manually loop over the sequences during the training
#   process like we must do for the ``decoder`` model. As long as you
#   maintain the correct conceptual model of these modules, implementing
#   sequential models can be very straightforward.
#
#


def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for rnn packing should always be on the cpu
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropatation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals


######################################################################
# Training iterations
# ~~~~~~~~~~~~~~~~~~~
#
# It is finally time to tie the full training procedure together with the
# data. The ``trainIters`` function is responsible for running
# ``n_iterations`` of training given the passed models, optimizers, data,
# etc. This function is quite self explanatory, as we have done the heavy
# lifting with the ``train`` function.
#
# One thing to note is that when we save our model, we save a tarball
# containing the encoder and decoder state_dicts (parameters), the
# optimizers’ state_dicts, the loss, the iteration, etc. Saving the model
# in this way will give us the ultimate flexibility with the checkpoint.
# After loading a checkpoint, we will be able to use the model parameters
# to run inference, or we can continue training right where we left off.
#

def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, clip, corpus_name, loadFilename):

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg))
            print_loss = 0

        #'''
        # Save checkpoint
        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size))
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint1')))

        #'''


######################################################################
# Run Model
# ---------
#
# Finally, it is time to run our model!
#
# Regardless of whether we want to train or test the chatbot model, we
# must initialize the individual encoder and decoder models. In the
# following block, we set our desired configurations, choose to start from
# scratch or set a checkpoint to load from, and build and initialize the
# models. Feel free to play with different model configurations to
# optimize performance.
#

# Configure models
model_name = 'cb_model'
attn_model = 'dot'
#attn_model = 'general'
#attn_model = 'concat'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 4000
#loadFilename = os.path.join(save_dir, model_name, corpus_name,
#                            '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
#                            '{}_checkpoint.tar'.format(checkpoint_iter))


# Load model if a loadFilename is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')


######################################################################
# Run Training
# ~~~~~~~~~~~~
#
# Run the following block if you want to train the model.
#
# First we set training parameters, then we initialize our optimizers, and
# finally we call the ``trainIters`` function to run our training
# iterations.
#

# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 4000
#n_iteration = 1  #just used for test
print_every = 1
save_every = 4000

# Ensure dropout layers are in train mode
encoder.train()
decoder.train()

# Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
if loadFilename:
    encoder_optimizer.load_state_dict(encoder_optimizer_sd)
    decoder_optimizer.load_state_dict(decoder_optimizer_sd)

# If you have cuda, configure cuda to call
for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

# Run training iterations
print("Starting Training!")
trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name, loadFilename)
# Out:
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# /var/folders/rk/rb0btt_x2mxgsj16ky_t07tr0000gn/T/ipykernel_6074/708885139.py:147: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:233.)
#   output = torch.tensor([item.detach().numpy() for item in outs])
# Iteration: 1; Percent complete: 0.0%; Average loss: 8.9664
# Iteration: 2; Percent complete: 0.1%; Average loss: 8.8567
# Iteration: 3; Percent complete: 0.1%; Average loss: 8.6965
# Iteration: 4; Percent complete: 0.1%; Average loss: 8.4649
# Iteration: 5; Percent complete: 0.1%; Average loss: 8.0535
# Iteration: 6; Percent complete: 0.1%; Average loss: 7.8200
# Iteration: 7; Percent complete: 0.2%; Average loss: 6.9690
# Iteration: 8; Percent complete: 0.2%; Average loss: 6.7733
# Iteration: 9; Percent complete: 0.2%; Average loss: 6.6907
# Iteration: 10; Percent complete: 0.2%; Average loss: 6.7965
# Iteration: 11; Percent complete: 0.3%; Average loss: 6.1415
# Iteration: 12; Percent complete: 0.3%; Average loss: 6.0025
# Iteration: 13; Percent complete: 0.3%; Average loss: 5.7533
# Iteration: 14; Percent complete: 0.4%; Average loss: 5.5243
# Iteration: 15; Percent complete: 0.4%; Average loss: 5.3920
# Iteration: 16; Percent complete: 0.4%; Average loss: 5.5241
# Iteration: 17; Percent complete: 0.4%; Average loss: 5.1222
# Iteration: 18; Percent complete: 0.4%; Average loss: 5.2473
# Iteration: 19; Percent complete: 0.5%; Average loss: 5.0127
# Iteration: 20; Percent complete: 0.5%; Average loss: 4.9755
# Iteration: 21; Percent complete: 0.5%; Average loss: 5.0169
# Iteration: 22; Percent complete: 0.5%; Average loss: 4.7338
# Iteration: 23; Percent complete: 0.6%; Average loss: 4.7555
# Iteration: 24; Percent complete: 0.6%; Average loss: 4.9185
# Iteration: 25; Percent complete: 0.6%; Average loss: 4.8681
# Iteration: 26; Percent complete: 0.7%; Average loss: 4.7316
# Iteration: 27; Percent complete: 0.7%; Average loss: 4.8917
# Iteration: 28; Percent complete: 0.7%; Average loss: 4.8915
# Iteration: 29; Percent complete: 0.7%; Average loss: 4.9039
# Iteration: 30; Percent complete: 0.8%; Average loss: 4.7616
# Iteration: 31; Percent complete: 0.8%; Average loss: 4.9049
# Iteration: 32; Percent complete: 0.8%; Average loss: 4.7791
# Iteration: 33; Percent complete: 0.8%; Average loss: 4.7004
# Iteration: 34; Percent complete: 0.9%; Average loss: 4.8234
# Iteration: 35; Percent complete: 0.9%; Average loss: 4.7614
# Iteration: 36; Percent complete: 0.9%; Average loss: 4.7328
# Iteration: 37; Percent complete: 0.9%; Average loss: 4.8808
# Iteration: 38; Percent complete: 0.9%; Average loss: 4.8184
# Iteration: 39; Percent complete: 1.0%; Average loss: 4.5409
# Iteration: 40; Percent complete: 1.0%; Average loss: 4.7531
# Iteration: 41; Percent complete: 1.0%; Average loss: 4.7646
# Iteration: 42; Percent complete: 1.1%; Average loss: 4.6910
# Iteration: 43; Percent complete: 1.1%; Average loss: 4.6100
# Iteration: 44; Percent complete: 1.1%; Average loss: 4.6533
# Iteration: 45; Percent complete: 1.1%; Average loss: 4.3853
# Iteration: 46; Percent complete: 1.1%; Average loss: 4.8561
# Iteration: 47; Percent complete: 1.2%; Average loss: 4.9673
# Iteration: 48; Percent complete: 1.2%; Average loss: 4.8420
# Iteration: 49; Percent complete: 1.2%; Average loss: 4.7123
# Iteration: 50; Percent complete: 1.2%; Average loss: 4.6973
# Iteration: 51; Percent complete: 1.3%; Average loss: 4.8060
# Iteration: 52; Percent complete: 1.3%; Average loss: 4.6172
# Iteration: 53; Percent complete: 1.3%; Average loss: 4.6855
# Iteration: 54; Percent complete: 1.4%; Average loss: 4.6168
# Iteration: 55; Percent complete: 1.4%; Average loss: 4.7302
# Iteration: 56; Percent complete: 1.4%; Average loss: 4.8587
# Iteration: 57; Percent complete: 1.4%; Average loss: 4.7060
# Iteration: 58; Percent complete: 1.5%; Average loss: 4.8492
# Iteration: 59; Percent complete: 1.5%; Average loss: 4.2917
# Iteration: 60; Percent complete: 1.5%; Average loss: 4.3960
# Iteration: 61; Percent complete: 1.5%; Average loss: 4.5834
# Iteration: 62; Percent complete: 1.6%; Average loss: 4.5447
# Iteration: 63; Percent complete: 1.6%; Average loss: 4.5754
# Iteration: 64; Percent complete: 1.6%; Average loss: 4.7960
# Iteration: 65; Percent complete: 1.6%; Average loss: 4.5691
# Iteration: 66; Percent complete: 1.7%; Average loss: 4.8224
# Iteration: 67; Percent complete: 1.7%; Average loss: 4.5121
# Iteration: 68; Percent complete: 1.7%; Average loss: 4.7188
# Iteration: 69; Percent complete: 1.7%; Average loss: 4.4886
# Iteration: 70; Percent complete: 1.8%; Average loss: 4.6850
# Iteration: 71; Percent complete: 1.8%; Average loss: 4.5548
# Iteration: 72; Percent complete: 1.8%; Average loss: 4.6050
# Iteration: 73; Percent complete: 1.8%; Average loss: 4.5136
# Iteration: 74; Percent complete: 1.8%; Average loss: 4.9124
# Iteration: 75; Percent complete: 1.9%; Average loss: 4.2769
# Iteration: 76; Percent complete: 1.9%; Average loss: 4.3447
# Iteration: 77; Percent complete: 1.9%; Average loss: 4.6260
# Iteration: 78; Percent complete: 1.9%; Average loss: 4.6887
# Iteration: 79; Percent complete: 2.0%; Average loss: 4.5988
# Iteration: 80; Percent complete: 2.0%; Average loss: 4.5066
# Iteration: 81; Percent complete: 2.0%; Average loss: 4.5324
# Iteration: 82; Percent complete: 2.1%; Average loss: 4.4495
# Iteration: 83; Percent complete: 2.1%; Average loss: 4.5494
# Iteration: 84; Percent complete: 2.1%; Average loss: 4.4304
# Iteration: 85; Percent complete: 2.1%; Average loss: 4.4105
# Iteration: 86; Percent complete: 2.1%; Average loss: 4.4058
# Iteration: 87; Percent complete: 2.2%; Average loss: 4.4915
# Iteration: 88; Percent complete: 2.2%; Average loss: 4.6471
# Iteration: 89; Percent complete: 2.2%; Average loss: 4.5427
# Iteration: 90; Percent complete: 2.2%; Average loss: 4.5589
# Iteration: 91; Percent complete: 2.3%; Average loss: 4.5110
# Iteration: 92; Percent complete: 2.3%; Average loss: 4.5333
# Iteration: 93; Percent complete: 2.3%; Average loss: 4.4390
# Iteration: 94; Percent complete: 2.4%; Average loss: 4.5840
# Iteration: 95; Percent complete: 2.4%; Average loss: 4.4936
# Iteration: 96; Percent complete: 2.4%; Average loss: 4.5036
# Iteration: 97; Percent complete: 2.4%; Average loss: 4.5003
# Iteration: 98; Percent complete: 2.5%; Average loss: 4.5647
# Iteration: 99; Percent complete: 2.5%; Average loss: 4.3740
# Iteration: 100; Percent complete: 2.5%; Average loss: 4.4723
# Iteration: 101; Percent complete: 2.5%; Average loss: 4.6246
# Iteration: 102; Percent complete: 2.5%; Average loss: 4.6175
# Iteration: 103; Percent complete: 2.6%; Average loss: 4.5962
# Iteration: 104; Percent complete: 2.6%; Average loss: 4.5926
# Iteration: 105; Percent complete: 2.6%; Average loss: 4.4236
# Iteration: 106; Percent complete: 2.6%; Average loss: 4.2876
# Iteration: 107; Percent complete: 2.7%; Average loss: 4.4207
# Iteration: 108; Percent complete: 2.7%; Average loss: 4.3885
# Iteration: 109; Percent complete: 2.7%; Average loss: 4.3337
# Iteration: 110; Percent complete: 2.8%; Average loss: 4.4737
# Iteration: 111; Percent complete: 2.8%; Average loss: 4.2597
# Iteration: 112; Percent complete: 2.8%; Average loss: 4.5395
# Iteration: 113; Percent complete: 2.8%; Average loss: 4.5047
# Iteration: 114; Percent complete: 2.9%; Average loss: 4.4846
# Iteration: 115; Percent complete: 2.9%; Average loss: 4.4785
# Iteration: 116; Percent complete: 2.9%; Average loss: 4.4639
# Iteration: 117; Percent complete: 2.9%; Average loss: 4.3785
# Iteration: 118; Percent complete: 2.9%; Average loss: 4.4095
# Iteration: 119; Percent complete: 3.0%; Average loss: 4.1204
# Iteration: 120; Percent complete: 3.0%; Average loss: 4.4718
# Iteration: 121; Percent complete: 3.0%; Average loss: 4.2652
# Iteration: 122; Percent complete: 3.0%; Average loss: 4.6168
# Iteration: 123; Percent complete: 3.1%; Average loss: 4.4803
# Iteration: 124; Percent complete: 3.1%; Average loss: 4.3950
# Iteration: 125; Percent complete: 3.1%; Average loss: 4.5202
# Iteration: 126; Percent complete: 3.1%; Average loss: 4.3162
# Iteration: 127; Percent complete: 3.2%; Average loss: 4.3992
# Iteration: 128; Percent complete: 3.2%; Average loss: 4.4632
# Iteration: 129; Percent complete: 3.2%; Average loss: 4.2707
# Iteration: 130; Percent complete: 3.2%; Average loss: 4.3522
# Iteration: 131; Percent complete: 3.3%; Average loss: 4.3135
# Iteration: 132; Percent complete: 3.3%; Average loss: 4.3195
# Iteration: 133; Percent complete: 3.3%; Average loss: 4.1611
# Iteration: 134; Percent complete: 3.4%; Average loss: 4.1090
# Iteration: 135; Percent complete: 3.4%; Average loss: 4.3748
# Iteration: 136; Percent complete: 3.4%; Average loss: 4.3498
# Iteration: 137; Percent complete: 3.4%; Average loss: 4.4793
# Iteration: 138; Percent complete: 3.5%; Average loss: 4.4024
# Iteration: 139; Percent complete: 3.5%; Average loss: 4.3413
# Iteration: 140; Percent complete: 3.5%; Average loss: 4.4510
# Iteration: 141; Percent complete: 3.5%; Average loss: 4.3712
# Iteration: 142; Percent complete: 3.5%; Average loss: 4.4027
# Iteration: 143; Percent complete: 3.6%; Average loss: 4.4131
# Iteration: 144; Percent complete: 3.6%; Average loss: 4.2396
# Iteration: 145; Percent complete: 3.6%; Average loss: 4.3236
# Iteration: 146; Percent complete: 3.6%; Average loss: 4.3960
# Iteration: 147; Percent complete: 3.7%; Average loss: 4.1706
# Iteration: 148; Percent complete: 3.7%; Average loss: 4.3361
# Iteration: 149; Percent complete: 3.7%; Average loss: 4.3036
# Iteration: 150; Percent complete: 3.8%; Average loss: 4.4079
# Iteration: 151; Percent complete: 3.8%; Average loss: 4.3719
# Iteration: 152; Percent complete: 3.8%; Average loss: 4.4554
# Iteration: 153; Percent complete: 3.8%; Average loss: 4.2005
# Iteration: 154; Percent complete: 3.9%; Average loss: 4.2839
# Iteration: 155; Percent complete: 3.9%; Average loss: 4.2278
# Iteration: 156; Percent complete: 3.9%; Average loss: 4.3211
# Iteration: 157; Percent complete: 3.9%; Average loss: 4.5131
# Iteration: 158; Percent complete: 4.0%; Average loss: 4.3521
# Iteration: 159; Percent complete: 4.0%; Average loss: 4.3434
# Iteration: 160; Percent complete: 4.0%; Average loss: 4.0507
# Iteration: 161; Percent complete: 4.0%; Average loss: 4.1726
# Iteration: 162; Percent complete: 4.0%; Average loss: 4.2365
# Iteration: 163; Percent complete: 4.1%; Average loss: 4.2471
# Iteration: 164; Percent complete: 4.1%; Average loss: 4.2344
# Iteration: 165; Percent complete: 4.1%; Average loss: 4.1354
# Iteration: 166; Percent complete: 4.2%; Average loss: 4.2412
# Iteration: 167; Percent complete: 4.2%; Average loss: 4.0938
# Iteration: 168; Percent complete: 4.2%; Average loss: 4.2741
# Iteration: 169; Percent complete: 4.2%; Average loss: 4.1467
# Iteration: 170; Percent complete: 4.2%; Average loss: 4.2566
# Iteration: 171; Percent complete: 4.3%; Average loss: 4.3729
# Iteration: 172; Percent complete: 4.3%; Average loss: 4.4346
# Iteration: 173; Percent complete: 4.3%; Average loss: 4.2305
# Iteration: 174; Percent complete: 4.3%; Average loss: 4.2929
# Iteration: 175; Percent complete: 4.4%; Average loss: 4.2828
# Iteration: 176; Percent complete: 4.4%; Average loss: 4.2655
# Iteration: 177; Percent complete: 4.4%; Average loss: 3.9882
# Iteration: 178; Percent complete: 4.5%; Average loss: 4.1628
# Iteration: 179; Percent complete: 4.5%; Average loss: 4.2629
# Iteration: 180; Percent complete: 4.5%; Average loss: 4.2180
# Iteration: 181; Percent complete: 4.5%; Average loss: 4.3513
# Iteration: 182; Percent complete: 4.5%; Average loss: 4.2558
# Iteration: 183; Percent complete: 4.6%; Average loss: 4.3034
# Iteration: 184; Percent complete: 4.6%; Average loss: 4.1802
# Iteration: 185; Percent complete: 4.6%; Average loss: 4.2266
# Iteration: 186; Percent complete: 4.7%; Average loss: 4.0648
# Iteration: 187; Percent complete: 4.7%; Average loss: 4.4287
# Iteration: 188; Percent complete: 4.7%; Average loss: 4.2050
# Iteration: 189; Percent complete: 4.7%; Average loss: 4.1293
# Iteration: 190; Percent complete: 4.8%; Average loss: 4.1383
# Iteration: 191; Percent complete: 4.8%; Average loss: 4.3649
# Iteration: 192; Percent complete: 4.8%; Average loss: 3.9943
# Iteration: 193; Percent complete: 4.8%; Average loss: 3.8064
# Iteration: 194; Percent complete: 4.9%; Average loss: 4.4035
# Iteration: 195; Percent complete: 4.9%; Average loss: 4.2117
# Iteration: 196; Percent complete: 4.9%; Average loss: 4.2325
# Iteration: 197; Percent complete: 4.9%; Average loss: 4.3428
# Iteration: 198; Percent complete: 5.0%; Average loss: 4.0650
# Iteration: 199; Percent complete: 5.0%; Average loss: 4.2667
# Iteration: 200; Percent complete: 5.0%; Average loss: 4.1266
# Iteration: 201; Percent complete: 5.0%; Average loss: 4.2346
# Iteration: 202; Percent complete: 5.1%; Average loss: 4.4743
# Iteration: 203; Percent complete: 5.1%; Average loss: 4.1233
# Iteration: 204; Percent complete: 5.1%; Average loss: 4.0463
# Iteration: 205; Percent complete: 5.1%; Average loss: 4.5162
# Iteration: 206; Percent complete: 5.1%; Average loss: 4.1675
# Iteration: 207; Percent complete: 5.2%; Average loss: 4.1682
# Iteration: 208; Percent complete: 5.2%; Average loss: 4.1938
# Iteration: 209; Percent complete: 5.2%; Average loss: 4.1542
# Iteration: 210; Percent complete: 5.2%; Average loss: 4.1679
# Iteration: 211; Percent complete: 5.3%; Average loss: 3.9706
# Iteration: 212; Percent complete: 5.3%; Average loss: 4.1192
# Iteration: 213; Percent complete: 5.3%; Average loss: 4.1619
# Iteration: 214; Percent complete: 5.3%; Average loss: 4.3708
# Iteration: 215; Percent complete: 5.4%; Average loss: 3.8969
# Iteration: 216; Percent complete: 5.4%; Average loss: 3.9942
# Iteration: 217; Percent complete: 5.4%; Average loss: 4.0690
# Iteration: 218; Percent complete: 5.5%; Average loss: 4.0379
# Iteration: 219; Percent complete: 5.5%; Average loss: 3.7794
# Iteration: 220; Percent complete: 5.5%; Average loss: 3.9503
# Iteration: 221; Percent complete: 5.5%; Average loss: 4.2277
# Iteration: 222; Percent complete: 5.5%; Average loss: 4.0132
# Iteration: 223; Percent complete: 5.6%; Average loss: 4.0043
# Iteration: 224; Percent complete: 5.6%; Average loss: 4.1142
# Iteration: 225; Percent complete: 5.6%; Average loss: 3.9187
# Iteration: 226; Percent complete: 5.7%; Average loss: 3.9778
# Iteration: 227; Percent complete: 5.7%; Average loss: 4.1426
# Iteration: 228; Percent complete: 5.7%; Average loss: 4.4586
# Iteration: 229; Percent complete: 5.7%; Average loss: 4.0728
# Iteration: 230; Percent complete: 5.8%; Average loss: 4.3260
# Iteration: 231; Percent complete: 5.8%; Average loss: 4.2177
# Iteration: 232; Percent complete: 5.8%; Average loss: 4.0634
# Iteration: 233; Percent complete: 5.8%; Average loss: 4.3210
# Iteration: 234; Percent complete: 5.9%; Average loss: 4.0496
# Iteration: 235; Percent complete: 5.9%; Average loss: 4.3434
# Iteration: 236; Percent complete: 5.9%; Average loss: 4.3809
# Iteration: 237; Percent complete: 5.9%; Average loss: 4.1675
# Iteration: 238; Percent complete: 5.9%; Average loss: 4.1776
# Iteration: 239; Percent complete: 6.0%; Average loss: 4.1970
# Iteration: 240; Percent complete: 6.0%; Average loss: 4.3943
# Iteration: 241; Percent complete: 6.0%; Average loss: 3.9122
# Iteration: 242; Percent complete: 6.0%; Average loss: 3.9853
# Iteration: 243; Percent complete: 6.1%; Average loss: 3.7799
# Iteration: 244; Percent complete: 6.1%; Average loss: 3.9691
# Iteration: 245; Percent complete: 6.1%; Average loss: 4.1135
# Iteration: 246; Percent complete: 6.2%; Average loss: 4.3793
# Iteration: 247; Percent complete: 6.2%; Average loss: 4.1114
# Iteration: 248; Percent complete: 6.2%; Average loss: 4.1676
# Iteration: 249; Percent complete: 6.2%; Average loss: 4.1006
# Iteration: 250; Percent complete: 6.2%; Average loss: 3.9406
# Iteration: 251; Percent complete: 6.3%; Average loss: 3.9628
# Iteration: 252; Percent complete: 6.3%; Average loss: 4.1875
# Iteration: 253; Percent complete: 6.3%; Average loss: 4.0866
# Iteration: 254; Percent complete: 6.3%; Average loss: 4.0152
# Iteration: 255; Percent complete: 6.4%; Average loss: 4.1034
# Iteration: 256; Percent complete: 6.4%; Average loss: 3.9105
# Iteration: 257; Percent complete: 6.4%; Average loss: 4.1406
# Iteration: 258; Percent complete: 6.5%; Average loss: 4.1895
# Iteration: 259; Percent complete: 6.5%; Average loss: 3.9923
# Iteration: 260; Percent complete: 6.5%; Average loss: 4.0809
# Iteration: 261; Percent complete: 6.5%; Average loss: 3.8694
# Iteration: 262; Percent complete: 6.6%; Average loss: 4.1812
# Iteration: 263; Percent complete: 6.6%; Average loss: 4.0354
# Iteration: 264; Percent complete: 6.6%; Average loss: 4.1131
# Iteration: 265; Percent complete: 6.6%; Average loss: 3.9251
# Iteration: 266; Percent complete: 6.7%; Average loss: 3.8335
# Iteration: 267; Percent complete: 6.7%; Average loss: 3.9457
# Iteration: 268; Percent complete: 6.7%; Average loss: 4.3141
# Iteration: 269; Percent complete: 6.7%; Average loss: 4.0882
# Iteration: 270; Percent complete: 6.8%; Average loss: 3.8018
# Iteration: 271; Percent complete: 6.8%; Average loss: 3.9043
# Iteration: 272; Percent complete: 6.8%; Average loss: 4.0164
# Iteration: 273; Percent complete: 6.8%; Average loss: 3.9193
# Iteration: 274; Percent complete: 6.9%; Average loss: 4.0127
# Iteration: 275; Percent complete: 6.9%; Average loss: 3.9002
# Iteration: 276; Percent complete: 6.9%; Average loss: 4.3062
# Iteration: 277; Percent complete: 6.9%; Average loss: 4.1965
# Iteration: 278; Percent complete: 7.0%; Average loss: 4.2599
# Iteration: 279; Percent complete: 7.0%; Average loss: 4.1046
# Iteration: 280; Percent complete: 7.0%; Average loss: 3.9142
# Iteration: 281; Percent complete: 7.0%; Average loss: 4.1671
# Iteration: 282; Percent complete: 7.0%; Average loss: 4.0451
# Iteration: 283; Percent complete: 7.1%; Average loss: 4.0137
# Iteration: 284; Percent complete: 7.1%; Average loss: 4.2902
# Iteration: 285; Percent complete: 7.1%; Average loss: 3.9656
# Iteration: 286; Percent complete: 7.1%; Average loss: 4.1150
# Iteration: 287; Percent complete: 7.2%; Average loss: 3.9700
# Iteration: 288; Percent complete: 7.2%; Average loss: 3.9793
# Iteration: 289; Percent complete: 7.2%; Average loss: 3.6506
# Iteration: 290; Percent complete: 7.2%; Average loss: 3.8788
# Iteration: 291; Percent complete: 7.3%; Average loss: 3.9003
# Iteration: 292; Percent complete: 7.3%; Average loss: 4.0427
# Iteration: 293; Percent complete: 7.3%; Average loss: 3.8056
# Iteration: 294; Percent complete: 7.3%; Average loss: 4.0270
# Iteration: 295; Percent complete: 7.4%; Average loss: 4.0642
# Iteration: 296; Percent complete: 7.4%; Average loss: 4.0051
# Iteration: 297; Percent complete: 7.4%; Average loss: 4.1748
# Iteration: 298; Percent complete: 7.4%; Average loss: 3.9989
# Iteration: 299; Percent complete: 7.5%; Average loss: 4.0973
# Iteration: 300; Percent complete: 7.5%; Average loss: 3.7523
# Iteration: 301; Percent complete: 7.5%; Average loss: 3.9445
# Iteration: 302; Percent complete: 7.5%; Average loss: 4.0287
# Iteration: 303; Percent complete: 7.6%; Average loss: 3.9976
# Iteration: 304; Percent complete: 7.6%; Average loss: 3.6651
# Iteration: 305; Percent complete: 7.6%; Average loss: 3.9197
# Iteration: 306; Percent complete: 7.6%; Average loss: 3.8905
# Iteration: 307; Percent complete: 7.7%; Average loss: 3.9308
# Iteration: 308; Percent complete: 7.7%; Average loss: 4.0827
# Iteration: 309; Percent complete: 7.7%; Average loss: 3.8209
# Iteration: 310; Percent complete: 7.8%; Average loss: 3.6830
# Iteration: 311; Percent complete: 7.8%; Average loss: 3.8830
# Iteration: 312; Percent complete: 7.8%; Average loss: 3.9974
# Iteration: 313; Percent complete: 7.8%; Average loss: 3.7908
# Iteration: 314; Percent complete: 7.8%; Average loss: 4.0189
# Iteration: 315; Percent complete: 7.9%; Average loss: 4.2061
# Iteration: 316; Percent complete: 7.9%; Average loss: 3.9102
# Iteration: 317; Percent complete: 7.9%; Average loss: 3.9331
# Iteration: 318; Percent complete: 8.0%; Average loss: 3.8336
# Iteration: 319; Percent complete: 8.0%; Average loss: 3.8227
# Iteration: 320; Percent complete: 8.0%; Average loss: 3.8780
# Iteration: 321; Percent complete: 8.0%; Average loss: 3.9127
# Iteration: 322; Percent complete: 8.1%; Average loss: 3.9282
# Iteration: 323; Percent complete: 8.1%; Average loss: 3.8105
# Iteration: 324; Percent complete: 8.1%; Average loss: 3.8727
# Iteration: 325; Percent complete: 8.1%; Average loss: 4.0783
# Iteration: 326; Percent complete: 8.2%; Average loss: 3.7139
# Iteration: 327; Percent complete: 8.2%; Average loss: 4.1908
# Iteration: 328; Percent complete: 8.2%; Average loss: 3.7457
# Iteration: 329; Percent complete: 8.2%; Average loss: 3.9106
# Iteration: 330; Percent complete: 8.2%; Average loss: 3.9078
# Iteration: 331; Percent complete: 8.3%; Average loss: 4.2330
# Iteration: 332; Percent complete: 8.3%; Average loss: 3.9443
# Iteration: 333; Percent complete: 8.3%; Average loss: 3.8454
# Iteration: 334; Percent complete: 8.3%; Average loss: 3.8408
# Iteration: 335; Percent complete: 8.4%; Average loss: 3.8517
# Iteration: 336; Percent complete: 8.4%; Average loss: 4.2895
# Iteration: 337; Percent complete: 8.4%; Average loss: 3.8588
# Iteration: 338; Percent complete: 8.5%; Average loss: 3.9392
# Iteration: 339; Percent complete: 8.5%; Average loss: 3.8337
# Iteration: 340; Percent complete: 8.5%; Average loss: 3.8245
# Iteration: 341; Percent complete: 8.5%; Average loss: 3.7883
# Iteration: 342; Percent complete: 8.6%; Average loss: 3.9415
# Iteration: 343; Percent complete: 8.6%; Average loss: 3.7955
# Iteration: 344; Percent complete: 8.6%; Average loss: 4.0101
# Iteration: 345; Percent complete: 8.6%; Average loss: 3.9908
# Iteration: 346; Percent complete: 8.6%; Average loss: 3.9526
# Iteration: 347; Percent complete: 8.7%; Average loss: 3.9451
# Iteration: 348; Percent complete: 8.7%; Average loss: 3.9909
# Iteration: 349; Percent complete: 8.7%; Average loss: 3.7488
# Iteration: 350; Percent complete: 8.8%; Average loss: 3.9153
# Iteration: 351; Percent complete: 8.8%; Average loss: 3.9223
# Iteration: 352; Percent complete: 8.8%; Average loss: 3.6731
# Iteration: 353; Percent complete: 8.8%; Average loss: 3.8000
# Iteration: 354; Percent complete: 8.8%; Average loss: 3.7698
# Iteration: 355; Percent complete: 8.9%; Average loss: 3.8848
# Iteration: 356; Percent complete: 8.9%; Average loss: 3.9644
# Iteration: 357; Percent complete: 8.9%; Average loss: 3.9402
# Iteration: 358; Percent complete: 8.9%; Average loss: 4.0083
# Iteration: 359; Percent complete: 9.0%; Average loss: 4.0579
# Iteration: 360; Percent complete: 9.0%; Average loss: 4.0939
# Iteration: 361; Percent complete: 9.0%; Average loss: 4.0300
# Iteration: 362; Percent complete: 9.0%; Average loss: 3.9971
# Iteration: 363; Percent complete: 9.1%; Average loss: 3.8648
# Iteration: 364; Percent complete: 9.1%; Average loss: 3.9745
# Iteration: 365; Percent complete: 9.1%; Average loss: 3.5287
# Iteration: 366; Percent complete: 9.2%; Average loss: 3.7398
# Iteration: 367; Percent complete: 9.2%; Average loss: 3.8220
# Iteration: 368; Percent complete: 9.2%; Average loss: 3.8253
# Iteration: 369; Percent complete: 9.2%; Average loss: 3.7940
# Iteration: 370; Percent complete: 9.2%; Average loss: 3.9296
# Iteration: 371; Percent complete: 9.3%; Average loss: 3.9343
# Iteration: 372; Percent complete: 9.3%; Average loss: 4.0861
# Iteration: 373; Percent complete: 9.3%; Average loss: 3.5191
# Iteration: 374; Percent complete: 9.3%; Average loss: 3.6836
# Iteration: 375; Percent complete: 9.4%; Average loss: 3.9147
# Iteration: 376; Percent complete: 9.4%; Average loss: 3.8841
# Iteration: 377; Percent complete: 9.4%; Average loss: 3.8538
# Iteration: 378; Percent complete: 9.4%; Average loss: 3.8211
# Iteration: 379; Percent complete: 9.5%; Average loss: 3.5551
# Iteration: 380; Percent complete: 9.5%; Average loss: 4.0319
# Iteration: 381; Percent complete: 9.5%; Average loss: 3.9338
# Iteration: 382; Percent complete: 9.6%; Average loss: 4.0639
# Iteration: 383; Percent complete: 9.6%; Average loss: 3.6679
# Iteration: 384; Percent complete: 9.6%; Average loss: 3.9747
# Iteration: 385; Percent complete: 9.6%; Average loss: 3.8077
# Iteration: 386; Percent complete: 9.7%; Average loss: 3.9452
# Iteration: 387; Percent complete: 9.7%; Average loss: 3.5842
# Iteration: 388; Percent complete: 9.7%; Average loss: 3.6917
# Iteration: 389; Percent complete: 9.7%; Average loss: 3.8190
# Iteration: 390; Percent complete: 9.8%; Average loss: 3.7440
# Iteration: 391; Percent complete: 9.8%; Average loss: 3.6617
# Iteration: 392; Percent complete: 9.8%; Average loss: 3.7505
# Iteration: 393; Percent complete: 9.8%; Average loss: 3.6807
# Iteration: 394; Percent complete: 9.8%; Average loss: 4.1072
# Iteration: 395; Percent complete: 9.9%; Average loss: 3.9791
# Iteration: 396; Percent complete: 9.9%; Average loss: 3.7738
# Iteration: 397; Percent complete: 9.9%; Average loss: 4.0377
# Iteration: 398; Percent complete: 10.0%; Average loss: 4.0593
# Iteration: 399; Percent complete: 10.0%; Average loss: 3.9978
# Iteration: 400; Percent complete: 10.0%; Average loss: 3.7941
# Iteration: 401; Percent complete: 10.0%; Average loss: 4.0198
# Iteration: 402; Percent complete: 10.1%; Average loss: 3.6834
# Iteration: 403; Percent complete: 10.1%; Average loss: 3.8947
# Iteration: 404; Percent complete: 10.1%; Average loss: 4.1955
# Iteration: 405; Percent complete: 10.1%; Average loss: 3.6390
# Iteration: 406; Percent complete: 10.2%; Average loss: 3.8785
# Iteration: 407; Percent complete: 10.2%; Average loss: 3.8692
# Iteration: 408; Percent complete: 10.2%; Average loss: 3.8817
# Iteration: 409; Percent complete: 10.2%; Average loss: 3.6613
# Iteration: 410; Percent complete: 10.2%; Average loss: 3.6988
# Iteration: 411; Percent complete: 10.3%; Average loss: 3.7536
# Iteration: 412; Percent complete: 10.3%; Average loss: 3.8832
# Iteration: 413; Percent complete: 10.3%; Average loss: 3.6908
# Iteration: 414; Percent complete: 10.3%; Average loss: 3.9006
# Iteration: 415; Percent complete: 10.4%; Average loss: 3.9648
# Iteration: 416; Percent complete: 10.4%; Average loss: 3.9307
# Iteration: 417; Percent complete: 10.4%; Average loss: 3.6235
# Iteration: 418; Percent complete: 10.4%; Average loss: 3.8305
# Iteration: 419; Percent complete: 10.5%; Average loss: 4.0286
# Iteration: 420; Percent complete: 10.5%; Average loss: 3.9731
# Iteration: 421; Percent complete: 10.5%; Average loss: 3.6842
# Iteration: 422; Percent complete: 10.5%; Average loss: 4.1065
# Iteration: 423; Percent complete: 10.6%; Average loss: 4.1195
# Iteration: 424; Percent complete: 10.6%; Average loss: 3.9605
# Iteration: 425; Percent complete: 10.6%; Average loss: 4.0594
# Iteration: 426; Percent complete: 10.7%; Average loss: 3.6407
# Iteration: 427; Percent complete: 10.7%; Average loss: 3.9995
# Iteration: 428; Percent complete: 10.7%; Average loss: 3.9718
# Iteration: 429; Percent complete: 10.7%; Average loss: 3.8146
# Iteration: 430; Percent complete: 10.8%; Average loss: 3.6935
# Iteration: 431; Percent complete: 10.8%; Average loss: 3.7791
# Iteration: 432; Percent complete: 10.8%; Average loss: 3.9999
# Iteration: 433; Percent complete: 10.8%; Average loss: 3.7253
# Iteration: 434; Percent complete: 10.8%; Average loss: 4.0518
# Iteration: 435; Percent complete: 10.9%; Average loss: 3.8258
# Iteration: 436; Percent complete: 10.9%; Average loss: 3.6176
# Iteration: 437; Percent complete: 10.9%; Average loss: 3.7263
# Iteration: 438; Percent complete: 10.9%; Average loss: 4.0138
# Iteration: 439; Percent complete: 11.0%; Average loss: 3.9847
# Iteration: 440; Percent complete: 11.0%; Average loss: 3.8448
# Iteration: 441; Percent complete: 11.0%; Average loss: 3.7374
# Iteration: 442; Percent complete: 11.1%; Average loss: 3.9139
# Iteration: 443; Percent complete: 11.1%; Average loss: 3.8691
# Iteration: 444; Percent complete: 11.1%; Average loss: 3.8324
# Iteration: 445; Percent complete: 11.1%; Average loss: 4.0375
# Iteration: 446; Percent complete: 11.2%; Average loss: 3.9366
# Iteration: 447; Percent complete: 11.2%; Average loss: 3.9160
# Iteration: 448; Percent complete: 11.2%; Average loss: 3.9451
# Iteration: 449; Percent complete: 11.2%; Average loss: 4.0191
# Iteration: 450; Percent complete: 11.2%; Average loss: 3.9928
# Iteration: 451; Percent complete: 11.3%; Average loss: 3.8976
# Iteration: 452; Percent complete: 11.3%; Average loss: 4.1038
# Iteration: 453; Percent complete: 11.3%; Average loss: 3.9000
# Iteration: 454; Percent complete: 11.3%; Average loss: 3.7632
# Iteration: 455; Percent complete: 11.4%; Average loss: 3.7504
# Iteration: 456; Percent complete: 11.4%; Average loss: 3.7945
# Iteration: 457; Percent complete: 11.4%; Average loss: 3.7094
# Iteration: 458; Percent complete: 11.5%; Average loss: 3.8156
# Iteration: 459; Percent complete: 11.5%; Average loss: 4.0013
# Iteration: 460; Percent complete: 11.5%; Average loss: 3.8129
# Iteration: 461; Percent complete: 11.5%; Average loss: 3.5475
# Iteration: 462; Percent complete: 11.6%; Average loss: 3.8714
# Iteration: 463; Percent complete: 11.6%; Average loss: 3.7337
# Iteration: 464; Percent complete: 11.6%; Average loss: 3.9030
# Iteration: 465; Percent complete: 11.6%; Average loss: 3.6434
# Iteration: 466; Percent complete: 11.7%; Average loss: 3.9022
# Iteration: 467; Percent complete: 11.7%; Average loss: 3.5722
# Iteration: 468; Percent complete: 11.7%; Average loss: 3.9739
# Iteration: 469; Percent complete: 11.7%; Average loss: 3.9036
# Iteration: 470; Percent complete: 11.8%; Average loss: 3.7663
# Iteration: 471; Percent complete: 11.8%; Average loss: 3.7052
# Iteration: 472; Percent complete: 11.8%; Average loss: 3.7502
# Iteration: 473; Percent complete: 11.8%; Average loss: 3.8623
# Iteration: 474; Percent complete: 11.8%; Average loss: 3.5915
# Iteration: 475; Percent complete: 11.9%; Average loss: 3.6501
# Iteration: 476; Percent complete: 11.9%; Average loss: 3.7270
# Iteration: 477; Percent complete: 11.9%; Average loss: 3.7245
# Iteration: 478; Percent complete: 11.9%; Average loss: 3.7031
# Iteration: 479; Percent complete: 12.0%; Average loss: 3.9467
# Iteration: 480; Percent complete: 12.0%; Average loss: 3.7652
# Iteration: 481; Percent complete: 12.0%; Average loss: 3.6675
# Iteration: 482; Percent complete: 12.0%; Average loss: 3.7218
# Iteration: 483; Percent complete: 12.1%; Average loss: 3.8929
# Iteration: 484; Percent complete: 12.1%; Average loss: 3.7585
# Iteration: 485; Percent complete: 12.1%; Average loss: 3.7229
# Iteration: 486; Percent complete: 12.2%; Average loss: 3.8604
# Iteration: 487; Percent complete: 12.2%; Average loss: 3.7787
# Iteration: 488; Percent complete: 12.2%; Average loss: 3.6637
# Iteration: 489; Percent complete: 12.2%; Average loss: 3.9511
# Iteration: 490; Percent complete: 12.2%; Average loss: 3.9222
# Iteration: 491; Percent complete: 12.3%; Average loss: 3.7453
# Iteration: 492; Percent complete: 12.3%; Average loss: 3.6278
# Iteration: 493; Percent complete: 12.3%; Average loss: 3.6408
# Iteration: 494; Percent complete: 12.3%; Average loss: 4.0551
# Iteration: 495; Percent complete: 12.4%; Average loss: 3.5956
# Iteration: 496; Percent complete: 12.4%; Average loss: 3.6622
# Iteration: 497; Percent complete: 12.4%; Average loss: 3.8647
# Iteration: 498; Percent complete: 12.4%; Average loss: 3.8082
# Iteration: 499; Percent complete: 12.5%; Average loss: 3.8029
# Iteration: 500; Percent complete: 12.5%; Average loss: 3.7139
# Iteration: 501; Percent complete: 12.5%; Average loss: 3.8449
# Iteration: 502; Percent complete: 12.6%; Average loss: 3.6839
# Iteration: 503; Percent complete: 12.6%; Average loss: 3.8760
# Iteration: 504; Percent complete: 12.6%; Average loss: 3.7046
# Iteration: 505; Percent complete: 12.6%; Average loss: 3.6623
# Iteration: 506; Percent complete: 12.7%; Average loss: 4.0014
# Iteration: 507; Percent complete: 12.7%; Average loss: 3.7238
# Iteration: 508; Percent complete: 12.7%; Average loss: 4.1113
# Iteration: 509; Percent complete: 12.7%; Average loss: 3.7878
# Iteration: 510; Percent complete: 12.8%; Average loss: 3.7957
# Iteration: 511; Percent complete: 12.8%; Average loss: 3.7076
# Iteration: 512; Percent complete: 12.8%; Average loss: 3.7167
# Iteration: 513; Percent complete: 12.8%; Average loss: 3.7300
# Iteration: 514; Percent complete: 12.8%; Average loss: 3.5842
# Iteration: 515; Percent complete: 12.9%; Average loss: 3.7699
# Iteration: 516; Percent complete: 12.9%; Average loss: 3.7126
# Iteration: 517; Percent complete: 12.9%; Average loss: 3.6255
# Iteration: 518; Percent complete: 13.0%; Average loss: 3.9056
# Iteration: 519; Percent complete: 13.0%; Average loss: 3.8196
# Iteration: 520; Percent complete: 13.0%; Average loss: 3.7182
# Iteration: 521; Percent complete: 13.0%; Average loss: 3.7011
# Iteration: 522; Percent complete: 13.1%; Average loss: 3.5938
# Iteration: 523; Percent complete: 13.1%; Average loss: 3.7767
# Iteration: 524; Percent complete: 13.1%; Average loss: 3.4977
# Iteration: 525; Percent complete: 13.1%; Average loss: 3.8871
# Iteration: 526; Percent complete: 13.2%; Average loss: 3.3998
# Iteration: 527; Percent complete: 13.2%; Average loss: 3.9188
# Iteration: 528; Percent complete: 13.2%; Average loss: 3.8521
# Iteration: 529; Percent complete: 13.2%; Average loss: 3.7863
# Iteration: 530; Percent complete: 13.2%; Average loss: 3.6665
# Iteration: 531; Percent complete: 13.3%; Average loss: 3.6363
# Iteration: 532; Percent complete: 13.3%; Average loss: 3.6981
# Iteration: 533; Percent complete: 13.3%; Average loss: 3.7412
# Iteration: 534; Percent complete: 13.4%; Average loss: 3.6993
# Iteration: 535; Percent complete: 13.4%; Average loss: 3.8387
# Iteration: 536; Percent complete: 13.4%; Average loss: 3.8462
# Iteration: 537; Percent complete: 13.4%; Average loss: 3.7383
# Iteration: 538; Percent complete: 13.5%; Average loss: 3.8689
# Iteration: 539; Percent complete: 13.5%; Average loss: 3.8346
# Iteration: 540; Percent complete: 13.5%; Average loss: 3.8857
# Iteration: 541; Percent complete: 13.5%; Average loss: 4.0296
# Iteration: 542; Percent complete: 13.6%; Average loss: 3.7147
# Iteration: 543; Percent complete: 13.6%; Average loss: 3.5316
# Iteration: 544; Percent complete: 13.6%; Average loss: 3.6944
# Iteration: 545; Percent complete: 13.6%; Average loss: 3.7697
# Iteration: 546; Percent complete: 13.7%; Average loss: 3.7041
# Iteration: 547; Percent complete: 13.7%; Average loss: 3.7125
# Iteration: 548; Percent complete: 13.7%; Average loss: 3.9259
# Iteration: 549; Percent complete: 13.7%; Average loss: 3.8512
# Iteration: 550; Percent complete: 13.8%; Average loss: 3.6932
# Iteration: 551; Percent complete: 13.8%; Average loss: 3.6216
# Iteration: 552; Percent complete: 13.8%; Average loss: 3.5813
# Iteration: 553; Percent complete: 13.8%; Average loss: 3.7873
# Iteration: 554; Percent complete: 13.9%; Average loss: 4.0846
# Iteration: 555; Percent complete: 13.9%; Average loss: 3.9095
# Iteration: 556; Percent complete: 13.9%; Average loss: 3.7074
# Iteration: 557; Percent complete: 13.9%; Average loss: 3.6834
# Iteration: 558; Percent complete: 14.0%; Average loss: 3.8026
# Iteration: 559; Percent complete: 14.0%; Average loss: 3.9762
# Iteration: 560; Percent complete: 14.0%; Average loss: 3.6073
# Iteration: 561; Percent complete: 14.0%; Average loss: 3.7081
# Iteration: 562; Percent complete: 14.1%; Average loss: 3.9027
# Iteration: 563; Percent complete: 14.1%; Average loss: 3.3788
# Iteration: 564; Percent complete: 14.1%; Average loss: 3.8675
# Iteration: 565; Percent complete: 14.1%; Average loss: 3.8136
# Iteration: 566; Percent complete: 14.1%; Average loss: 3.4901
# Iteration: 567; Percent complete: 14.2%; Average loss: 3.7737
# Iteration: 568; Percent complete: 14.2%; Average loss: 3.7027
# Iteration: 569; Percent complete: 14.2%; Average loss: 3.8836
# Iteration: 570; Percent complete: 14.2%; Average loss: 3.6010
# Iteration: 571; Percent complete: 14.3%; Average loss: 3.9230
# Iteration: 572; Percent complete: 14.3%; Average loss: 3.4894
# Iteration: 573; Percent complete: 14.3%; Average loss: 3.5728
# Iteration: 574; Percent complete: 14.3%; Average loss: 3.6828
# Iteration: 575; Percent complete: 14.4%; Average loss: 3.5240
# Iteration: 576; Percent complete: 14.4%; Average loss: 3.9759
# Iteration: 577; Percent complete: 14.4%; Average loss: 3.6021
# Iteration: 578; Percent complete: 14.4%; Average loss: 3.7138
# Iteration: 579; Percent complete: 14.5%; Average loss: 3.6527
# Iteration: 580; Percent complete: 14.5%; Average loss: 3.5485
# Iteration: 581; Percent complete: 14.5%; Average loss: 3.8182
# Iteration: 582; Percent complete: 14.5%; Average loss: 3.6710
# Iteration: 583; Percent complete: 14.6%; Average loss: 3.8392
# Iteration: 584; Percent complete: 14.6%; Average loss: 3.5317
# Iteration: 585; Percent complete: 14.6%; Average loss: 3.5496
# Iteration: 586; Percent complete: 14.6%; Average loss: 3.5546
# Iteration: 587; Percent complete: 14.7%; Average loss: 3.6830
# Iteration: 588; Percent complete: 14.7%; Average loss: 3.7666
# Iteration: 589; Percent complete: 14.7%; Average loss: 3.7562
# Iteration: 590; Percent complete: 14.8%; Average loss: 3.4847
# Iteration: 591; Percent complete: 14.8%; Average loss: 3.8553
# Iteration: 592; Percent complete: 14.8%; Average loss: 3.9041
# Iteration: 593; Percent complete: 14.8%; Average loss: 3.9070
# Iteration: 594; Percent complete: 14.8%; Average loss: 3.5663
# Iteration: 595; Percent complete: 14.9%; Average loss: 3.9689
# Iteration: 596; Percent complete: 14.9%; Average loss: 3.6262
# Iteration: 597; Percent complete: 14.9%; Average loss: 3.5844
# Iteration: 598; Percent complete: 14.9%; Average loss: 3.7163
# Iteration: 599; Percent complete: 15.0%; Average loss: 3.8040
# Iteration: 600; Percent complete: 15.0%; Average loss: 3.8897
# Iteration: 601; Percent complete: 15.0%; Average loss: 3.6478
# Iteration: 602; Percent complete: 15.0%; Average loss: 3.7107
# Iteration: 603; Percent complete: 15.1%; Average loss: 3.6116
# Iteration: 604; Percent complete: 15.1%; Average loss: 3.6625
# Iteration: 605; Percent complete: 15.1%; Average loss: 3.8272
# Iteration: 606; Percent complete: 15.2%; Average loss: 3.6567
# Iteration: 607; Percent complete: 15.2%; Average loss: 3.5999
# Iteration: 608; Percent complete: 15.2%; Average loss: 3.6875
# Iteration: 609; Percent complete: 15.2%; Average loss: 3.9536
# Iteration: 610; Percent complete: 15.2%; Average loss: 3.6553
# Iteration: 611; Percent complete: 15.3%; Average loss: 3.4143
# Iteration: 612; Percent complete: 15.3%; Average loss: 3.9630
# Iteration: 613; Percent complete: 15.3%; Average loss: 3.6959
# Iteration: 614; Percent complete: 15.3%; Average loss: 3.7093
# Iteration: 615; Percent complete: 15.4%; Average loss: 3.7422
# Iteration: 616; Percent complete: 15.4%; Average loss: 3.8026
# Iteration: 617; Percent complete: 15.4%; Average loss: 3.7738
# Iteration: 618; Percent complete: 15.4%; Average loss: 3.7915
# Iteration: 619; Percent complete: 15.5%; Average loss: 3.6281
# Iteration: 620; Percent complete: 15.5%; Average loss: 3.7034
# Iteration: 621; Percent complete: 15.5%; Average loss: 3.8172
# Iteration: 622; Percent complete: 15.6%; Average loss: 3.5517
# Iteration: 623; Percent complete: 15.6%; Average loss: 3.5791
# Iteration: 624; Percent complete: 15.6%; Average loss: 3.7875
# Iteration: 625; Percent complete: 15.6%; Average loss: 4.0972
# Iteration: 626; Percent complete: 15.7%; Average loss: 3.9957
# Iteration: 627; Percent complete: 15.7%; Average loss: 3.5237
# Iteration: 628; Percent complete: 15.7%; Average loss: 3.5561
# Iteration: 629; Percent complete: 15.7%; Average loss: 3.6763
# Iteration: 630; Percent complete: 15.8%; Average loss: 3.8009
# Iteration: 631; Percent complete: 15.8%; Average loss: 3.5615
# Iteration: 632; Percent complete: 15.8%; Average loss: 3.6511
# Iteration: 633; Percent complete: 15.8%; Average loss: 3.6545
# Iteration: 634; Percent complete: 15.8%; Average loss: 3.6914
# Iteration: 635; Percent complete: 15.9%; Average loss: 3.6253
# Iteration: 636; Percent complete: 15.9%; Average loss: 3.8207
# Iteration: 637; Percent complete: 15.9%; Average loss: 3.5633
# Iteration: 638; Percent complete: 16.0%; Average loss: 3.3542
# Iteration: 639; Percent complete: 16.0%; Average loss: 3.7267
# Iteration: 640; Percent complete: 16.0%; Average loss: 3.7860
# Iteration: 641; Percent complete: 16.0%; Average loss: 3.5838
# Iteration: 642; Percent complete: 16.1%; Average loss: 3.8834
# Iteration: 643; Percent complete: 16.1%; Average loss: 3.5159
# Iteration: 644; Percent complete: 16.1%; Average loss: 3.6353
# Iteration: 645; Percent complete: 16.1%; Average loss: 3.7421
# Iteration: 646; Percent complete: 16.2%; Average loss: 3.5387
# Iteration: 647; Percent complete: 16.2%; Average loss: 3.6448
# Iteration: 648; Percent complete: 16.2%; Average loss: 3.3850
# Iteration: 649; Percent complete: 16.2%; Average loss: 3.9199
# Iteration: 650; Percent complete: 16.2%; Average loss: 3.9397
# Iteration: 651; Percent complete: 16.3%; Average loss: 3.4006
# Iteration: 652; Percent complete: 16.3%; Average loss: 3.5755
# Iteration: 653; Percent complete: 16.3%; Average loss: 3.6279
# Iteration: 654; Percent complete: 16.4%; Average loss: 3.6949
# Iteration: 655; Percent complete: 16.4%; Average loss: 3.5250
# Iteration: 656; Percent complete: 16.4%; Average loss: 3.7225
# Iteration: 657; Percent complete: 16.4%; Average loss: 3.6747
# Iteration: 658; Percent complete: 16.4%; Average loss: 3.7577
# Iteration: 659; Percent complete: 16.5%; Average loss: 3.6535
# Iteration: 660; Percent complete: 16.5%; Average loss: 3.5859
# Iteration: 661; Percent complete: 16.5%; Average loss: 3.3426
# Iteration: 662; Percent complete: 16.6%; Average loss: 3.6716
# Iteration: 663; Percent complete: 16.6%; Average loss: 3.7217
# Iteration: 664; Percent complete: 16.6%; Average loss: 3.7126
# Iteration: 665; Percent complete: 16.6%; Average loss: 3.6096
# Iteration: 666; Percent complete: 16.7%; Average loss: 3.7926
# Iteration: 667; Percent complete: 16.7%; Average loss: 3.7434
# Iteration: 668; Percent complete: 16.7%; Average loss: 3.7478
# Iteration: 669; Percent complete: 16.7%; Average loss: 3.5840
# Iteration: 670; Percent complete: 16.8%; Average loss: 3.3651
# Iteration: 671; Percent complete: 16.8%; Average loss: 3.7844
# Iteration: 672; Percent complete: 16.8%; Average loss: 3.6740
# Iteration: 673; Percent complete: 16.8%; Average loss: 3.7526
# Iteration: 674; Percent complete: 16.9%; Average loss: 4.0523
# Iteration: 675; Percent complete: 16.9%; Average loss: 3.4940
# Iteration: 676; Percent complete: 16.9%; Average loss: 3.4951
# Iteration: 677; Percent complete: 16.9%; Average loss: 3.8954
# Iteration: 678; Percent complete: 17.0%; Average loss: 3.5466
# Iteration: 679; Percent complete: 17.0%; Average loss: 3.8568
# Iteration: 680; Percent complete: 17.0%; Average loss: 3.5705
# Iteration: 681; Percent complete: 17.0%; Average loss: 3.7442
# Iteration: 682; Percent complete: 17.1%; Average loss: 3.7485
# Iteration: 683; Percent complete: 17.1%; Average loss: 3.4340
# Iteration: 684; Percent complete: 17.1%; Average loss: 3.6965
# Iteration: 685; Percent complete: 17.1%; Average loss: 3.8389
# Iteration: 686; Percent complete: 17.2%; Average loss: 3.8128
# Iteration: 687; Percent complete: 17.2%; Average loss: 3.4563
# Iteration: 688; Percent complete: 17.2%; Average loss: 3.7059
# Iteration: 689; Percent complete: 17.2%; Average loss: 3.4207
# Iteration: 690; Percent complete: 17.2%; Average loss: 3.9171
# Iteration: 691; Percent complete: 17.3%; Average loss: 3.8688
# Iteration: 692; Percent complete: 17.3%; Average loss: 3.5921
# Iteration: 693; Percent complete: 17.3%; Average loss: 3.6162
# Iteration: 694; Percent complete: 17.3%; Average loss: 3.6377
# Iteration: 695; Percent complete: 17.4%; Average loss: 3.6822
# Iteration: 696; Percent complete: 17.4%; Average loss: 3.6186
# Iteration: 697; Percent complete: 17.4%; Average loss: 3.5311
# Iteration: 698; Percent complete: 17.4%; Average loss: 3.6293
# Iteration: 699; Percent complete: 17.5%; Average loss: 3.9392
# Iteration: 700; Percent complete: 17.5%; Average loss: 3.5922
# Iteration: 701; Percent complete: 17.5%; Average loss: 3.6564
# Iteration: 702; Percent complete: 17.5%; Average loss: 3.8695
# Iteration: 703; Percent complete: 17.6%; Average loss: 3.4369
# Iteration: 704; Percent complete: 17.6%; Average loss: 3.4906
# Iteration: 705; Percent complete: 17.6%; Average loss: 3.6351
# Iteration: 706; Percent complete: 17.6%; Average loss: 3.6856
# Iteration: 707; Percent complete: 17.7%; Average loss: 4.0055
# Iteration: 708; Percent complete: 17.7%; Average loss: 3.5408
# Iteration: 709; Percent complete: 17.7%; Average loss: 3.8980
# Iteration: 710; Percent complete: 17.8%; Average loss: 3.6779
# Iteration: 711; Percent complete: 17.8%; Average loss: 3.7203
# Iteration: 712; Percent complete: 17.8%; Average loss: 3.6788
# Iteration: 713; Percent complete: 17.8%; Average loss: 3.5066
# Iteration: 714; Percent complete: 17.8%; Average loss: 3.6324
# Iteration: 715; Percent complete: 17.9%; Average loss: 3.6287
# Iteration: 716; Percent complete: 17.9%; Average loss: 3.4290
# Iteration: 717; Percent complete: 17.9%; Average loss: 3.5643
# Iteration: 718; Percent complete: 17.9%; Average loss: 3.4396
# Iteration: 719; Percent complete: 18.0%; Average loss: 3.6660
# Iteration: 720; Percent complete: 18.0%; Average loss: 3.6743
# Iteration: 721; Percent complete: 18.0%; Average loss: 3.8438
# Iteration: 722; Percent complete: 18.1%; Average loss: 3.6927
# Iteration: 723; Percent complete: 18.1%; Average loss: 3.5323
# Iteration: 724; Percent complete: 18.1%; Average loss: 3.7228
# Iteration: 725; Percent complete: 18.1%; Average loss: 3.6533
# Iteration: 726; Percent complete: 18.1%; Average loss: 3.4989
# Iteration: 727; Percent complete: 18.2%; Average loss: 3.5434
# Iteration: 728; Percent complete: 18.2%; Average loss: 3.8505
# Iteration: 729; Percent complete: 18.2%; Average loss: 3.7856
# Iteration: 730; Percent complete: 18.2%; Average loss: 3.6483
# Iteration: 731; Percent complete: 18.3%; Average loss: 3.6059
# Iteration: 732; Percent complete: 18.3%; Average loss: 3.7016
# Iteration: 733; Percent complete: 18.3%; Average loss: 3.7751
# Iteration: 734; Percent complete: 18.4%; Average loss: 3.9463
# Iteration: 735; Percent complete: 18.4%; Average loss: 3.6418
# Iteration: 736; Percent complete: 18.4%; Average loss: 3.5450
# Iteration: 737; Percent complete: 18.4%; Average loss: 3.7480
# Iteration: 738; Percent complete: 18.4%; Average loss: 3.7435
# Iteration: 739; Percent complete: 18.5%; Average loss: 3.7566
# Iteration: 740; Percent complete: 18.5%; Average loss: 3.5295
# Iteration: 741; Percent complete: 18.5%; Average loss: 3.6309
# Iteration: 742; Percent complete: 18.6%; Average loss: 3.7105
# Iteration: 743; Percent complete: 18.6%; Average loss: 3.8016
# Iteration: 744; Percent complete: 18.6%; Average loss: 3.5208
# Iteration: 745; Percent complete: 18.6%; Average loss: 3.4490
# Iteration: 746; Percent complete: 18.6%; Average loss: 3.7679
# Iteration: 747; Percent complete: 18.7%; Average loss: 3.8158
# Iteration: 748; Percent complete: 18.7%; Average loss: 3.9779
# Iteration: 749; Percent complete: 18.7%; Average loss: 3.5167
# Iteration: 750; Percent complete: 18.8%; Average loss: 3.7178
# Iteration: 751; Percent complete: 18.8%; Average loss: 3.6547
# Iteration: 752; Percent complete: 18.8%; Average loss: 3.6984
# Iteration: 753; Percent complete: 18.8%; Average loss: 3.5668
# Iteration: 754; Percent complete: 18.9%; Average loss: 3.5652
# Iteration: 755; Percent complete: 18.9%; Average loss: 3.3879
# Iteration: 756; Percent complete: 18.9%; Average loss: 3.5314
# Iteration: 757; Percent complete: 18.9%; Average loss: 3.6772
# Iteration: 758; Percent complete: 18.9%; Average loss: 3.4744
# Iteration: 759; Percent complete: 19.0%; Average loss: 3.6255
# Iteration: 760; Percent complete: 19.0%; Average loss: 3.7983
# Iteration: 761; Percent complete: 19.0%; Average loss: 3.6993
# Iteration: 762; Percent complete: 19.1%; Average loss: 3.5111
# Iteration: 763; Percent complete: 19.1%; Average loss: 3.8755
# Iteration: 764; Percent complete: 19.1%; Average loss: 3.7828
# Iteration: 765; Percent complete: 19.1%; Average loss: 3.6296
# Iteration: 766; Percent complete: 19.1%; Average loss: 3.6135
# Iteration: 767; Percent complete: 19.2%; Average loss: 3.7417
# Iteration: 768; Percent complete: 19.2%; Average loss: 3.4185
# Iteration: 769; Percent complete: 19.2%; Average loss: 3.6295
# Iteration: 770; Percent complete: 19.2%; Average loss: 3.6689
# Iteration: 771; Percent complete: 19.3%; Average loss: 3.6634
# Iteration: 772; Percent complete: 19.3%; Average loss: 3.7790
# ...
# Iteration: 3748; Percent complete: 93.7%; Average loss: 3.1746
# Iteration: 3749; Percent complete: 93.7%; Average loss: 2.9726
# Iteration: 3750; Percent complete: 93.8%; Average loss: 3.1251
# Iteration: 3751; Percent complete: 93.8%; Average loss: 2.9618
# Iteration: 3752; Percent complete: 93.8%; Average loss: 3.0333
# Iteration: 3753; Percent complete: 93.8%; Average loss: 2.9235
# Iteration: 3754; Percent complete: 93.8%; Average loss: 2.8661
# Iteration: 3755; Percent complete: 93.9%; Average loss: 2.7858
# Iteration: 3756; Percent complete: 93.9%; Average loss: 3.2067
# Iteration: 3757; Percent complete: 93.9%; Average loss: 2.9157
# Iteration: 3758; Percent complete: 94.0%; Average loss: 2.9510
# Iteration: 3759; Percent complete: 94.0%; Average loss: 3.2056
# Iteration: 3760; Percent complete: 94.0%; Average loss: 3.0686
# Iteration: 3761; Percent complete: 94.0%; Average loss: 2.8564
# Iteration: 3762; Percent complete: 94.0%; Average loss: 3.4584
# Iteration: 3763; Percent complete: 94.1%; Average loss: 2.9452
# Iteration: 3764; Percent complete: 94.1%; Average loss: 3.0309
# Iteration: 3765; Percent complete: 94.1%; Average loss: 3.0406
# Iteration: 3766; Percent complete: 94.2%; Average loss: 2.8388
# Iteration: 3767; Percent complete: 94.2%; Average loss: 2.9534
# Iteration: 3768; Percent complete: 94.2%; Average loss: 2.9518
# Iteration: 3769; Percent complete: 94.2%; Average loss: 2.9285
# Iteration: 3770; Percent complete: 94.2%; Average loss: 2.9862
# Iteration: 3771; Percent complete: 94.3%; Average loss: 3.2225
# Iteration: 3772; Percent complete: 94.3%; Average loss: 2.9548
# Iteration: 3773; Percent complete: 94.3%; Average loss: 2.7426
# Iteration: 3774; Percent complete: 94.3%; Average loss: 2.7026
# Iteration: 3775; Percent complete: 94.4%; Average loss: 2.9483
# Iteration: 3776; Percent complete: 94.4%; Average loss: 2.9176
# Iteration: 3777; Percent complete: 94.4%; Average loss: 3.0687
# Iteration: 3778; Percent complete: 94.5%; Average loss: 2.9019
# Iteration: 3779; Percent complete: 94.5%; Average loss: 2.8489
# Iteration: 3780; Percent complete: 94.5%; Average loss: 2.9309
# Iteration: 3781; Percent complete: 94.5%; Average loss: 3.2303
# Iteration: 3782; Percent complete: 94.5%; Average loss: 2.8792
# Iteration: 3783; Percent complete: 94.6%; Average loss: 3.1678
# Iteration: 3784; Percent complete: 94.6%; Average loss: 2.9247
# Iteration: 3785; Percent complete: 94.6%; Average loss: 2.9606
# Iteration: 3786; Percent complete: 94.7%; Average loss: 2.8273
# Iteration: 3787; Percent complete: 94.7%; Average loss: 2.8169
# Iteration: 3788; Percent complete: 94.7%; Average loss: 3.0442
# Iteration: 3789; Percent complete: 94.7%; Average loss: 3.3445
# Iteration: 3790; Percent complete: 94.8%; Average loss: 2.9390
# Iteration: 3791; Percent complete: 94.8%; Average loss: 3.2343
# Iteration: 3792; Percent complete: 94.8%; Average loss: 2.8566
# Iteration: 3793; Percent complete: 94.8%; Average loss: 2.8189
# Iteration: 3794; Percent complete: 94.8%; Average loss: 2.8742
# Iteration: 3795; Percent complete: 94.9%; Average loss: 3.0562
# Iteration: 3796; Percent complete: 94.9%; Average loss: 3.1981
# Iteration: 3797; Percent complete: 94.9%; Average loss: 3.0673
# Iteration: 3798; Percent complete: 95.0%; Average loss: 3.0664
# Iteration: 3799; Percent complete: 95.0%; Average loss: 2.9873
# Iteration: 3800; Percent complete: 95.0%; Average loss: 2.6813
# Iteration: 3801; Percent complete: 95.0%; Average loss: 2.8126
# Iteration: 3802; Percent complete: 95.0%; Average loss: 2.9292
# Iteration: 3803; Percent complete: 95.1%; Average loss: 3.0242
# Iteration: 3804; Percent complete: 95.1%; Average loss: 2.8500
# Iteration: 3805; Percent complete: 95.1%; Average loss: 2.9780
# Iteration: 3806; Percent complete: 95.2%; Average loss: 3.0039
# Iteration: 3807; Percent complete: 95.2%; Average loss: 3.0199
# Iteration: 3808; Percent complete: 95.2%; Average loss: 2.8645
# Iteration: 3809; Percent complete: 95.2%; Average loss: 2.9935
# Iteration: 3810; Percent complete: 95.2%; Average loss: 3.1607
# Iteration: 3811; Percent complete: 95.3%; Average loss: 3.0792
# Iteration: 3812; Percent complete: 95.3%; Average loss: 2.8428
# Iteration: 3813; Percent complete: 95.3%; Average loss: 2.9456
# Iteration: 3814; Percent complete: 95.3%; Average loss: 2.9707
# Iteration: 3815; Percent complete: 95.4%; Average loss: 2.9125
# Iteration: 3816; Percent complete: 95.4%; Average loss: 3.1202
# Iteration: 3817; Percent complete: 95.4%; Average loss: 3.0077
# Iteration: 3818; Percent complete: 95.5%; Average loss: 3.0177
# Iteration: 3819; Percent complete: 95.5%; Average loss: 3.1166
# Iteration: 3820; Percent complete: 95.5%; Average loss: 3.1746
# Iteration: 3821; Percent complete: 95.5%; Average loss: 3.0256
# Iteration: 3822; Percent complete: 95.5%; Average loss: 2.9432
# Iteration: 3823; Percent complete: 95.6%; Average loss: 2.9132
# Iteration: 3824; Percent complete: 95.6%; Average loss: 3.1290
# Iteration: 3825; Percent complete: 95.6%; Average loss: 2.7218
# Iteration: 3826; Percent complete: 95.7%; Average loss: 2.8713
# Iteration: 3827; Percent complete: 95.7%; Average loss: 2.8578
# Iteration: 3828; Percent complete: 95.7%; Average loss: 3.2331
# Iteration: 3829; Percent complete: 95.7%; Average loss: 2.9464
# Iteration: 3830; Percent complete: 95.8%; Average loss: 3.0410
# Iteration: 3831; Percent complete: 95.8%; Average loss: 2.9498
# Iteration: 3832; Percent complete: 95.8%; Average loss: 3.1859
# Iteration: 3833; Percent complete: 95.8%; Average loss: 3.0907
# Iteration: 3834; Percent complete: 95.9%; Average loss: 3.1363
# Iteration: 3835; Percent complete: 95.9%; Average loss: 2.8988
# Iteration: 3836; Percent complete: 95.9%; Average loss: 2.7172
# Iteration: 3837; Percent complete: 95.9%; Average loss: 2.7597
# Iteration: 3838; Percent complete: 96.0%; Average loss: 2.9002
# Iteration: 3839; Percent complete: 96.0%; Average loss: 2.8423
# Iteration: 3840; Percent complete: 96.0%; Average loss: 2.8613
# Iteration: 3841; Percent complete: 96.0%; Average loss: 2.7581
# Iteration: 3842; Percent complete: 96.0%; Average loss: 3.1387
# Iteration: 3843; Percent complete: 96.1%; Average loss: 2.8783
# Iteration: 3844; Percent complete: 96.1%; Average loss: 3.1110
# Iteration: 3845; Percent complete: 96.1%; Average loss: 2.8388
# Iteration: 3846; Percent complete: 96.2%; Average loss: 3.0990
# Iteration: 3847; Percent complete: 96.2%; Average loss: 2.7650
# Iteration: 3848; Percent complete: 96.2%; Average loss: 3.0452
# Iteration: 3849; Percent complete: 96.2%; Average loss: 3.1324
# Iteration: 3850; Percent complete: 96.2%; Average loss: 2.8609
# Iteration: 3851; Percent complete: 96.3%; Average loss: 2.8808
# Iteration: 3852; Percent complete: 96.3%; Average loss: 2.8946
# Iteration: 3853; Percent complete: 96.3%; Average loss: 3.0275
# Iteration: 3854; Percent complete: 96.4%; Average loss: 3.1572
# Iteration: 3855; Percent complete: 96.4%; Average loss: 2.8640
# Iteration: 3856; Percent complete: 96.4%; Average loss: 3.0312
# Iteration: 3857; Percent complete: 96.4%; Average loss: 2.9392
# Iteration: 3858; Percent complete: 96.5%; Average loss: 3.0110
# Iteration: 3859; Percent complete: 96.5%; Average loss: 2.9795
# Iteration: 3860; Percent complete: 96.5%; Average loss: 3.0557
# Iteration: 3861; Percent complete: 96.5%; Average loss: 3.0690
# Iteration: 3862; Percent complete: 96.5%; Average loss: 3.2397
# Iteration: 3863; Percent complete: 96.6%; Average loss: 3.0104
# Iteration: 3864; Percent complete: 96.6%; Average loss: 2.8932
# Iteration: 3865; Percent complete: 96.6%; Average loss: 2.9422
# Iteration: 3866; Percent complete: 96.7%; Average loss: 2.8630
# Iteration: 3867; Percent complete: 96.7%; Average loss: 2.8660
# Iteration: 3868; Percent complete: 96.7%; Average loss: 2.8692
# Iteration: 3869; Percent complete: 96.7%; Average loss: 2.9608
# Iteration: 3870; Percent complete: 96.8%; Average loss: 2.9654
# Iteration: 3871; Percent complete: 96.8%; Average loss: 3.2500
# Iteration: 3872; Percent complete: 96.8%; Average loss: 2.9981
# Iteration: 3873; Percent complete: 96.8%; Average loss: 2.9304
# Iteration: 3874; Percent complete: 96.9%; Average loss: 2.9119
# Iteration: 3875; Percent complete: 96.9%; Average loss: 2.7970
# Iteration: 3876; Percent complete: 96.9%; Average loss: 2.9884
# Iteration: 3877; Percent complete: 96.9%; Average loss: 2.9276
# Iteration: 3878; Percent complete: 97.0%; Average loss: 2.6550
# Iteration: 3879; Percent complete: 97.0%; Average loss: 2.8805
# Iteration: 3880; Percent complete: 97.0%; Average loss: 2.7628
# Iteration: 3881; Percent complete: 97.0%; Average loss: 2.9598
# Iteration: 3882; Percent complete: 97.0%; Average loss: 3.1091
# Iteration: 3883; Percent complete: 97.1%; Average loss: 2.9189
# Iteration: 3884; Percent complete: 97.1%; Average loss: 3.1134
# Iteration: 3885; Percent complete: 97.1%; Average loss: 2.7899
# Iteration: 3886; Percent complete: 97.2%; Average loss: 3.0535
# Iteration: 3887; Percent complete: 97.2%; Average loss: 3.0126
# Iteration: 3888; Percent complete: 97.2%; Average loss: 2.9740
# Iteration: 3889; Percent complete: 97.2%; Average loss: 2.9354
# Iteration: 3890; Percent complete: 97.2%; Average loss: 2.9275
# Iteration: 3891; Percent complete: 97.3%; Average loss: 2.9000
# Iteration: 3892; Percent complete: 97.3%; Average loss: 3.0203
# Iteration: 3893; Percent complete: 97.3%; Average loss: 2.8724
# Iteration: 3894; Percent complete: 97.4%; Average loss: 3.1304
# Iteration: 3895; Percent complete: 97.4%; Average loss: 3.1395
# Iteration: 3896; Percent complete: 97.4%; Average loss: 3.0714
# Iteration: 3897; Percent complete: 97.4%; Average loss: 2.8935
# Iteration: 3898; Percent complete: 97.5%; Average loss: 3.1267
# Iteration: 3899; Percent complete: 97.5%; Average loss: 2.9489
# Iteration: 3900; Percent complete: 97.5%; Average loss: 3.0405
# Iteration: 3901; Percent complete: 97.5%; Average loss: 3.1398
# Iteration: 3902; Percent complete: 97.5%; Average loss: 2.7309
# Iteration: 3903; Percent complete: 97.6%; Average loss: 2.9483
# Iteration: 3904; Percent complete: 97.6%; Average loss: 2.9851
# Iteration: 3905; Percent complete: 97.6%; Average loss: 3.1711
# Iteration: 3906; Percent complete: 97.7%; Average loss: 3.0910
# Iteration: 3907; Percent complete: 97.7%; Average loss: 2.8873
# Iteration: 3908; Percent complete: 97.7%; Average loss: 3.0465
# Iteration: 3909; Percent complete: 97.7%; Average loss: 3.1339
# Iteration: 3910; Percent complete: 97.8%; Average loss: 2.9676
# Iteration: 3911; Percent complete: 97.8%; Average loss: 2.8954
# Iteration: 3912; Percent complete: 97.8%; Average loss: 2.8415
# Iteration: 3913; Percent complete: 97.8%; Average loss: 2.9167
# Iteration: 3914; Percent complete: 97.9%; Average loss: 2.7012
# Iteration: 3915; Percent complete: 97.9%; Average loss: 2.9317
# Iteration: 3916; Percent complete: 97.9%; Average loss: 2.8542
# Iteration: 3917; Percent complete: 97.9%; Average loss: 2.8970
# Iteration: 3918; Percent complete: 98.0%; Average loss: 2.9689
# Iteration: 3919; Percent complete: 98.0%; Average loss: 2.5837
# Iteration: 3920; Percent complete: 98.0%; Average loss: 2.9772
# Iteration: 3921; Percent complete: 98.0%; Average loss: 2.9713
# Iteration: 3922; Percent complete: 98.0%; Average loss: 3.0357
# Iteration: 3923; Percent complete: 98.1%; Average loss: 3.0799
# Iteration: 3924; Percent complete: 98.1%; Average loss: 2.9495
# Iteration: 3925; Percent complete: 98.1%; Average loss: 2.8304
# Iteration: 3926; Percent complete: 98.2%; Average loss: 3.0227
# Iteration: 3927; Percent complete: 98.2%; Average loss: 2.9829
# Iteration: 3928; Percent complete: 98.2%; Average loss: 2.9033
# Iteration: 3929; Percent complete: 98.2%; Average loss: 2.8890
# Iteration: 3930; Percent complete: 98.2%; Average loss: 2.7719
# Iteration: 3931; Percent complete: 98.3%; Average loss: 2.9644
# Iteration: 3932; Percent complete: 98.3%; Average loss: 2.9002
# Iteration: 3933; Percent complete: 98.3%; Average loss: 2.9461
# Iteration: 3934; Percent complete: 98.4%; Average loss: 2.8395
# Iteration: 3935; Percent complete: 98.4%; Average loss: 3.1623
# Iteration: 3936; Percent complete: 98.4%; Average loss: 3.0511
# Iteration: 3937; Percent complete: 98.4%; Average loss: 2.9314
# Iteration: 3938; Percent complete: 98.5%; Average loss: 2.9500
# Iteration: 3939; Percent complete: 98.5%; Average loss: 2.9764
# Iteration: 3940; Percent complete: 98.5%; Average loss: 2.7874
# Iteration: 3941; Percent complete: 98.5%; Average loss: 2.8342
# Iteration: 3942; Percent complete: 98.6%; Average loss: 2.8276
# Iteration: 3943; Percent complete: 98.6%; Average loss: 3.0529
# Iteration: 3944; Percent complete: 98.6%; Average loss: 2.9192
# Iteration: 3945; Percent complete: 98.6%; Average loss: 2.9496
# Iteration: 3946; Percent complete: 98.7%; Average loss: 2.8995
# Iteration: 3947; Percent complete: 98.7%; Average loss: 3.0427
# Iteration: 3948; Percent complete: 98.7%; Average loss: 3.1435
# Iteration: 3949; Percent complete: 98.7%; Average loss: 3.1123
# Iteration: 3950; Percent complete: 98.8%; Average loss: 2.7157
# Iteration: 3951; Percent complete: 98.8%; Average loss: 2.8462
# Iteration: 3952; Percent complete: 98.8%; Average loss: 2.9926
# Iteration: 3953; Percent complete: 98.8%; Average loss: 3.1520
# Iteration: 3954; Percent complete: 98.9%; Average loss: 3.1167
# Iteration: 3955; Percent complete: 98.9%; Average loss: 3.0591
# Iteration: 3956; Percent complete: 98.9%; Average loss: 3.1408
# Iteration: 3957; Percent complete: 98.9%; Average loss: 2.7679
# Iteration: 3958; Percent complete: 99.0%; Average loss: 2.6953
# Iteration: 3959; Percent complete: 99.0%; Average loss: 2.9354
# Iteration: 3960; Percent complete: 99.0%; Average loss: 3.0507
# Iteration: 3961; Percent complete: 99.0%; Average loss: 2.9364
# Iteration: 3962; Percent complete: 99.1%; Average loss: 2.9522
# Iteration: 3963; Percent complete: 99.1%; Average loss: 3.0317
# Iteration: 3964; Percent complete: 99.1%; Average loss: 2.8407
# Iteration: 3965; Percent complete: 99.1%; Average loss: 2.8439
# Iteration: 3966; Percent complete: 99.2%; Average loss: 2.9847
# Iteration: 3967; Percent complete: 99.2%; Average loss: 3.0067
# Iteration: 3968; Percent complete: 99.2%; Average loss: 2.8628
# Iteration: 3969; Percent complete: 99.2%; Average loss: 2.7869
# Iteration: 3970; Percent complete: 99.2%; Average loss: 2.7984
# Iteration: 3971; Percent complete: 99.3%; Average loss: 2.9539
# Iteration: 3972; Percent complete: 99.3%; Average loss: 3.0049
# Iteration: 3973; Percent complete: 99.3%; Average loss: 3.0845
# Iteration: 3974; Percent complete: 99.4%; Average loss: 2.9410
# Iteration: 3975; Percent complete: 99.4%; Average loss: 3.0753
# Iteration: 3976; Percent complete: 99.4%; Average loss: 2.7539
# Iteration: 3977; Percent complete: 99.4%; Average loss: 2.9818
# Iteration: 3978; Percent complete: 99.5%; Average loss: 2.9051
# Iteration: 3979; Percent complete: 99.5%; Average loss: 2.9466
# Iteration: 3980; Percent complete: 99.5%; Average loss: 2.9367
# Iteration: 3981; Percent complete: 99.5%; Average loss: 2.8842
# Iteration: 3982; Percent complete: 99.6%; Average loss: 3.0498
# Iteration: 3983; Percent complete: 99.6%; Average loss: 2.8082
# Iteration: 3984; Percent complete: 99.6%; Average loss: 3.0049
# Iteration: 3985; Percent complete: 99.6%; Average loss: 2.9630
# Iteration: 3986; Percent complete: 99.7%; Average loss: 2.9513
# Iteration: 3987; Percent complete: 99.7%; Average loss: 2.8077
# Iteration: 3988; Percent complete: 99.7%; Average loss: 2.9180
# Iteration: 3989; Percent complete: 99.7%; Average loss: 3.0525
# Iteration: 3990; Percent complete: 99.8%; Average loss: 2.9408
# Iteration: 3991; Percent complete: 99.8%; Average loss: 3.0500
# Iteration: 3992; Percent complete: 99.8%; Average loss: 2.8128
# Iteration: 3993; Percent complete: 99.8%; Average loss: 3.0222
# Iteration: 3994; Percent complete: 99.9%; Average loss: 3.1128
# Iteration: 3995; Percent complete: 99.9%; Average loss: 2.8786
# Iteration: 3996; Percent complete: 99.9%; Average loss: 2.9055
# Iteration: 3997; Percent complete: 99.9%; Average loss: 3.0364
# Iteration: 3998; Percent complete: 100.0%; Average loss: 2.9794
# Iteration: 3999; Percent complete: 100.0%; Average loss: 2.9140
# Iteration: 4000; Percent complete: 100.0%; Average loss: 2.9502

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores


def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to("cpu")
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            print(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            print(output_words)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

searcher = GreedySearchDecoder(encoder, decoder)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# hello
# ['i', 'm', 'sorry', '.', 'EOS', 'is', 'there', '.', 'EOS', '.']
# Bot: i m sorry . is there . .
# hello
# ['i', 'm', 'sorry', '.', 'EOS', '.', 'EOS', '.', 'EOS', '.']
# Bot: i m sorry . . . .
# what is your name
# ['i', 'm', 'sorry', '.', 'EOS', 'is', 'there', '.', 'EOS', '?']
# Bot: i m sorry . is there . ?
# what s up
# ['i', 'm', 'not', 'asking', 'you', 'a', 'week', '!', 'EOS', 'EOS']
# Bot: i m not asking you a week !
# who are you ?
# ['i', 'm', 'not', 'asking', 'you', 'a', 'man', '.', 'EOS', '.']
# Bot: i m not asking you a man . .
# where am i ?
# ['i', 'don', 't', 'know', '.', 'EOS', '.', 'EOS', '.', 'EOS']
# Bot: i don t know . . .
# where are you from ?
# ['i', 'm', 'not', 'asking', 'you', 'a', 'week', '.', 'EOS', '.']
# Bot: i m not asking you a week . .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_6.ipynb Cell 4 in <cell line: 72>()
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_6.ipynb#W3sZmlsZQ%3D%3D?line=68'>69</a>             print("Error: Encountered unknown word.")
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_6.ipynb#W3sZmlsZQ%3D%3D?line=70'>71</a> searcher = GreedySearchDecoder(encoder, decoder)
# ---> <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_6.ipynb#W3sZmlsZQ%3D%3D?line=71'>72</a> evaluateInput(encoder, decoder, searcher, voc)
#
# /Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_6.ipynb Cell 4 in evaluateInput(encoder, decoder, searcher, voc)
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_6.ipynb#W3sZmlsZQ%3D%3D?line=51'>52</a> while(1):
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_6.ipynb#W3sZmlsZQ%3D%3D?line=52'>53</a>     try:
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_6.ipynb#W3sZmlsZQ%3D%3D?line=53'>54</a>         # Get input sentence
# ---> <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_6.ipynb#W3sZmlsZQ%3D%3D?line=54'>55</a>         input_sentence = input('> ')
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_6.ipynb#W3sZmlsZQ%3D%3D?line=55'>56</a>         # Check if it is quit case
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_6.ipynb#W3sZmlsZQ%3D%3D?line=56'>57</a>         if input_sentence == 'q' or input_sentence == 'quit': break
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ipykernel/kernelbase.py:1161, in Kernel.raw_input(self, prompt)
#    1157 if not self._allow_stdin:
#    1158     raise StdinNotImplementedError(
#    1159         "raw_input was called, but this frontend does not support input requests."
#    1160     )
# -> 1161 return self._input_request(
#    1162     str(prompt),
#    1163     self._parent_ident["shell"],
#    1164     self.get_parent("shell"),
#    1165     password=False,
#    1166 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ipykernel/kernelbase.py:1205, in Kernel._input_request(self, prompt, ident, parent, password)
#    1202             break
#    1203 except KeyboardInterrupt:
#    1204     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1205     raise KeyboardInterrupt("Interrupted by user") from None
#    1206 except Exception:
#    1207     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
import torch.nn as nn
import re
import os
import unicodedata
import numpy as np
from model import EncoderRNN, Attn, LuongAttnDecoderRNN
from Voc import *

device = torch.device("cpu")
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder, decoder_n_layers):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self._device = device
        self._SOS_token = SOS_token
        self._decoder_n_layers = decoder_n_layers

    __constants__ = ['_device', '_SOS_token', '_decoder_n_layers']

    def forward(self, input_seq : torch.Tensor, input_length : torch.Tensor, max_length : int):
        # Forward input through encoder model
        #print(input_seq.shape)
        #print(len(input_seq.shape))
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        #print(encoder_outputs)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:self._decoder_n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=self._device, dtype=torch.long) * self._SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=self._device, dtype=torch.long)
        all_scores = torch.zeros([0], device=self._device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores
def evaluate(searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to(device)
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    #print(tokens)
    #print(scores)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    #print(decoded_words)
    return decoded_words


# Evaluate inputs from user input (stdin)
def evaluateInput(searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# Normalize input sentence and call evaluate()
def evaluateExample(sentence, searcher, voc):
    print("> " + sentence)
    # Normalize sentence
    input_sentence = normalizeString(sentence)
    #print(input_sentence)
    # Evaluate sentence
    output_words = evaluate(searcher, voc, input_sentence)
    output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
    print('Bot:', ' '.join(output_words))

save_dir = os.path.join("data", "save")
corpus_name = "movie-corpus"

# Configure models
model_name = 'cb_model'
attn_model = 'dot'
#attn_model = 'general'
#attn_model = 'concat'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# If you're loading your own model
# Set checkpoint to load from

# If you're loading the hosted model
#loadFilename = 'data/4000_checkpoint.tar'




### Compile the whole greedy search model to TorchScript model
# Create artificial inputs
test_seq = torch.LongTensor(MAX_LENGTH, 1).random_(0, voc.num_words).to(device)
test_seq_length = torch.LongTensor([test_seq.size()[0]]).to(device)
# Trace the model
traced_encoder = torch.jit.trace(encoder, (test_seq, test_seq_length))

### Convert decoder model
# Create and generate artificial inputs
test_encoder_outputs, test_encoder_hidden = traced_encoder(test_seq, test_seq_length)
test_decoder_hidden = test_encoder_hidden[:decoder.n_layers]
test_decoder_input = torch.LongTensor(1, 1).random_(0, voc.num_words)
# Trace the model
traced_decoder = torch.jit.trace(decoder, (test_decoder_input, test_decoder_hidden, test_encoder_outputs))

### Initialize searcher module by wrapping ``torch.jit.script`` call
scripted_searcher = torch.jit.script(GreedySearchDecoder(traced_encoder, traced_decoder, decoder.n_layers))


# Use appropriate device
scripted_searcher.to(device)
# Set dropout layers to eval mode
scripted_searcher.eval()

# Evaluate examples
sentences = ["hello", "what's up?", "who are you?", "where am I?", "where are you from?"]
#sentences = ["hello"]
for s in sentences:
    evaluateExample(s, scripted_searcher, voc)
# Out:
# /var/folders/rk/rb0btt_x2mxgsj16ky_t07tr0000gn/T/ipykernel_6074/708885139.py:122: TracerWarning: Converting a tensor to a Python float might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   cell_id = math.floor(input_seq[t, i] / 88) * self.num_layers
# /var/folders/rk/rb0btt_x2mxgsj16ky_t07tr0000gn/T/ipykernel_6074/708885139.py:147: TracerWarning: Converting a tensor to a NumPy array might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   output = torch.tensor([item.detach().numpy() for item in outs])
# /var/folders/rk/rb0btt_x2mxgsj16ky_t07tr0000gn/T/ipykernel_6074/708885139.py:147: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   output = torch.tensor([item.detach().numpy() for item in outs])
# /var/folders/rk/rb0btt_x2mxgsj16ky_t07tr0000gn/T/ipykernel_6074/708885139.py:156: TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
#   h0[layer] = torch.tensor([item.detach().numpy() for item in hidden_forward[layer]])
# /var/folders/rk/rb0btt_x2mxgsj16ky_t07tr0000gn/T/ipykernel_6074/708885139.py:156: TracerWarning: Converting a tensor to a NumPy array might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   h0[layer] = torch.tensor([item.detach().numpy() for item in hidden_forward[layer]])
# /var/folders/rk/rb0btt_x2mxgsj16ky_t07tr0000gn/T/ipykernel_6074/708885139.py:156: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   h0[layer] = torch.tensor([item.detach().numpy() for item in hidden_forward[layer]])
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/jit/_trace.py:1001: TracerWarning: Output nr 1. of the traced function does not match the corresponding output of the Python function. Detailed error:
# Tensor-likes are not close!
#
# Mismatched elements: 4913 / 7836 (62.7%)
# Greatest absolute difference: 0.02825591468717903 at index (0, 14) (up to 1e-05 allowed)
# Greatest relative difference: 10.871063234601607 at index (0, 3987) (up to 1e-05 allowed)
#   _check_trace(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/jit/_trace.py:1001: TracerWarning: Output nr 2. of the traced function does not match the corresponding output of the Python function. Detailed error:
# Tensor-likes are not close!
#
# Mismatched elements: 1000 / 1000 (100.0%)
# Greatest absolute difference: 0.6849508583545685 at index (0, 0, 205) (up to 1e-05 allowed)
# Greatest relative difference: 455.835348320481 at index (0, 0, 318) (up to 1e-05 allowed)
#   _check_trace(
# > hello
# Bot: i m not sure . . .
# > what's up?
# Bot: i m not asking you a week . ?
# > who are you?
# Bot: i m sorry . and leia . .
# > where am I?
# Bot: i m sorry . . . .
# > where are you from?
# Bot: i m not asking you a week . ?
