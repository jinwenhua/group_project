# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals
from pre_process import *

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import random
import os


USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")
# Out:
# b'{"id": "L1045", "conversation_id": "L1044", "text": "They do not!", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "not", "tag": "RB", "dep": "neg", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L1044", "timestamp": null, "vectors": []}\n'
# b'{"id": "L1044", "conversation_id": "L1044", "text": "They do to!", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "to", "tag": "TO", "dep": "dobj", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L985", "conversation_id": "L984", "text": "I hope so.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "hope", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "so", "tag": "RB", "dep": "advmod", "up": 1, "dn": []}, {"tok": ".", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L984", "timestamp": null, "vectors": []}\n'
# b'{"id": "L984", "conversation_id": "L984", "text": "She okay?", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "She", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "okay", "tag": "RB", "dep": "ROOT", "dn": [0, 2]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L925", "conversation_id": "L924", "text": "Let\'s go.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Let", "tag": "VB", "dep": "ROOT", "dn": [2, 3]}, {"tok": "\'s", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "go", "tag": "VB", "dep": "ccomp", "up": 0, "dn": [1]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L924", "timestamp": null, "vectors": []}\n'
# b'{"id": "L924", "conversation_id": "L924", "text": "Wow", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Wow", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L872", "conversation_id": "L870", "text": "Okay -- you\'re gonna need to learn how to lie.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 4, "toks": [{"tok": "Okay", "tag": "UH", "dep": "intj", "up": 4, "dn": []}, {"tok": "--", "tag": ":", "dep": "punct", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "\'re", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "gon", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 2, 3, 6, 12]}, {"tok": "na", "tag": "TO", "dep": "aux", "up": 6, "dn": []}, {"tok": "need", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 8]}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 8, "dn": []}, {"tok": "learn", "tag": "VB", "dep": "xcomp", "up": 6, "dn": [7, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 11, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 11, "dn": []}, {"tok": "lie", "tag": "VB", "dep": "xcomp", "up": 8, "dn": [9, 10]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": "L871", "timestamp": null, "vectors": []}\n'
# b'{"id": "L871", "conversation_id": "L870", "text": "No", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "No", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": "L870", "timestamp": null, "vectors": []}\n'
# b'{"id": "L870", "conversation_id": "L870", "text": "I\'m kidding.  You know how sometimes you just become this \\"persona\\"?  And you don\'t know how to quit?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 2, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "\'m", "tag": "VBP", "dep": "aux", "up": 2, "dn": []}, {"tok": "kidding", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 3]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 2, "dn": [4]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 3, "dn": []}]}, {"rt": 1, "toks": [{"tok": "You", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "know", "tag": "VBP", "dep": "ROOT", "dn": [0, 6, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 3, "dn": []}, {"tok": "sometimes", "tag": "RB", "dep": "advmod", "up": 6, "dn": [2]}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 6, "dn": []}, {"tok": "just", "tag": "RB", "dep": "advmod", "up": 6, "dn": []}, {"tok": "become", "tag": "VBP", "dep": "ccomp", "up": 1, "dn": [3, 4, 5, 9]}, {"tok": "this", "tag": "DT", "dep": "det", "up": 9, "dn": []}, {"tok": "\\"", "tag": "``", "dep": "punct", "up": 9, "dn": []}, {"tok": "persona", "tag": "NN", "dep": "attr", "up": 6, "dn": [7, 8, 10]}, {"tok": "\\"", "tag": "\'\'", "dep": "punct", "up": 9, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": [12]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 11, "dn": []}]}, {"rt": 4, "toks": [{"tok": "And", "tag": "CC", "dep": "cc", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "n\'t", "tag": "RB", "dep": "neg", "up": 4, "dn": []}, {"tok": "know", "tag": "VB", "dep": "ROOT", "dn": [0, 1, 2, 3, 7, 8]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 7, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 7, "dn": []}, {"tok": "quit", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 6]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L869", "conversation_id": "L866", "text": "Like my fear of wearing pastels?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Like", "tag": "IN", "dep": "ROOT", "dn": [2, 6]}, {"tok": "my", "tag": "PRP$", "dep": "poss", "up": 2, "dn": []}, {"tok": "fear", "tag": "NN", "dep": "pobj", "up": 0, "dn": [1, 3]}, {"tok": "of", "tag": "IN", "dep": "prep", "up": 2, "dn": [4]}, {"tok": "wearing", "tag": "VBG", "dep": "pcomp", "up": 3, "dn": [5]}, {"tok": "pastels", "tag": "NNS", "dep": "dobj", "up": 4, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L868", "timestamp": null, "vectors": []}\n'
#
# Processing corpus into lines and conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# b'They do to!\tThey do not!\n'
# b'She okay?\tI hope so.\n'
# b"Wow\tLet's go.\n"
# b'"I\'m kidding.  You know how sometimes you just become this ""persona""?  And you don\'t know how to quit?"\tNo\n'
# b"No\tOkay -- you're gonna need to learn how to lie.\n"
# b"I figured you'd get to the good stuff eventually.\tWhat good stuff?\n"
# b'What good stuff?\t"The ""real you""."\n'
# b'"The ""real you""."\tLike my fear of wearing pastels?\n'
# b'do you listen to this crap?\tWhat crap?\n'
# b"What crap?\tMe.  This endless ...blonde babble. I'm like, boring myself.\n"
# Start preparing training data ...
# Reading lines...
# Read 221282 sentence pairs
# Trimmed to 64313 sentence pairs
# Counting words...
# Counted words: 18082
#
# pairs:
# ['they do to !', 'they do not !']
# ['she okay ?', 'i hope so .']
# ['wow', 'let s go .']
# ['what good stuff ?', 'the real you .']
# ['the real you .', 'like my fear of wearing pastels ?']
# ['do you listen to this crap ?', 'what crap ?']
# ['well no . . .', 'then that s all you had to say .']
# ['then that s all you had to say .', 'but']
# ['but', 'you always been this selfish ?']
# ['have fun tonight ?', 'tons']
# keep_words 7833 / 18079 = 0.4333
# Trimmed from 64313 pairs to 53131, 0.8261 of total
# input_variable: tensor([[  11,   19,   19,   31,  191],
#         [ 208,  176,   14, 1740,   14],
#         [ 135,   24,   14,   14,    2],
#         [  48, 1603,   14,    2,    0],
#         [  19,  141,   10,    0,    0],
#         [   5,  161,    2,    0,    0],
#         [  39,   10,    0,    0,    0],
#         [  14,    2,    0,    0,    0],
#         [   2,    0,    0,    0,    0]])
# lengths: tensor([9, 8, 6, 4, 3])
# target_variable: tensor([[  39,   85,  194,   11,  317],
#         [  24,   17,   72,  971,   24],
#         [ 181,   99,  103,  619,   49],
#         [ 773,   66,   11,   14,   36],
#         [  14,   14, 1171,    2,   14],
#         [   2,    2,  160,    0,    2],
#         [   0,    0,   14,    0,    0],
#         [   0,    0,    2,    0,    0]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True, False,  True],
#         [False, False,  True, False, False],
#         [False, False,  True, False, False]])
# max_target_len: 8

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import torch
import torch.nn as nn
from torch.autograd import Variable
import numpy as np
import math


class GRUCell(nn.Module):
    def __init__(self, input_size, hidden_size, bias=True):
        super(GRUCell, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.bias = bias

        self.x2h = nn.Linear(input_size, 3 * hidden_size, bias=bias)
        self.h2h = nn.Linear(hidden_size, 3 * hidden_size, bias=bias)

        self.reset_parameters()


    def reset_parameters(self):
        std = 1.0 / np.sqrt(self.hidden_size)
        for w in self.parameters():
            w.data.uniform_(-std, std)

    def forward(self, input, hx=None):

        # Inputs:
        #       input: of shape (batch_size, input_size)
        #       hx: of shape (batch_size, hidden_size)
        # Output:
        #       hy: of shape (batch_size, hidden_size)

        if hx is None:
            hx = Variable(input.new_zeros(input.size(0), self.hidden_size))

        x_t = self.x2h(input)
        h_t = self.h2h(hx)


        x_reset, x_upd, x_new = x_t.chunk(3, 0)
        h_reset, h_upd, h_new = h_t.chunk(3, 0)

        reset_gate = torch.sigmoid(x_reset + h_reset)
        update_gate = torch.sigmoid(x_upd + h_upd)
        new_gate = torch.tanh(x_new + (reset_gate * h_new))

        hy = update_gate * hx + (1 - update_gate) * new_gate

        return hy



class BidirRecurrentModel(nn.Module):
    def __init__(self, mode, input_size, hidden_size, num_layers, output_size = 0, bias = True):
        super(BidirRecurrentModel, self).__init__()
        self.mode = mode
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.bias = bias
        #self.output_size = output_size

        self.rnn_cell_list = nn.ModuleList()

        for _ in range(100):
            self.rnn_cell_list.append(GRUCell(self.input_size,
                                                self.hidden_size,
                                                self.bias))
            for l in range(1, self.num_layers):
                self.rnn_cell_list.append(GRUCell(self.hidden_size,
                                                    self.hidden_size,
                                                    self.bias))



        #self.fc = nn.Linear(self.hidden_size * 2, self.output_size)

    def forward(self, input, input_seq=None, merge_mode = 'ave'):

        # Input of shape (batch_size, sequence length, input_size)
        #
        # Output of shape (batch_size, output_size)

        if torch.cuda.is_available():
            h0 = Variable(torch.zeros(self.num_layers, input.size(1), self.hidden_size).cuda())
        else:
            h0 = Variable(torch.zeros(self.num_layers, input.size(1), self.hidden_size))


        outs = []
        outs_rev = []

        hidden_forward = list()
        for layer in range(self.num_layers):
            if self.mode == 'LSTM':
                hidden_forward.append((h0[layer, :, :], h0[layer, :, :]))
            else:
                hidden_forward.append(h0[layer, :, :])

        for t in range(input.shape[0]):
            for layer in range(self.num_layers):
                # If RNN{_TANH/_RELU} / GRU
                '''
                if layer == 0:
                    # Forward net
                    h_forward_l = self.rnn_cell_list[layer](input[t, :, :], hidden_forward[layer])

                else:
                    # Forward net
                    h_forward_l = self.rnn_cell_list[layer](hidden_forward[layer - 1], hidden_forward[layer])
                '''
                if torch.cuda.is_available():
                    h_forward_l = Variable(torch.zeros(input.size(1), self.hidden_size).cuda())
                else:
                    h_forward_l = Variable(torch.zeros( input.size(1), self.hidden_size))
                for i in range(input.size(1)):
                    if input_seq[t, i] > 0:
                        cell_id = math.floor(input_seq[t, i] / 88) * self.num_layers 
                        if layer == 0:
                            # Forward net
                            h_forward_l[i] = self.rnn_cell_list[cell_id + layer](input[t, i, :], hidden_forward[layer][i])
                        else:
                            # Forward net
                            h_forward_l[i] = self.rnn_cell_list[cell_id + layer](hidden_forward[layer - 1][i], hidden_forward[layer][i])

                    else:
                        break
                
                

                hidden_forward[layer] = h_forward_l

            if self.mode == 'LSTM':

                outs.append(h_forward_l[0])

            else:
                outs.append(h_forward_l)

        output = []


        if torch.cuda.is_available():
            output = torch.tensor([item.detach().numpy() for item in outs]).cuda()
        else:
            output = torch.tensor([item.detach().numpy() for item in outs])

        '''
        out = outs[-1].squeeze()
        out_rev = outs_rev[0].squeeze()
        out = torch.cat((out, out_rev), 1)
        '''

        for layer in range(self.num_layers):
            h0[layer] = torch.tensor([item.detach().numpy() for item in hidden_forward[layer]])
                
        
        #out = self.fc(out)
        return output, h0
        
######################################################################
# Define Encoder
# --------------
#
# We implement our encoder’s RNN with the ``torch.nn.GRU`` module which we
# feed a batch of sentences (vectors of word embeddings) and it internally
# iterates through the sentences one token at a time calculating the
# hidden states. We initialize this module to be bidirectional, meaning
# that we have two independent GRUs: one that iterates through the
# sequences in chronological order, and another that iterates in reverse
# order. We ultimately return the sum of these two GRUs’ outputs. Since
# our model was trained using batching, our ``EncoderRNN`` model’s
# ``forward`` function expects a padded input batch. To batch
# variable-length sentences, we allow a maximum of *MAX_LENGTH* tokens in
# a sentence, and all sentences in the batch that have less than
# *MAX_LENGTH* tokens are padded at the end with our dedicated *PAD_token*
# tokens. To use padded batches with a PyTorch RNN module, we must wrap
# the forward pass call with ``torch.nn.utils.rnn.pack_padded_sequence``
# and ``torch.nn.utils.rnn.pad_packed_sequence`` data transformations.
# Note that the ``forward`` function also takes an ``input_lengths`` list,
# which contains the length of each sentence in the batch. This input is
# used by the ``torch.nn.utils.rnn.pack_padded_sequence`` function when
# padding.
#
# TorchScript Notes:
# ~~~~~~~~~~~~~~~~~~~~~~
#
# Since the encoder’s ``forward`` function does not contain any
# data-dependent control flow, we will use **tracing** to convert it to
# script mode. When tracing a module, we can leave the module definition
# as-is. We will initialize all models towards the end of this document
# before we run evaluations.
#

class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size params are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = BidirRecurrentModel("GRU", hidden_size, hidden_size, n_layers)
        #self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # type: (Tensor, Tensor, Optional[Tensor]) -> Tuple[Tensor, Tensor]
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        outputs, hidden = self.gru(embedded, input_seq)
        '''
        # Pack padded batch of sequences for RNN module
        packed = torch.nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = torch.nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        '''
        
        # Return output and final hidden state
        return outputs, hidden

    ######################################################################
# Define Decoder’s Attention Module
# ---------------------------------
#
# Next, we’ll define our attention module (``Attn``). Note that this
# module will be used as a submodule in our decoder model. Luong et
# al. consider various “score functions”, which take the current decoder
# RNN output and the entire encoder output, and return attention
# “energies”. This attention energies tensor is the same size as the
# encoder output, and the two are ultimately multiplied, resulting in a
# weighted tensor whose largest values represent the most important parts
# of the query sentence at a particular time-step of decoding.
#

# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))
    
    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)


######################################################################
# Define Decoder
# --------------
#
# Similarly to the ``EncoderRNN``, we use the ``torch.nn.GRU`` module for
# our decoder’s RNN. This time, however, we use a unidirectional GRU. It
# is important to note that unlike the encoder, we will feed the decoder
# RNN one word at a time. We start by getting the embedding of the current
# word and applying a
# `dropout <https://pytorch.org/docs/stable/nn.html?highlight=dropout#torch.nn.Dropout>`__.
# Next, we forward the embedding and the last hidden state to the GRU and
# obtain a current GRU output and hidden state. We then use our ``Attn``
# module as a layer to obtain the attention weights, which we multiply by
# the encoder’s output to obtain our attended encoder output. We use this
# attended encoder output as our ``context`` tensor, which represents a
# weighted sum indicating what parts of the encoder’s output to pay
# attention to. From here, we use a linear layer and softmax normalization
# to select the next word in the output sequence.

# TorchScript Notes:
# ~~~~~~~~~~~~~~~~~~~~~~
#
# Similarly to the ``EncoderRNN``, this module does not contain any
# data-dependent control flow. Therefore, we can once again use
# **tracing** to convert this model to TorchScript after it
# is initialized and its parameters are loaded.
#

class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %%
######################################################################
# Define Training Procedure
# -------------------------
#
# Masked loss
# ~~~~~~~~~~~
#
# Since we are dealing with batches of padded sequences, we cannot simply
# consider all elements of the tensor when calculating loss. We define
# ``maskNLLLoss`` to calculate our loss based on our decoder’s output
# tensor, the target tensor, and a binary mask tensor describing the
# padding of the target tensor. This loss function calculates the average
# negative log likelihood of the elements that correspond to a *1* in the
# mask tensor.
#

def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()


######################################################################
# Single training iteration
# ~~~~~~~~~~~~~~~~~~~~~~~~~
#
# The ``train`` function contains the algorithm for a single training
# iteration (a single batch of inputs).
#
# We will use a couple of clever tricks to aid in convergence:
#
# -  The first trick is using **teacher forcing**. This means that at some
#    probability, set by ``teacher_forcing_ratio``, we use the current
#    target word as the decoder’s next input rather than using the
#    decoder’s current guess. This technique acts as training wheels for
#    the decoder, aiding in more efficient training. However, teacher
#    forcing can lead to model instability during inference, as the
#    decoder may not have a sufficient chance to truly craft its own
#    output sequences during training. Thus, we must be mindful of how we
#    are setting the ``teacher_forcing_ratio``, and not be fooled by fast
#    convergence.
#
# -  The second trick that we implement is **gradient clipping**. This is
#    a commonly used technique for countering the “exploding gradient”
#    problem. In essence, by clipping or thresholding gradients to a
#    maximum value, we prevent the gradients from growing exponentially
#    and either overflow (NaN), or overshoot steep cliffs in the cost
#    function.
#
# .. figure:: /_static/img/chatbot/grad_clip.png
#    :align: center
#    :width: 60%
#    :alt: grad_clip
#
# Image source: Goodfellow et al. *Deep Learning*. 2016. https://www.deeplearningbook.org/
#
# **Sequence of Operations:**
#
#    1) Forward pass entire input batch through encoder.
#    2) Initialize decoder inputs as SOS_token, and hidden state as the encoder's final hidden state.
#    3) Forward input batch sequence through decoder one time step at a time.
#    4) If teacher forcing: set next decoder input as the current target; else: set next decoder input as current decoder output.
#    5) Calculate and accumulate loss.
#    6) Perform backpropagation.
#    7) Clip gradients.
#    8) Update encoder and decoder model parameters.
#
#
# .. Note ::
#
#   PyTorch’s RNN modules (``RNN``, ``LSTM``, ``GRU``) can be used like any
#   other non-recurrent layers by simply passing them the entire input
#   sequence (or batch of sequences). We use the ``GRU`` layer like this in
#   the ``encoder``. The reality is that under the hood, there is an
#   iterative process looping over each time step calculating hidden states.
#   Alternatively, you can run these modules one time-step at a time. In
#   this case, we manually loop over the sequences during the training
#   process like we must do for the ``decoder`` model. As long as you
#   maintain the correct conceptual model of these modules, implementing
#   sequential models can be very straightforward.
#
#


def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for rnn packing should always be on the cpu
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropatation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals


######################################################################
# Training iterations
# ~~~~~~~~~~~~~~~~~~~
#
# It is finally time to tie the full training procedure together with the
# data. The ``trainIters`` function is responsible for running
# ``n_iterations`` of training given the passed models, optimizers, data,
# etc. This function is quite self explanatory, as we have done the heavy
# lifting with the ``train`` function.
#
# One thing to note is that when we save our model, we save a tarball
# containing the encoder and decoder state_dicts (parameters), the
# optimizers’ state_dicts, the loss, the iteration, etc. Saving the model
# in this way will give us the ultimate flexibility with the checkpoint.
# After loading a checkpoint, we will be able to use the model parameters
# to run inference, or we can continue training right where we left off.
#

def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, clip, corpus_name, loadFilename):

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg))
            print_loss = 0

        #'''
        # Save checkpoint
        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size))
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint1')))

        #'''


######################################################################
# Run Model
# ---------
#
# Finally, it is time to run our model!
#
# Regardless of whether we want to train or test the chatbot model, we
# must initialize the individual encoder and decoder models. In the
# following block, we set our desired configurations, choose to start from
# scratch or set a checkpoint to load from, and build and initialize the
# models. Feel free to play with different model configurations to
# optimize performance.
#

# Configure models
model_name = 'cb_model'
attn_model = 'dot'
#attn_model = 'general'
#attn_model = 'concat'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 1

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 4000
#loadFilename = os.path.join(save_dir, model_name, corpus_name,
#                            '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
#                            '{}_checkpoint.tar'.format(checkpoint_iter))


# Load model if a loadFilename is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')


######################################################################
# Run Training
# ~~~~~~~~~~~~
#
# Run the following block if you want to train the model.
#
# First we set training parameters, then we initialize our optimizers, and
# finally we call the ``trainIters`` function to run our training
# iterations.
#

# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 40000
#n_iteration = 1  #just used for test
print_every = 10
save_every = 40000

# Ensure dropout layers are in train mode
encoder.train()
decoder.train()

# Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
if loadFilename:
    encoder_optimizer.load_state_dict(encoder_optimizer_sd)
    decoder_optimizer.load_state_dict(decoder_optimizer_sd)

# If you have cuda, configure cuda to call
for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

# Run training iterations
print("Starting Training!")
trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name, loadFilename)
# Out:
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 10; Percent complete: 0.0%; Average loss: 8.8331
# Iteration: 20; Percent complete: 0.1%; Average loss: 7.1480
# Iteration: 30; Percent complete: 0.1%; Average loss: 6.1522
# Iteration: 40; Percent complete: 0.1%; Average loss: 5.5382
# Iteration: 50; Percent complete: 0.1%; Average loss: 5.5854
# Iteration: 60; Percent complete: 0.1%; Average loss: 4.7340
# Iteration: 70; Percent complete: 0.2%; Average loss: 4.7476
# Iteration: 80; Percent complete: 0.2%; Average loss: 4.8503
# Iteration: 90; Percent complete: 0.2%; Average loss: 4.8410
# Iteration: 100; Percent complete: 0.2%; Average loss: 5.0347
# Iteration: 110; Percent complete: 0.3%; Average loss: 4.5049
# Iteration: 120; Percent complete: 0.3%; Average loss: 5.0631
# Iteration: 130; Percent complete: 0.3%; Average loss: 4.4341
# Iteration: 140; Percent complete: 0.4%; Average loss: 4.6096
# Iteration: 150; Percent complete: 0.4%; Average loss: 4.8793
# Iteration: 160; Percent complete: 0.4%; Average loss: 4.9155
# Iteration: 170; Percent complete: 0.4%; Average loss: 5.1577
# Iteration: 180; Percent complete: 0.4%; Average loss: 4.5828
# Iteration: 190; Percent complete: 0.5%; Average loss: 4.8804
# Iteration: 200; Percent complete: 0.5%; Average loss: 4.8261
# Iteration: 210; Percent complete: 0.5%; Average loss: 4.7261
# Iteration: 220; Percent complete: 0.5%; Average loss: 5.5917
# Iteration: 230; Percent complete: 0.6%; Average loss: 3.9240
# Iteration: 240; Percent complete: 0.6%; Average loss: 4.8734
# Iteration: 250; Percent complete: 0.6%; Average loss: 4.6543
# Iteration: 260; Percent complete: 0.7%; Average loss: 5.0376
# Iteration: 270; Percent complete: 0.7%; Average loss: 5.4137
# Iteration: 280; Percent complete: 0.7%; Average loss: 3.8995
# Iteration: 290; Percent complete: 0.7%; Average loss: 4.4623
# Iteration: 300; Percent complete: 0.8%; Average loss: 4.4623
# Iteration: 310; Percent complete: 0.8%; Average loss: 3.8408
# Iteration: 320; Percent complete: 0.8%; Average loss: 5.3813
# Iteration: 330; Percent complete: 0.8%; Average loss: 4.6811
# Iteration: 340; Percent complete: 0.9%; Average loss: 4.0564
# Iteration: 350; Percent complete: 0.9%; Average loss: 4.7438
# Iteration: 360; Percent complete: 0.9%; Average loss: 4.2193
# Iteration: 370; Percent complete: 0.9%; Average loss: 4.9388
# Iteration: 380; Percent complete: 0.9%; Average loss: 4.3846
# Iteration: 390; Percent complete: 1.0%; Average loss: 4.6101
# Iteration: 400; Percent complete: 1.0%; Average loss: 5.0735
# Iteration: 410; Percent complete: 1.0%; Average loss: 4.3735
# Iteration: 420; Percent complete: 1.1%; Average loss: 4.1493
# Iteration: 430; Percent complete: 1.1%; Average loss: 4.2082
# Iteration: 440; Percent complete: 1.1%; Average loss: 4.0271
# Iteration: 450; Percent complete: 1.1%; Average loss: 4.5365
# Iteration: 460; Percent complete: 1.1%; Average loss: 4.7134
# Iteration: 470; Percent complete: 1.2%; Average loss: 5.0092
# Iteration: 480; Percent complete: 1.2%; Average loss: 5.3720
# Iteration: 490; Percent complete: 1.2%; Average loss: 3.9285
# Iteration: 500; Percent complete: 1.2%; Average loss: 3.9352
# Iteration: 510; Percent complete: 1.3%; Average loss: 4.5066
# Iteration: 520; Percent complete: 1.3%; Average loss: 4.3538
# Iteration: 530; Percent complete: 1.3%; Average loss: 5.0616
# Iteration: 540; Percent complete: 1.4%; Average loss: 4.8635
# Iteration: 550; Percent complete: 1.4%; Average loss: 4.5786
# Iteration: 560; Percent complete: 1.4%; Average loss: 4.7232
# Iteration: 570; Percent complete: 1.4%; Average loss: 4.6423
# Iteration: 580; Percent complete: 1.5%; Average loss: 4.2043
# Iteration: 590; Percent complete: 1.5%; Average loss: 3.9540
# Iteration: 600; Percent complete: 1.5%; Average loss: 4.4970
# Iteration: 610; Percent complete: 1.5%; Average loss: 4.3392
# Iteration: 620; Percent complete: 1.6%; Average loss: 4.2187
# Iteration: 630; Percent complete: 1.6%; Average loss: 4.8496
# Iteration: 640; Percent complete: 1.6%; Average loss: 4.3380
# Iteration: 650; Percent complete: 1.6%; Average loss: 4.5583
# Iteration: 660; Percent complete: 1.7%; Average loss: 3.4503
# Iteration: 670; Percent complete: 1.7%; Average loss: 4.2909
# Iteration: 680; Percent complete: 1.7%; Average loss: 5.0235
# Iteration: 690; Percent complete: 1.7%; Average loss: 4.8717
# Iteration: 700; Percent complete: 1.8%; Average loss: 4.4268
# Iteration: 710; Percent complete: 1.8%; Average loss: 4.9339
# Iteration: 720; Percent complete: 1.8%; Average loss: 3.8409
# Iteration: 730; Percent complete: 1.8%; Average loss: 4.0145
# Iteration: 740; Percent complete: 1.8%; Average loss: 4.3163
# Iteration: 750; Percent complete: 1.9%; Average loss: 3.9111
# Iteration: 760; Percent complete: 1.9%; Average loss: 4.4050
# Iteration: 770; Percent complete: 1.9%; Average loss: 3.8187
# Iteration: 780; Percent complete: 1.9%; Average loss: 4.3051
# Iteration: 790; Percent complete: 2.0%; Average loss: 4.6487
# Iteration: 800; Percent complete: 2.0%; Average loss: 4.8185
# Iteration: 810; Percent complete: 2.0%; Average loss: 4.5448
# Iteration: 820; Percent complete: 2.1%; Average loss: 4.9884
# Iteration: 830; Percent complete: 2.1%; Average loss: 3.7427
# Iteration: 840; Percent complete: 2.1%; Average loss: 4.1314
# Iteration: 850; Percent complete: 2.1%; Average loss: 3.8247
# Iteration: 860; Percent complete: 2.1%; Average loss: 4.0821
# Iteration: 870; Percent complete: 2.2%; Average loss: 4.5329
# Iteration: 880; Percent complete: 2.2%; Average loss: 3.7606
# Iteration: 890; Percent complete: 2.2%; Average loss: 3.7074
# Iteration: 900; Percent complete: 2.2%; Average loss: 3.6123
# Iteration: 910; Percent complete: 2.3%; Average loss: 4.3618
# Iteration: 920; Percent complete: 2.3%; Average loss: 3.7120
# Iteration: 930; Percent complete: 2.3%; Average loss: 3.9932
# Iteration: 940; Percent complete: 2.4%; Average loss: 5.1116
# Iteration: 950; Percent complete: 2.4%; Average loss: 4.2660
# Iteration: 960; Percent complete: 2.4%; Average loss: 4.3262
# Iteration: 970; Percent complete: 2.4%; Average loss: 4.9089
# Iteration: 980; Percent complete: 2.5%; Average loss: 4.2447
# Iteration: 990; Percent complete: 2.5%; Average loss: 5.0636
# Iteration: 1000; Percent complete: 2.5%; Average loss: 4.5855
# Iteration: 1010; Percent complete: 2.5%; Average loss: 3.9797
# Iteration: 1020; Percent complete: 2.5%; Average loss: 4.4913
# Iteration: 1030; Percent complete: 2.6%; Average loss: 4.9072
# Iteration: 1040; Percent complete: 2.6%; Average loss: 4.0123
# Iteration: 1050; Percent complete: 2.6%; Average loss: 5.3423
# Iteration: 1060; Percent complete: 2.6%; Average loss: 4.0281
# Iteration: 1070; Percent complete: 2.7%; Average loss: 4.8385
# Iteration: 1080; Percent complete: 2.7%; Average loss: 3.9025
# Iteration: 1090; Percent complete: 2.7%; Average loss: 4.5129
# Iteration: 1100; Percent complete: 2.8%; Average loss: 4.8115
# Iteration: 1110; Percent complete: 2.8%; Average loss: 4.4084
# Iteration: 1120; Percent complete: 2.8%; Average loss: 4.6314
# Iteration: 1130; Percent complete: 2.8%; Average loss: 4.2628
# Iteration: 1140; Percent complete: 2.9%; Average loss: 3.9885
# Iteration: 1150; Percent complete: 2.9%; Average loss: 4.5406
# Iteration: 1160; Percent complete: 2.9%; Average loss: 4.2228
# Iteration: 1170; Percent complete: 2.9%; Average loss: 3.9021
# Iteration: 1180; Percent complete: 2.9%; Average loss: 4.2719
# Iteration: 1190; Percent complete: 3.0%; Average loss: 3.5423
# Iteration: 1200; Percent complete: 3.0%; Average loss: 4.8420
# Iteration: 1210; Percent complete: 3.0%; Average loss: 4.4740
# Iteration: 1220; Percent complete: 3.0%; Average loss: 4.2614
# Iteration: 1230; Percent complete: 3.1%; Average loss: 4.5572
# Iteration: 1240; Percent complete: 3.1%; Average loss: 4.5698
# Iteration: 1250; Percent complete: 3.1%; Average loss: 3.9997
# Iteration: 1260; Percent complete: 3.1%; Average loss: 3.6412
# Iteration: 1270; Percent complete: 3.2%; Average loss: 4.4472
# Iteration: 1280; Percent complete: 3.2%; Average loss: 4.5572
# Iteration: 1290; Percent complete: 3.2%; Average loss: 3.6669
# Iteration: 1300; Percent complete: 3.2%; Average loss: 4.9383
# Iteration: 1310; Percent complete: 3.3%; Average loss: 4.7212
# Iteration: 1320; Percent complete: 3.3%; Average loss: 4.6060
# Iteration: 1330; Percent complete: 3.3%; Average loss: 4.7696
# Iteration: 1340; Percent complete: 3.4%; Average loss: 4.8151
# Iteration: 1350; Percent complete: 3.4%; Average loss: 4.0364
# Iteration: 1360; Percent complete: 3.4%; Average loss: 4.9530
# Iteration: 1370; Percent complete: 3.4%; Average loss: 4.1577
# Iteration: 1380; Percent complete: 3.5%; Average loss: 3.8545
# Iteration: 1390; Percent complete: 3.5%; Average loss: 3.7806
# Iteration: 1400; Percent complete: 3.5%; Average loss: 3.7836
# Iteration: 1410; Percent complete: 3.5%; Average loss: 4.0506
# Iteration: 1420; Percent complete: 3.5%; Average loss: 3.3462
# Iteration: 1430; Percent complete: 3.6%; Average loss: 4.5792
# Iteration: 1440; Percent complete: 3.6%; Average loss: 3.4882
# Iteration: 1450; Percent complete: 3.6%; Average loss: 4.0063
# Iteration: 1460; Percent complete: 3.6%; Average loss: 4.8298
# Iteration: 1470; Percent complete: 3.7%; Average loss: 3.7287
# Iteration: 1480; Percent complete: 3.7%; Average loss: 4.7838
# Iteration: 1490; Percent complete: 3.7%; Average loss: 5.1229
# Iteration: 1500; Percent complete: 3.8%; Average loss: 4.2616
# Iteration: 1510; Percent complete: 3.8%; Average loss: 5.5237
# Iteration: 1520; Percent complete: 3.8%; Average loss: 4.2684
# Iteration: 1530; Percent complete: 3.8%; Average loss: 4.5379
# Iteration: 1540; Percent complete: 3.9%; Average loss: 3.7205
# Iteration: 1550; Percent complete: 3.9%; Average loss: 4.4630
# Iteration: 1560; Percent complete: 3.9%; Average loss: 4.5550
# Iteration: 1570; Percent complete: 3.9%; Average loss: 4.2680
# Iteration: 1580; Percent complete: 4.0%; Average loss: 4.2316
# Iteration: 1590; Percent complete: 4.0%; Average loss: 4.3291
# Iteration: 1600; Percent complete: 4.0%; Average loss: 4.7783
# Iteration: 1610; Percent complete: 4.0%; Average loss: 3.7000
# Iteration: 1620; Percent complete: 4.0%; Average loss: 3.3263
# Iteration: 1630; Percent complete: 4.1%; Average loss: 4.0627
# Iteration: 1640; Percent complete: 4.1%; Average loss: 4.2477
# Iteration: 1650; Percent complete: 4.1%; Average loss: 4.3023
# Iteration: 1660; Percent complete: 4.2%; Average loss: 4.0061
# Iteration: 1670; Percent complete: 4.2%; Average loss: 4.0278
# Iteration: 1680; Percent complete: 4.2%; Average loss: 4.4455
# Iteration: 1690; Percent complete: 4.2%; Average loss: 4.1761
# Iteration: 1700; Percent complete: 4.2%; Average loss: 4.2424
# Iteration: 1710; Percent complete: 4.3%; Average loss: 4.7918
# Iteration: 1720; Percent complete: 4.3%; Average loss: 4.4484
# Iteration: 1730; Percent complete: 4.3%; Average loss: 3.4372
# Iteration: 1740; Percent complete: 4.3%; Average loss: 4.0321
# Iteration: 1750; Percent complete: 4.4%; Average loss: 4.3322
# Iteration: 1760; Percent complete: 4.4%; Average loss: 4.3425
# Iteration: 1770; Percent complete: 4.4%; Average loss: 4.2742
# Iteration: 1780; Percent complete: 4.5%; Average loss: 3.9301
# Iteration: 1790; Percent complete: 4.5%; Average loss: 3.3051
# Iteration: 1800; Percent complete: 4.5%; Average loss: 3.4227
# Iteration: 1810; Percent complete: 4.5%; Average loss: 3.7006
# Iteration: 1820; Percent complete: 4.5%; Average loss: 3.4458
# Iteration: 1830; Percent complete: 4.6%; Average loss: 4.7044
# Iteration: 1840; Percent complete: 4.6%; Average loss: 3.8461
# Iteration: 1850; Percent complete: 4.6%; Average loss: 3.6513
# Iteration: 1860; Percent complete: 4.7%; Average loss: 3.7809
# Iteration: 1870; Percent complete: 4.7%; Average loss: 4.7922
# Iteration: 1880; Percent complete: 4.7%; Average loss: 4.7103
# Iteration: 1890; Percent complete: 4.7%; Average loss: 4.4947
# Iteration: 1900; Percent complete: 4.8%; Average loss: 3.6163
# Iteration: 1910; Percent complete: 4.8%; Average loss: 3.8522
# Iteration: 1920; Percent complete: 4.8%; Average loss: 4.1531
# Iteration: 1930; Percent complete: 4.8%; Average loss: 4.6801
# Iteration: 1940; Percent complete: 4.9%; Average loss: 4.5198
# Iteration: 1950; Percent complete: 4.9%; Average loss: 4.2039
# Iteration: 1960; Percent complete: 4.9%; Average loss: 4.1364
# Iteration: 1970; Percent complete: 4.9%; Average loss: 4.3509
# Iteration: 1980; Percent complete: 5.0%; Average loss: 4.1245
# Iteration: 1990; Percent complete: 5.0%; Average loss: 4.2604
# Iteration: 2000; Percent complete: 5.0%; Average loss: 4.8085
# Iteration: 2010; Percent complete: 5.0%; Average loss: 3.6054
# Iteration: 2020; Percent complete: 5.1%; Average loss: 3.9941
# Iteration: 2030; Percent complete: 5.1%; Average loss: 3.8008
# Iteration: 2040; Percent complete: 5.1%; Average loss: 4.5991
# Iteration: 2050; Percent complete: 5.1%; Average loss: 4.4880
# Iteration: 2060; Percent complete: 5.1%; Average loss: 3.7685
# Iteration: 2070; Percent complete: 5.2%; Average loss: 4.0266
# Iteration: 2080; Percent complete: 5.2%; Average loss: 5.4208
# Iteration: 2090; Percent complete: 5.2%; Average loss: 3.7192
# Iteration: 2100; Percent complete: 5.2%; Average loss: 4.2152
# Iteration: 2110; Percent complete: 5.3%; Average loss: 4.1030
# Iteration: 2120; Percent complete: 5.3%; Average loss: 3.8559
# Iteration: 2130; Percent complete: 5.3%; Average loss: 3.8069
# Iteration: 2140; Percent complete: 5.3%; Average loss: 3.9653
# Iteration: 2150; Percent complete: 5.4%; Average loss: 4.2493
# Iteration: 2160; Percent complete: 5.4%; Average loss: 4.6907
# Iteration: 2170; Percent complete: 5.4%; Average loss: 4.1955
# Iteration: 2180; Percent complete: 5.5%; Average loss: 4.5965
# Iteration: 2190; Percent complete: 5.5%; Average loss: 4.0331
# Iteration: 2200; Percent complete: 5.5%; Average loss: 4.0919
# Iteration: 2210; Percent complete: 5.5%; Average loss: 4.8826
# Iteration: 2220; Percent complete: 5.5%; Average loss: 4.1670
# Iteration: 2230; Percent complete: 5.6%; Average loss: 3.4640
# Iteration: 2240; Percent complete: 5.6%; Average loss: 3.6060
# Iteration: 2250; Percent complete: 5.6%; Average loss: 3.9062
# Iteration: 2260; Percent complete: 5.7%; Average loss: 4.4446
# Iteration: 2270; Percent complete: 5.7%; Average loss: 4.0934
# Iteration: 2280; Percent complete: 5.7%; Average loss: 4.6075
# Iteration: 2290; Percent complete: 5.7%; Average loss: 4.3194
# Iteration: 2300; Percent complete: 5.8%; Average loss: 3.9270
# Iteration: 2310; Percent complete: 5.8%; Average loss: 4.3653
# Iteration: 2320; Percent complete: 5.8%; Average loss: 4.3700
# Iteration: 2330; Percent complete: 5.8%; Average loss: 3.2797
# Iteration: 2340; Percent complete: 5.9%; Average loss: 4.1142
# Iteration: 2350; Percent complete: 5.9%; Average loss: 3.8829
# Iteration: 2360; Percent complete: 5.9%; Average loss: 5.1010
# Iteration: 2370; Percent complete: 5.9%; Average loss: 3.8153
# Iteration: 2380; Percent complete: 5.9%; Average loss: 4.9286
# Iteration: 2390; Percent complete: 6.0%; Average loss: 4.3493
# Iteration: 2400; Percent complete: 6.0%; Average loss: 4.0314
# Iteration: 2410; Percent complete: 6.0%; Average loss: 4.2374
# Iteration: 2420; Percent complete: 6.0%; Average loss: 3.6641
# Iteration: 2430; Percent complete: 6.1%; Average loss: 3.2023
# Iteration: 2440; Percent complete: 6.1%; Average loss: 4.5350
# Iteration: 2450; Percent complete: 6.1%; Average loss: 3.4521
# Iteration: 2460; Percent complete: 6.2%; Average loss: 3.4602
# Iteration: 2470; Percent complete: 6.2%; Average loss: 4.1863
# Iteration: 2480; Percent complete: 6.2%; Average loss: 4.5147
# Iteration: 2490; Percent complete: 6.2%; Average loss: 4.3735
# Iteration: 2500; Percent complete: 6.2%; Average loss: 3.9314
# Iteration: 2510; Percent complete: 6.3%; Average loss: 4.3685
# Iteration: 2520; Percent complete: 6.3%; Average loss: 4.7894
# Iteration: 2530; Percent complete: 6.3%; Average loss: 4.3523
# Iteration: 2540; Percent complete: 6.3%; Average loss: 4.5640
# Iteration: 2550; Percent complete: 6.4%; Average loss: 4.6441
# Iteration: 2560; Percent complete: 6.4%; Average loss: 4.2885
# Iteration: 2570; Percent complete: 6.4%; Average loss: 3.8241
# Iteration: 2580; Percent complete: 6.5%; Average loss: 3.8507
# Iteration: 2590; Percent complete: 6.5%; Average loss: 4.3390
# Iteration: 2600; Percent complete: 6.5%; Average loss: 4.2604
# Iteration: 2610; Percent complete: 6.5%; Average loss: 4.3588
# Iteration: 2620; Percent complete: 6.6%; Average loss: 3.9296
# Iteration: 2630; Percent complete: 6.6%; Average loss: 4.6613
# Iteration: 2640; Percent complete: 6.6%; Average loss: 3.2058
# Iteration: 2650; Percent complete: 6.6%; Average loss: 4.1178
# Iteration: 2660; Percent complete: 6.7%; Average loss: 4.1972
# Iteration: 2670; Percent complete: 6.7%; Average loss: 4.0012
# Iteration: 2680; Percent complete: 6.7%; Average loss: 4.6199
# Iteration: 2690; Percent complete: 6.7%; Average loss: 3.8269
# Iteration: 2700; Percent complete: 6.8%; Average loss: 3.5732
# Iteration: 2710; Percent complete: 6.8%; Average loss: 3.9672
# Iteration: 2720; Percent complete: 6.8%; Average loss: 4.1351
# Iteration: 2730; Percent complete: 6.8%; Average loss: 3.2162
# Iteration: 2740; Percent complete: 6.9%; Average loss: 4.0832
# Iteration: 2750; Percent complete: 6.9%; Average loss: 3.9462
# Iteration: 2760; Percent complete: 6.9%; Average loss: 4.1228
# Iteration: 2770; Percent complete: 6.9%; Average loss: 4.6287
# Iteration: 2780; Percent complete: 7.0%; Average loss: 5.2821
# Iteration: 2790; Percent complete: 7.0%; Average loss: 3.5530
# Iteration: 2800; Percent complete: 7.0%; Average loss: 4.3144
# Iteration: 2810; Percent complete: 7.0%; Average loss: 4.0601
# Iteration: 2820; Percent complete: 7.0%; Average loss: 3.8729
# Iteration: 2830; Percent complete: 7.1%; Average loss: 3.8553
# Iteration: 2840; Percent complete: 7.1%; Average loss: 3.8615
# Iteration: 2850; Percent complete: 7.1%; Average loss: 4.1399
# Iteration: 2860; Percent complete: 7.1%; Average loss: 4.3953
# Iteration: 2870; Percent complete: 7.2%; Average loss: 3.4123
# Iteration: 2880; Percent complete: 7.2%; Average loss: 4.5703
# Iteration: 2890; Percent complete: 7.2%; Average loss: 3.2667
# Iteration: 2900; Percent complete: 7.2%; Average loss: 3.7344
# Iteration: 2910; Percent complete: 7.3%; Average loss: 4.5154
# Iteration: 2920; Percent complete: 7.3%; Average loss: 3.6766
# Iteration: 2930; Percent complete: 7.3%; Average loss: 3.0980
# Iteration: 2940; Percent complete: 7.3%; Average loss: 4.4105
# Iteration: 2950; Percent complete: 7.4%; Average loss: 3.2761
# Iteration: 2960; Percent complete: 7.4%; Average loss: 4.8718
# Iteration: 2970; Percent complete: 7.4%; Average loss: 3.6149
# Iteration: 2980; Percent complete: 7.4%; Average loss: 4.1598
# Iteration: 2990; Percent complete: 7.5%; Average loss: 4.2193
# Iteration: 3000; Percent complete: 7.5%; Average loss: 3.9608
# Iteration: 3010; Percent complete: 7.5%; Average loss: 3.7051
# Iteration: 3020; Percent complete: 7.5%; Average loss: 3.9970
# Iteration: 3030; Percent complete: 7.6%; Average loss: 4.1694
# Iteration: 3040; Percent complete: 7.6%; Average loss: 4.4383
# Iteration: 3050; Percent complete: 7.6%; Average loss: 3.7834
# Iteration: 3060; Percent complete: 7.6%; Average loss: 4.2694
# Iteration: 3070; Percent complete: 7.7%; Average loss: 4.3978
# Iteration: 3080; Percent complete: 7.7%; Average loss: 4.0951
# Iteration: 3090; Percent complete: 7.7%; Average loss: 4.3122
# Iteration: 3100; Percent complete: 7.8%; Average loss: 3.2952
# Iteration: 3110; Percent complete: 7.8%; Average loss: 3.7051
# Iteration: 3120; Percent complete: 7.8%; Average loss: 3.5840
# Iteration: 3130; Percent complete: 7.8%; Average loss: 4.1426
# Iteration: 3140; Percent complete: 7.8%; Average loss: 2.8248
# Iteration: 3150; Percent complete: 7.9%; Average loss: 3.6531
# Iteration: 3160; Percent complete: 7.9%; Average loss: 3.4329
# Iteration: 3170; Percent complete: 7.9%; Average loss: 4.2199
# Iteration: 3180; Percent complete: 8.0%; Average loss: 3.6164
# Iteration: 3190; Percent complete: 8.0%; Average loss: 3.2215
# Iteration: 3200; Percent complete: 8.0%; Average loss: 4.0830
# Iteration: 3210; Percent complete: 8.0%; Average loss: 3.9059
# Iteration: 3220; Percent complete: 8.1%; Average loss: 3.9724
# Iteration: 3230; Percent complete: 8.1%; Average loss: 3.6389
# Iteration: 3240; Percent complete: 8.1%; Average loss: 3.9475
# Iteration: 3250; Percent complete: 8.1%; Average loss: 4.1819
# Iteration: 3260; Percent complete: 8.2%; Average loss: 4.1068
# Iteration: 3270; Percent complete: 8.2%; Average loss: 3.9445
# Iteration: 3280; Percent complete: 8.2%; Average loss: 3.9590
# Iteration: 3290; Percent complete: 8.2%; Average loss: 3.9009
# Iteration: 3300; Percent complete: 8.2%; Average loss: 4.2556
# Iteration: 3310; Percent complete: 8.3%; Average loss: 4.5362
# Iteration: 3320; Percent complete: 8.3%; Average loss: 4.2325
# Iteration: 3330; Percent complete: 8.3%; Average loss: 4.6545
# Iteration: 3340; Percent complete: 8.3%; Average loss: 3.8447
# Iteration: 3350; Percent complete: 8.4%; Average loss: 3.9525
# Iteration: 3360; Percent complete: 8.4%; Average loss: 4.2698
# Iteration: 3370; Percent complete: 8.4%; Average loss: 3.5414
# Iteration: 3380; Percent complete: 8.5%; Average loss: 3.5862
# Iteration: 3390; Percent complete: 8.5%; Average loss: 3.7409
# Iteration: 3400; Percent complete: 8.5%; Average loss: 3.7780
# Iteration: 3410; Percent complete: 8.5%; Average loss: 4.1482
# Iteration: 3420; Percent complete: 8.6%; Average loss: 2.9435
# Iteration: 3430; Percent complete: 8.6%; Average loss: 3.8803
# Iteration: 3440; Percent complete: 8.6%; Average loss: 3.1763
# Iteration: 3450; Percent complete: 8.6%; Average loss: 4.7991
# Iteration: 3460; Percent complete: 8.6%; Average loss: 4.0705
# Iteration: 3470; Percent complete: 8.7%; Average loss: 4.4033
# Iteration: 3480; Percent complete: 8.7%; Average loss: 3.7742
# Iteration: 3490; Percent complete: 8.7%; Average loss: 3.1653
# Iteration: 3500; Percent complete: 8.8%; Average loss: 4.9739
# Iteration: 3510; Percent complete: 8.8%; Average loss: 4.0655
# Iteration: 3520; Percent complete: 8.8%; Average loss: 4.6604
# Iteration: 3530; Percent complete: 8.8%; Average loss: 3.9286
# Iteration: 3540; Percent complete: 8.8%; Average loss: 3.9383
# Iteration: 3550; Percent complete: 8.9%; Average loss: 4.0312
# Iteration: 3560; Percent complete: 8.9%; Average loss: 4.7961
# Iteration: 3570; Percent complete: 8.9%; Average loss: 3.9865
# Iteration: 3580; Percent complete: 8.9%; Average loss: 4.3454
# Iteration: 3590; Percent complete: 9.0%; Average loss: 4.7406
# Iteration: 3600; Percent complete: 9.0%; Average loss: 4.6970
# Iteration: 3610; Percent complete: 9.0%; Average loss: 4.5884
# Iteration: 3620; Percent complete: 9.0%; Average loss: 4.1755
# Iteration: 3630; Percent complete: 9.1%; Average loss: 3.8693
# Iteration: 3640; Percent complete: 9.1%; Average loss: 4.3077
# Iteration: 3650; Percent complete: 9.1%; Average loss: 4.1795
# Iteration: 3660; Percent complete: 9.2%; Average loss: 4.4002
# Iteration: 3670; Percent complete: 9.2%; Average loss: 4.7123
# Iteration: 3680; Percent complete: 9.2%; Average loss: 3.9504
# Iteration: 3690; Percent complete: 9.2%; Average loss: 3.8236
# Iteration: 3700; Percent complete: 9.2%; Average loss: 3.5452
# Iteration: 3710; Percent complete: 9.3%; Average loss: 4.4213
# Iteration: 3720; Percent complete: 9.3%; Average loss: 4.6605
# Iteration: 3730; Percent complete: 9.3%; Average loss: 3.7906
# Iteration: 3740; Percent complete: 9.3%; Average loss: 4.7532
# Iteration: 3750; Percent complete: 9.4%; Average loss: 3.9045
# Iteration: 3760; Percent complete: 9.4%; Average loss: 4.7193
# Iteration: 3770; Percent complete: 9.4%; Average loss: 4.1298
# Iteration: 3780; Percent complete: 9.4%; Average loss: 4.2288
# Iteration: 3790; Percent complete: 9.5%; Average loss: 4.2368
# Iteration: 3800; Percent complete: 9.5%; Average loss: 3.5838
# Iteration: 3810; Percent complete: 9.5%; Average loss: 4.1953
# Iteration: 3820; Percent complete: 9.6%; Average loss: 3.7560
# Iteration: 3830; Percent complete: 9.6%; Average loss: 3.6650
# Iteration: 3840; Percent complete: 9.6%; Average loss: 3.6859
# Iteration: 3850; Percent complete: 9.6%; Average loss: 4.3311
# Iteration: 3860; Percent complete: 9.7%; Average loss: 3.5293
# Iteration: 3870; Percent complete: 9.7%; Average loss: 3.5916
# Iteration: 3880; Percent complete: 9.7%; Average loss: 4.7073
# Iteration: 3890; Percent complete: 9.7%; Average loss: 3.8319
# Iteration: 3900; Percent complete: 9.8%; Average loss: 4.6634
# Iteration: 3910; Percent complete: 9.8%; Average loss: 3.4520
# Iteration: 3920; Percent complete: 9.8%; Average loss: 4.0488
# Iteration: 3930; Percent complete: 9.8%; Average loss: 3.1194
# Iteration: 3940; Percent complete: 9.8%; Average loss: 4.0094
# Iteration: 3950; Percent complete: 9.9%; Average loss: 4.3447
# Iteration: 3960; Percent complete: 9.9%; Average loss: 4.1489
# Iteration: 3970; Percent complete: 9.9%; Average loss: 4.9055
# Iteration: 3980; Percent complete: 10.0%; Average loss: 3.7638
# Iteration: 3990; Percent complete: 10.0%; Average loss: 3.6911
# Iteration: 4000; Percent complete: 10.0%; Average loss: 4.1882
# Iteration: 4010; Percent complete: 10.0%; Average loss: 3.6326
# Iteration: 4020; Percent complete: 10.1%; Average loss: 4.4578
# Iteration: 4030; Percent complete: 10.1%; Average loss: 3.5478
# Iteration: 4040; Percent complete: 10.1%; Average loss: 4.0998
# Iteration: 4050; Percent complete: 10.1%; Average loss: 3.7021
# Iteration: 4060; Percent complete: 10.2%; Average loss: 3.9120
# Iteration: 4070; Percent complete: 10.2%; Average loss: 3.5857
# Iteration: 4080; Percent complete: 10.2%; Average loss: 3.2961
# Iteration: 4090; Percent complete: 10.2%; Average loss: 4.3488
# Iteration: 4100; Percent complete: 10.2%; Average loss: 3.8621
# Iteration: 4110; Percent complete: 10.3%; Average loss: 3.7977
# Iteration: 4120; Percent complete: 10.3%; Average loss: 3.8275
# Iteration: 4130; Percent complete: 10.3%; Average loss: 3.2123
# Iteration: 4140; Percent complete: 10.3%; Average loss: 3.7906
# Iteration: 4150; Percent complete: 10.4%; Average loss: 4.4006
# Iteration: 4160; Percent complete: 10.4%; Average loss: 3.2112
# Iteration: 4170; Percent complete: 10.4%; Average loss: 3.3953
# Iteration: 4180; Percent complete: 10.4%; Average loss: 4.2443
# Iteration: 4190; Percent complete: 10.5%; Average loss: 4.2044
# Iteration: 4200; Percent complete: 10.5%; Average loss: 4.4108
# Iteration: 4210; Percent complete: 10.5%; Average loss: 5.1551
# Iteration: 4220; Percent complete: 10.5%; Average loss: 4.1956
# Iteration: 4230; Percent complete: 10.6%; Average loss: 3.7885
# Iteration: 4240; Percent complete: 10.6%; Average loss: 4.1997
# Iteration: 4250; Percent complete: 10.6%; Average loss: 5.1240
# Iteration: 4260; Percent complete: 10.7%; Average loss: 4.3975
# Iteration: 4270; Percent complete: 10.7%; Average loss: 4.4248
# Iteration: 4280; Percent complete: 10.7%; Average loss: 4.4575
# Iteration: 4290; Percent complete: 10.7%; Average loss: 4.0440
# Iteration: 4300; Percent complete: 10.8%; Average loss: 4.3255
# Iteration: 4310; Percent complete: 10.8%; Average loss: 4.0194
# Iteration: 4320; Percent complete: 10.8%; Average loss: 4.2608
# Iteration: 4330; Percent complete: 10.8%; Average loss: 3.9905
# Iteration: 4340; Percent complete: 10.8%; Average loss: 3.1994
# Iteration: 4350; Percent complete: 10.9%; Average loss: 3.6488
# Iteration: 4360; Percent complete: 10.9%; Average loss: 2.9378
# Iteration: 4370; Percent complete: 10.9%; Average loss: 4.6493
# Iteration: 4380; Percent complete: 10.9%; Average loss: 3.7887
# Iteration: 4390; Percent complete: 11.0%; Average loss: 3.7501
# Iteration: 4400; Percent complete: 11.0%; Average loss: 4.0503
# Iteration: 4410; Percent complete: 11.0%; Average loss: 3.2275
# Iteration: 4420; Percent complete: 11.1%; Average loss: 3.7682
# Iteration: 4430; Percent complete: 11.1%; Average loss: 3.6905
# Iteration: 4440; Percent complete: 11.1%; Average loss: 3.9102
# Iteration: 4450; Percent complete: 11.1%; Average loss: 3.9431
# Iteration: 4460; Percent complete: 11.2%; Average loss: 3.6168
# Iteration: 4470; Percent complete: 11.2%; Average loss: 4.0949
# Iteration: 4480; Percent complete: 11.2%; Average loss: 4.4707
# Iteration: 4490; Percent complete: 11.2%; Average loss: 3.0552
# Iteration: 4500; Percent complete: 11.2%; Average loss: 3.5874
# Iteration: 4510; Percent complete: 11.3%; Average loss: 3.9438
# Iteration: 4520; Percent complete: 11.3%; Average loss: 3.4124
# Iteration: 4530; Percent complete: 11.3%; Average loss: 3.6327
# Iteration: 4540; Percent complete: 11.3%; Average loss: 3.9881
# Iteration: 4550; Percent complete: 11.4%; Average loss: 3.6702
# Iteration: 4560; Percent complete: 11.4%; Average loss: 4.0795
# Iteration: 4570; Percent complete: 11.4%; Average loss: 3.5105
# Iteration: 4580; Percent complete: 11.5%; Average loss: 4.5109
# Iteration: 4590; Percent complete: 11.5%; Average loss: 4.7398
# Iteration: 4600; Percent complete: 11.5%; Average loss: 4.4769
# Iteration: 4610; Percent complete: 11.5%; Average loss: 3.6500
# Iteration: 4620; Percent complete: 11.6%; Average loss: 3.4756
# Iteration: 4630; Percent complete: 11.6%; Average loss: 3.8100
# Iteration: 4640; Percent complete: 11.6%; Average loss: 3.9508
# Iteration: 4650; Percent complete: 11.6%; Average loss: 3.9909
# Iteration: 4660; Percent complete: 11.7%; Average loss: 3.6235
# Iteration: 4670; Percent complete: 11.7%; Average loss: 3.6554
# Iteration: 4680; Percent complete: 11.7%; Average loss: 3.9777
# Iteration: 4690; Percent complete: 11.7%; Average loss: 3.8543
# Iteration: 4700; Percent complete: 11.8%; Average loss: 4.5027
# Iteration: 4710; Percent complete: 11.8%; Average loss: 5.2335
# Iteration: 4720; Percent complete: 11.8%; Average loss: 4.5150
# Iteration: 4730; Percent complete: 11.8%; Average loss: 4.1279
# Iteration: 4740; Percent complete: 11.8%; Average loss: 3.3819
# Iteration: 4750; Percent complete: 11.9%; Average loss: 3.1261
# Iteration: 4760; Percent complete: 11.9%; Average loss: 3.4646
# Iteration: 4770; Percent complete: 11.9%; Average loss: 4.2838
# Iteration: 4780; Percent complete: 11.9%; Average loss: 4.2545
# Iteration: 4790; Percent complete: 12.0%; Average loss: 3.0768
# Iteration: 4800; Percent complete: 12.0%; Average loss: 3.9455
# Iteration: 4810; Percent complete: 12.0%; Average loss: 3.6821
# Iteration: 4820; Percent complete: 12.0%; Average loss: 3.6532
# Iteration: 4830; Percent complete: 12.1%; Average loss: 3.2524
# Iteration: 4840; Percent complete: 12.1%; Average loss: 3.4551
# Iteration: 4850; Percent complete: 12.1%; Average loss: 3.4502
# Iteration: 4860; Percent complete: 12.2%; Average loss: 5.2937
# Iteration: 4870; Percent complete: 12.2%; Average loss: 3.6502
# Iteration: 4880; Percent complete: 12.2%; Average loss: 3.7882
# Iteration: 4890; Percent complete: 12.2%; Average loss: 3.9026
# Iteration: 4900; Percent complete: 12.2%; Average loss: 4.2621
# Iteration: 4910; Percent complete: 12.3%; Average loss: 4.2265
# Iteration: 4920; Percent complete: 12.3%; Average loss: 4.4737
# Iteration: 4930; Percent complete: 12.3%; Average loss: 3.6190
# Iteration: 4940; Percent complete: 12.3%; Average loss: 3.5391
# Iteration: 4950; Percent complete: 12.4%; Average loss: 4.1524
# Iteration: 4960; Percent complete: 12.4%; Average loss: 3.9566
# Iteration: 4970; Percent complete: 12.4%; Average loss: 3.8919
# Iteration: 4980; Percent complete: 12.4%; Average loss: 4.5467
# Iteration: 4990; Percent complete: 12.5%; Average loss: 4.1083
# Iteration: 5000; Percent complete: 12.5%; Average loss: 4.4191
# Iteration: 5010; Percent complete: 12.5%; Average loss: 3.6483
# Iteration: 5020; Percent complete: 12.6%; Average loss: 4.0314
# Iteration: 5030; Percent complete: 12.6%; Average loss: 3.7805
# Iteration: 5040; Percent complete: 12.6%; Average loss: 4.5976
# Iteration: 5050; Percent complete: 12.6%; Average loss: 4.0534
# Iteration: 5060; Percent complete: 12.7%; Average loss: 4.2044
# Iteration: 5070; Percent complete: 12.7%; Average loss: 4.1633
# Iteration: 5080; Percent complete: 12.7%; Average loss: 4.3211
# Iteration: 5090; Percent complete: 12.7%; Average loss: 4.2721
# Iteration: 5100; Percent complete: 12.8%; Average loss: 3.7367
# Iteration: 5110; Percent complete: 12.8%; Average loss: 3.7822
# Iteration: 5120; Percent complete: 12.8%; Average loss: 4.4475
# Iteration: 5130; Percent complete: 12.8%; Average loss: 3.9513
# Iteration: 5140; Percent complete: 12.8%; Average loss: 3.3231
# Iteration: 5150; Percent complete: 12.9%; Average loss: 3.9632
# Iteration: 5160; Percent complete: 12.9%; Average loss: 4.6958
# Iteration: 5170; Percent complete: 12.9%; Average loss: 3.8325
# Iteration: 5180; Percent complete: 13.0%; Average loss: 3.4826
# Iteration: 5190; Percent complete: 13.0%; Average loss: 3.9680
# Iteration: 5200; Percent complete: 13.0%; Average loss: 3.4277
# Iteration: 5210; Percent complete: 13.0%; Average loss: 3.7691
# Iteration: 5220; Percent complete: 13.1%; Average loss: 4.1071
# Iteration: 5230; Percent complete: 13.1%; Average loss: 3.9330
# Iteration: 5240; Percent complete: 13.1%; Average loss: 3.4916
# Iteration: 5250; Percent complete: 13.1%; Average loss: 4.2622
# Iteration: 5260; Percent complete: 13.2%; Average loss: 3.9123
# Iteration: 5270; Percent complete: 13.2%; Average loss: 4.9496
# Iteration: 5280; Percent complete: 13.2%; Average loss: 4.4438
# Iteration: 5290; Percent complete: 13.2%; Average loss: 4.2225
# Iteration: 5300; Percent complete: 13.2%; Average loss: 3.5140
# Iteration: 5310; Percent complete: 13.3%; Average loss: 3.9340
# Iteration: 5320; Percent complete: 13.3%; Average loss: 4.0355
# Iteration: 5330; Percent complete: 13.3%; Average loss: 4.9776
# Iteration: 5340; Percent complete: 13.4%; Average loss: 4.1712
# Iteration: 5350; Percent complete: 13.4%; Average loss: 3.0329
# Iteration: 5360; Percent complete: 13.4%; Average loss: 4.0892
# Iteration: 5370; Percent complete: 13.4%; Average loss: 4.5604
# Iteration: 5380; Percent complete: 13.5%; Average loss: 3.3057
# Iteration: 5390; Percent complete: 13.5%; Average loss: 4.2212
# Iteration: 5400; Percent complete: 13.5%; Average loss: 4.5601
# Iteration: 5410; Percent complete: 13.5%; Average loss: 4.1941
# Iteration: 5420; Percent complete: 13.6%; Average loss: 3.6876
# Iteration: 5430; Percent complete: 13.6%; Average loss: 3.4843
# Iteration: 5440; Percent complete: 13.6%; Average loss: 4.1346
# Iteration: 5450; Percent complete: 13.6%; Average loss: 3.8226
# Iteration: 5460; Percent complete: 13.7%; Average loss: 4.1768
# Iteration: 5470; Percent complete: 13.7%; Average loss: 3.3428
# Iteration: 5480; Percent complete: 13.7%; Average loss: 4.5676
# Iteration: 5490; Percent complete: 13.7%; Average loss: 3.7796
# Iteration: 5500; Percent complete: 13.8%; Average loss: 3.3448
# Iteration: 5510; Percent complete: 13.8%; Average loss: 3.5679
# Iteration: 5520; Percent complete: 13.8%; Average loss: 4.5142
# Iteration: 5530; Percent complete: 13.8%; Average loss: 4.5913
# Iteration: 5540; Percent complete: 13.9%; Average loss: 3.9625
# Iteration: 5550; Percent complete: 13.9%; Average loss: 4.4116
# Iteration: 5560; Percent complete: 13.9%; Average loss: 3.9530
# Iteration: 5570; Percent complete: 13.9%; Average loss: 3.6398
# Iteration: 5580; Percent complete: 14.0%; Average loss: 4.1315
# Iteration: 5590; Percent complete: 14.0%; Average loss: 4.1851
# Iteration: 5600; Percent complete: 14.0%; Average loss: 2.8946
# Iteration: 5610; Percent complete: 14.0%; Average loss: 3.9331
# Iteration: 5620; Percent complete: 14.1%; Average loss: 3.5721
# Iteration: 5630; Percent complete: 14.1%; Average loss: 4.6516
# Iteration: 5640; Percent complete: 14.1%; Average loss: 3.7381
# Iteration: 5650; Percent complete: 14.1%; Average loss: 4.1561
# Iteration: 5660; Percent complete: 14.1%; Average loss: 3.7420
# Iteration: 5670; Percent complete: 14.2%; Average loss: 3.4910
# Iteration: 5680; Percent complete: 14.2%; Average loss: 3.8654
# Iteration: 5690; Percent complete: 14.2%; Average loss: 4.8611
# Iteration: 5700; Percent complete: 14.2%; Average loss: 4.4513
# Iteration: 5710; Percent complete: 14.3%; Average loss: 3.7146
# Iteration: 5720; Percent complete: 14.3%; Average loss: 3.2136
# Iteration: 5730; Percent complete: 14.3%; Average loss: 3.7460
# Iteration: 5740; Percent complete: 14.3%; Average loss: 4.0048
# Iteration: 5750; Percent complete: 14.4%; Average loss: 3.9916
# Iteration: 5760; Percent complete: 14.4%; Average loss: 3.9382
# Iteration: 5770; Percent complete: 14.4%; Average loss: 3.5660
# Iteration: 5780; Percent complete: 14.4%; Average loss: 3.9618
# Iteration: 5790; Percent complete: 14.5%; Average loss: 3.5740
# Iteration: 5800; Percent complete: 14.5%; Average loss: 4.3452
# Iteration: 5810; Percent complete: 14.5%; Average loss: 3.5472
# Iteration: 5820; Percent complete: 14.5%; Average loss: 4.5943
# Iteration: 5830; Percent complete: 14.6%; Average loss: 4.9588
# Iteration: 5840; Percent complete: 14.6%; Average loss: 4.1976
# Iteration: 5850; Percent complete: 14.6%; Average loss: 3.8351
# Iteration: 5860; Percent complete: 14.6%; Average loss: 4.0236
# Iteration: 5870; Percent complete: 14.7%; Average loss: 4.8476
# Iteration: 5880; Percent complete: 14.7%; Average loss: 3.6970
# Iteration: 5890; Percent complete: 14.7%; Average loss: 4.3213
# Iteration: 5900; Percent complete: 14.8%; Average loss: 3.3143
# Iteration: 5910; Percent complete: 14.8%; Average loss: 3.4674
# Iteration: 5920; Percent complete: 14.8%; Average loss: 3.8949
# Iteration: 5930; Percent complete: 14.8%; Average loss: 4.2860
# Iteration: 5940; Percent complete: 14.8%; Average loss: 3.5001
# Iteration: 5950; Percent complete: 14.9%; Average loss: 3.3319
# Iteration: 5960; Percent complete: 14.9%; Average loss: 4.0623
# Iteration: 5970; Percent complete: 14.9%; Average loss: 3.7853
# Iteration: 5980; Percent complete: 14.9%; Average loss: 4.2535
# Iteration: 5990; Percent complete: 15.0%; Average loss: 4.3030
# Iteration: 6000; Percent complete: 15.0%; Average loss: 4.0118
# Iteration: 6010; Percent complete: 15.0%; Average loss: 3.6214
# Iteration: 6020; Percent complete: 15.0%; Average loss: 3.8348
# Iteration: 6030; Percent complete: 15.1%; Average loss: 4.5739
# Iteration: 6040; Percent complete: 15.1%; Average loss: 4.3484
# Iteration: 6050; Percent complete: 15.1%; Average loss: 4.0065
# Iteration: 6060; Percent complete: 15.2%; Average loss: 3.8137
# Iteration: 6070; Percent complete: 15.2%; Average loss: 3.8183
# Iteration: 6080; Percent complete: 15.2%; Average loss: 4.3403
# Iteration: 6090; Percent complete: 15.2%; Average loss: 4.2738
# Iteration: 6100; Percent complete: 15.2%; Average loss: 4.4519
# Iteration: 6110; Percent complete: 15.3%; Average loss: 3.4721
# Iteration: 6120; Percent complete: 15.3%; Average loss: 3.3963
# Iteration: 6130; Percent complete: 15.3%; Average loss: 3.9173
# Iteration: 6140; Percent complete: 15.3%; Average loss: 4.3709
# Iteration: 6150; Percent complete: 15.4%; Average loss: 3.9650
# Iteration: 6160; Percent complete: 15.4%; Average loss: 3.9970
# Iteration: 6170; Percent complete: 15.4%; Average loss: 3.7797
# Iteration: 6180; Percent complete: 15.4%; Average loss: 4.0107
# Iteration: 6190; Percent complete: 15.5%; Average loss: 3.8232
# Iteration: 6200; Percent complete: 15.5%; Average loss: 4.2350
# Iteration: 6210; Percent complete: 15.5%; Average loss: 4.4560
# Iteration: 6220; Percent complete: 15.6%; Average loss: 4.0962
# Iteration: 6230; Percent complete: 15.6%; Average loss: 4.0354
# Iteration: 6240; Percent complete: 15.6%; Average loss: 3.8310
# Iteration: 6250; Percent complete: 15.6%; Average loss: 4.4608
# Iteration: 6260; Percent complete: 15.7%; Average loss: 4.4358
# Iteration: 6270; Percent complete: 15.7%; Average loss: 2.7926
# Iteration: 6280; Percent complete: 15.7%; Average loss: 3.5182
# Iteration: 6290; Percent complete: 15.7%; Average loss: 4.6682
# Iteration: 6300; Percent complete: 15.8%; Average loss: 3.9871
# Iteration: 6310; Percent complete: 15.8%; Average loss: 4.0030
# Iteration: 6320; Percent complete: 15.8%; Average loss: 3.4174
# Iteration: 6330; Percent complete: 15.8%; Average loss: 4.5107
# Iteration: 6340; Percent complete: 15.8%; Average loss: 3.3197
# Iteration: 6350; Percent complete: 15.9%; Average loss: 3.2817
# Iteration: 6360; Percent complete: 15.9%; Average loss: 3.8633
# Iteration: 6370; Percent complete: 15.9%; Average loss: 4.0600
# Iteration: 6380; Percent complete: 16.0%; Average loss: 3.5943
# Iteration: 6390; Percent complete: 16.0%; Average loss: 4.4146
# Iteration: 6400; Percent complete: 16.0%; Average loss: 4.5560
# Iteration: 6410; Percent complete: 16.0%; Average loss: 4.5715
# Iteration: 6420; Percent complete: 16.1%; Average loss: 3.8559
# Iteration: 6430; Percent complete: 16.1%; Average loss: 4.2599
# Iteration: 6440; Percent complete: 16.1%; Average loss: 3.3160
# Iteration: 6450; Percent complete: 16.1%; Average loss: 4.1351
# Iteration: 6460; Percent complete: 16.2%; Average loss: 3.1771
# Iteration: 6470; Percent complete: 16.2%; Average loss: 3.3117
# Iteration: 6480; Percent complete: 16.2%; Average loss: 4.1972
# Iteration: 6490; Percent complete: 16.2%; Average loss: 3.9831
# Iteration: 6500; Percent complete: 16.2%; Average loss: 4.8180
# Iteration: 6510; Percent complete: 16.3%; Average loss: 3.9558
# Iteration: 6520; Percent complete: 16.3%; Average loss: 4.0814
# Iteration: 6530; Percent complete: 16.3%; Average loss: 4.0885
# Iteration: 6540; Percent complete: 16.4%; Average loss: 4.2265
# Iteration: 6550; Percent complete: 16.4%; Average loss: 4.2311
# Iteration: 6560; Percent complete: 16.4%; Average loss: 4.4696
# Iteration: 6570; Percent complete: 16.4%; Average loss: 4.2371
# Iteration: 6580; Percent complete: 16.4%; Average loss: 4.6768
# Iteration: 6590; Percent complete: 16.5%; Average loss: 4.2472
# Iteration: 6600; Percent complete: 16.5%; Average loss: 4.1508
# Iteration: 6610; Percent complete: 16.5%; Average loss: 4.6037
# Iteration: 6620; Percent complete: 16.6%; Average loss: 3.8566
# Iteration: 6630; Percent complete: 16.6%; Average loss: 4.9366
# Iteration: 6640; Percent complete: 16.6%; Average loss: 3.9530
# Iteration: 6650; Percent complete: 16.6%; Average loss: 4.0784
# Iteration: 6660; Percent complete: 16.7%; Average loss: 3.6124
# Iteration: 6670; Percent complete: 16.7%; Average loss: 4.2863
# Iteration: 6680; Percent complete: 16.7%; Average loss: 4.1811
# Iteration: 6690; Percent complete: 16.7%; Average loss: 4.1992
# Iteration: 6700; Percent complete: 16.8%; Average loss: 3.7818
# Iteration: 6710; Percent complete: 16.8%; Average loss: 3.8730
# Iteration: 6720; Percent complete: 16.8%; Average loss: 4.1279
# Iteration: 6730; Percent complete: 16.8%; Average loss: 3.8893
# Iteration: 6740; Percent complete: 16.9%; Average loss: 3.8861
# Iteration: 6750; Percent complete: 16.9%; Average loss: 3.8075
# Iteration: 6760; Percent complete: 16.9%; Average loss: 3.5724
# Iteration: 6770; Percent complete: 16.9%; Average loss: 3.8463
# Iteration: 6780; Percent complete: 17.0%; Average loss: 3.8783
# Iteration: 6790; Percent complete: 17.0%; Average loss: 4.2033
# Iteration: 6800; Percent complete: 17.0%; Average loss: 3.3901
# Iteration: 6810; Percent complete: 17.0%; Average loss: 4.4569
# Iteration: 6820; Percent complete: 17.1%; Average loss: 3.9842
# Iteration: 6830; Percent complete: 17.1%; Average loss: 3.6061
# Iteration: 6840; Percent complete: 17.1%; Average loss: 3.9344
# Iteration: 6850; Percent complete: 17.1%; Average loss: 4.6465
# Iteration: 6860; Percent complete: 17.2%; Average loss: 4.5623
# Iteration: 6870; Percent complete: 17.2%; Average loss: 3.6122
# Iteration: 6880; Percent complete: 17.2%; Average loss: 3.7829
# Iteration: 6890; Percent complete: 17.2%; Average loss: 4.0943
# Iteration: 6900; Percent complete: 17.2%; Average loss: 4.3871
# Iteration: 6910; Percent complete: 17.3%; Average loss: 3.4722
# Iteration: 6920; Percent complete: 17.3%; Average loss: 3.6214
# Iteration: 6930; Percent complete: 17.3%; Average loss: 3.6405
# Iteration: 6940; Percent complete: 17.3%; Average loss: 4.0381
# Iteration: 6950; Percent complete: 17.4%; Average loss: 4.1619
# Iteration: 6960; Percent complete: 17.4%; Average loss: 4.1272
# Iteration: 6970; Percent complete: 17.4%; Average loss: 4.0686
# Iteration: 6980; Percent complete: 17.4%; Average loss: 4.1266
# Iteration: 6990; Percent complete: 17.5%; Average loss: 4.7209
# Iteration: 7000; Percent complete: 17.5%; Average loss: 4.1050
# Iteration: 7010; Percent complete: 17.5%; Average loss: 3.8858
# Iteration: 7020; Percent complete: 17.5%; Average loss: 4.2329
# Iteration: 7030; Percent complete: 17.6%; Average loss: 4.0420
# Iteration: 7040; Percent complete: 17.6%; Average loss: 4.2217
# Iteration: 7050; Percent complete: 17.6%; Average loss: 4.4442
# Iteration: 7060; Percent complete: 17.6%; Average loss: 3.8010
# Iteration: 7070; Percent complete: 17.7%; Average loss: 4.4328
# Iteration: 7080; Percent complete: 17.7%; Average loss: 3.6365
# Iteration: 7090; Percent complete: 17.7%; Average loss: 4.0404
# Iteration: 7100; Percent complete: 17.8%; Average loss: 3.6079
# Iteration: 7110; Percent complete: 17.8%; Average loss: 4.0181
# Iteration: 7120; Percent complete: 17.8%; Average loss: 3.7381
# Iteration: 7130; Percent complete: 17.8%; Average loss: 3.6085
# Iteration: 7140; Percent complete: 17.8%; Average loss: 4.1161
# Iteration: 7150; Percent complete: 17.9%; Average loss: 3.0646
# Iteration: 7160; Percent complete: 17.9%; Average loss: 3.5885
# Iteration: 7170; Percent complete: 17.9%; Average loss: 4.3094
# Iteration: 7180; Percent complete: 17.9%; Average loss: 4.7925
# Iteration: 7190; Percent complete: 18.0%; Average loss: 4.3946
# Iteration: 7200; Percent complete: 18.0%; Average loss: 4.3930
# Iteration: 7210; Percent complete: 18.0%; Average loss: 4.8724
# Iteration: 7220; Percent complete: 18.1%; Average loss: 4.6915
# Iteration: 7230; Percent complete: 18.1%; Average loss: 3.6659
# Iteration: 7240; Percent complete: 18.1%; Average loss: 3.9864
# Iteration: 7250; Percent complete: 18.1%; Average loss: 4.0188
# Iteration: 7260; Percent complete: 18.1%; Average loss: 4.1250
# Iteration: 7270; Percent complete: 18.2%; Average loss: 3.9319
# Iteration: 7280; Percent complete: 18.2%; Average loss: 3.4160
# Iteration: 7290; Percent complete: 18.2%; Average loss: 4.1245
# Iteration: 7300; Percent complete: 18.2%; Average loss: 4.5178
# Iteration: 7310; Percent complete: 18.3%; Average loss: 3.7286
# Iteration: 7320; Percent complete: 18.3%; Average loss: 3.5586
# Iteration: 7330; Percent complete: 18.3%; Average loss: 4.0346
# Iteration: 7340; Percent complete: 18.4%; Average loss: 3.5643
# Iteration: 7350; Percent complete: 18.4%; Average loss: 3.9170
# Iteration: 7360; Percent complete: 18.4%; Average loss: 3.6289
# Iteration: 7370; Percent complete: 18.4%; Average loss: 4.3999
# Iteration: 7380; Percent complete: 18.4%; Average loss: 3.8526
# Iteration: 7390; Percent complete: 18.5%; Average loss: 3.9437
# Iteration: 7400; Percent complete: 18.5%; Average loss: 4.0825
# Iteration: 7410; Percent complete: 18.5%; Average loss: 4.3131
# Iteration: 7420; Percent complete: 18.6%; Average loss: 3.9520
# Iteration: 7430; Percent complete: 18.6%; Average loss: 3.8734
# Iteration: 7440; Percent complete: 18.6%; Average loss: 3.8198
# Iteration: 7450; Percent complete: 18.6%; Average loss: 4.1048
# Iteration: 7460; Percent complete: 18.6%; Average loss: 3.7764
# Iteration: 7470; Percent complete: 18.7%; Average loss: 3.7465
# Iteration: 7480; Percent complete: 18.7%; Average loss: 3.1641
# Iteration: 7490; Percent complete: 18.7%; Average loss: 3.7157
# Iteration: 7500; Percent complete: 18.8%; Average loss: 3.6870
# Iteration: 7510; Percent complete: 18.8%; Average loss: 3.6218
# Iteration: 7520; Percent complete: 18.8%; Average loss: 4.1862
# Iteration: 7530; Percent complete: 18.8%; Average loss: 4.0083
# Iteration: 7540; Percent complete: 18.9%; Average loss: 4.2483
# Iteration: 7550; Percent complete: 18.9%; Average loss: 3.8464
# Iteration: 7560; Percent complete: 18.9%; Average loss: 3.3086
# Iteration: 7570; Percent complete: 18.9%; Average loss: 3.3516
# Iteration: 7580; Percent complete: 18.9%; Average loss: 4.0990
# Iteration: 7590; Percent complete: 19.0%; Average loss: 3.7875
# Iteration: 7600; Percent complete: 19.0%; Average loss: 4.2487
# Iteration: 7610; Percent complete: 19.0%; Average loss: 3.0618
# Iteration: 7620; Percent complete: 19.1%; Average loss: 3.8974
# Iteration: 7630; Percent complete: 19.1%; Average loss: 2.9121
# Iteration: 7640; Percent complete: 19.1%; Average loss: 4.1109
# Iteration: 7650; Percent complete: 19.1%; Average loss: 4.4041
# Iteration: 7660; Percent complete: 19.1%; Average loss: 3.3257
# Iteration: 7670; Percent complete: 19.2%; Average loss: 4.6452
# ...
# Iteration: 37520; Percent complete: 93.8%; Average loss: 4.0361
# Iteration: 37530; Percent complete: 93.8%; Average loss: 3.5612
# Iteration: 37540; Percent complete: 93.8%; Average loss: 3.7233
# Iteration: 37550; Percent complete: 93.9%; Average loss: 3.3828
# Iteration: 37560; Percent complete: 93.9%; Average loss: 3.8622
# Iteration: 37570; Percent complete: 93.9%; Average loss: 3.5218
# Iteration: 37580; Percent complete: 94.0%; Average loss: 3.0295
# Iteration: 37590; Percent complete: 94.0%; Average loss: 4.2224
# Iteration: 37600; Percent complete: 94.0%; Average loss: 3.4815
# Iteration: 37610; Percent complete: 94.0%; Average loss: 3.2885
# Iteration: 37620; Percent complete: 94.0%; Average loss: 2.9367
# Iteration: 37630; Percent complete: 94.1%; Average loss: 3.7098
# Iteration: 37640; Percent complete: 94.1%; Average loss: 3.2711
# Iteration: 37650; Percent complete: 94.1%; Average loss: 3.4348
# Iteration: 37660; Percent complete: 94.2%; Average loss: 3.9761
# Iteration: 37670; Percent complete: 94.2%; Average loss: 3.8301
# Iteration: 37680; Percent complete: 94.2%; Average loss: 3.8388
# Iteration: 37690; Percent complete: 94.2%; Average loss: 3.2601
# Iteration: 37700; Percent complete: 94.2%; Average loss: 2.8203
# Iteration: 37710; Percent complete: 94.3%; Average loss: 3.7956
# Iteration: 37720; Percent complete: 94.3%; Average loss: 3.3831
# Iteration: 37730; Percent complete: 94.3%; Average loss: 4.1820
# Iteration: 37740; Percent complete: 94.3%; Average loss: 3.7297
# Iteration: 37750; Percent complete: 94.4%; Average loss: 3.0783
# Iteration: 37760; Percent complete: 94.4%; Average loss: 3.7442
# Iteration: 37770; Percent complete: 94.4%; Average loss: 2.7970
# Iteration: 37780; Percent complete: 94.5%; Average loss: 4.0403
# Iteration: 37790; Percent complete: 94.5%; Average loss: 2.9031
# Iteration: 37800; Percent complete: 94.5%; Average loss: 3.1604
# Iteration: 37810; Percent complete: 94.5%; Average loss: 3.7403
# Iteration: 37820; Percent complete: 94.5%; Average loss: 3.2520
# Iteration: 37830; Percent complete: 94.6%; Average loss: 2.9474
# Iteration: 37840; Percent complete: 94.6%; Average loss: 3.4574
# Iteration: 37850; Percent complete: 94.6%; Average loss: 3.3107
# Iteration: 37860; Percent complete: 94.7%; Average loss: 3.3860
# Iteration: 37870; Percent complete: 94.7%; Average loss: 3.6472
# Iteration: 37880; Percent complete: 94.7%; Average loss: 3.2515
# Iteration: 37890; Percent complete: 94.7%; Average loss: 4.4903
# Iteration: 37900; Percent complete: 94.8%; Average loss: 2.9546
# Iteration: 37910; Percent complete: 94.8%; Average loss: 3.7326
# Iteration: 37920; Percent complete: 94.8%; Average loss: 3.8590
# Iteration: 37930; Percent complete: 94.8%; Average loss: 3.4431
# Iteration: 37940; Percent complete: 94.8%; Average loss: 3.8300
# Iteration: 37950; Percent complete: 94.9%; Average loss: 3.4034
# Iteration: 37960; Percent complete: 94.9%; Average loss: 3.5611
# Iteration: 37970; Percent complete: 94.9%; Average loss: 3.0913
# Iteration: 37980; Percent complete: 95.0%; Average loss: 3.9345
# Iteration: 37990; Percent complete: 95.0%; Average loss: 3.5999
# Iteration: 38000; Percent complete: 95.0%; Average loss: 2.6971
# Iteration: 38010; Percent complete: 95.0%; Average loss: 3.4264
# Iteration: 38020; Percent complete: 95.0%; Average loss: 4.1681
# Iteration: 38030; Percent complete: 95.1%; Average loss: 3.4067
# Iteration: 38040; Percent complete: 95.1%; Average loss: 3.6589
# Iteration: 38050; Percent complete: 95.1%; Average loss: 3.4964
# Iteration: 38060; Percent complete: 95.2%; Average loss: 3.3945
# Iteration: 38070; Percent complete: 95.2%; Average loss: 3.9724
# Iteration: 38080; Percent complete: 95.2%; Average loss: 4.3740
# Iteration: 38090; Percent complete: 95.2%; Average loss: 2.8989
# Iteration: 38100; Percent complete: 95.2%; Average loss: 4.9213
# Iteration: 38110; Percent complete: 95.3%; Average loss: 3.2842
# Iteration: 38120; Percent complete: 95.3%; Average loss: 3.1130
# Iteration: 38130; Percent complete: 95.3%; Average loss: 3.7341
# Iteration: 38140; Percent complete: 95.3%; Average loss: 3.3081
# Iteration: 38150; Percent complete: 95.4%; Average loss: 3.6620
# Iteration: 38160; Percent complete: 95.4%; Average loss: 4.1953
# Iteration: 38170; Percent complete: 95.4%; Average loss: 3.6836
# Iteration: 38180; Percent complete: 95.5%; Average loss: 3.2811
# Iteration: 38190; Percent complete: 95.5%; Average loss: 3.6346
# Iteration: 38200; Percent complete: 95.5%; Average loss: 3.0383
# Iteration: 38210; Percent complete: 95.5%; Average loss: 3.3107
# Iteration: 38220; Percent complete: 95.5%; Average loss: 3.5586
# Iteration: 38230; Percent complete: 95.6%; Average loss: 3.5754
# Iteration: 38240; Percent complete: 95.6%; Average loss: 2.8577
# Iteration: 38250; Percent complete: 95.6%; Average loss: 2.6051
# Iteration: 38260; Percent complete: 95.7%; Average loss: 2.6519
# Iteration: 38270; Percent complete: 95.7%; Average loss: 3.2061
# Iteration: 38280; Percent complete: 95.7%; Average loss: 4.0261
# Iteration: 38290; Percent complete: 95.7%; Average loss: 3.7350
# Iteration: 38300; Percent complete: 95.8%; Average loss: 4.9828
# Iteration: 38310; Percent complete: 95.8%; Average loss: 3.5465
# Iteration: 38320; Percent complete: 95.8%; Average loss: 3.4659
# Iteration: 38330; Percent complete: 95.8%; Average loss: 3.6711
# Iteration: 38340; Percent complete: 95.9%; Average loss: 3.3780
# Iteration: 38350; Percent complete: 95.9%; Average loss: 4.0594
# Iteration: 38360; Percent complete: 95.9%; Average loss: 3.4187
# Iteration: 38370; Percent complete: 95.9%; Average loss: 4.1793
# Iteration: 38380; Percent complete: 96.0%; Average loss: 3.0174
# Iteration: 38390; Percent complete: 96.0%; Average loss: 2.9179
# Iteration: 38400; Percent complete: 96.0%; Average loss: 3.8429
# Iteration: 38410; Percent complete: 96.0%; Average loss: 3.3967
# Iteration: 38420; Percent complete: 96.0%; Average loss: 3.5409
# Iteration: 38430; Percent complete: 96.1%; Average loss: 3.5114
# Iteration: 38440; Percent complete: 96.1%; Average loss: 3.3686
# Iteration: 38450; Percent complete: 96.1%; Average loss: 3.8338
# Iteration: 38460; Percent complete: 96.2%; Average loss: 3.7324
# Iteration: 38470; Percent complete: 96.2%; Average loss: 3.6723
# Iteration: 38480; Percent complete: 96.2%; Average loss: 3.8519
# Iteration: 38490; Percent complete: 96.2%; Average loss: 3.1034
# Iteration: 38500; Percent complete: 96.2%; Average loss: 3.4356
# Iteration: 38510; Percent complete: 96.3%; Average loss: 3.7391
# Iteration: 38520; Percent complete: 96.3%; Average loss: 3.0154
# Iteration: 38530; Percent complete: 96.3%; Average loss: 3.9919
# Iteration: 38540; Percent complete: 96.4%; Average loss: 4.5346
# Iteration: 38550; Percent complete: 96.4%; Average loss: 3.5289
# Iteration: 38560; Percent complete: 96.4%; Average loss: 3.3534
# Iteration: 38570; Percent complete: 96.4%; Average loss: 3.6595
# Iteration: 38580; Percent complete: 96.5%; Average loss: 4.2029
# Iteration: 38590; Percent complete: 96.5%; Average loss: 3.8374
# Iteration: 38600; Percent complete: 96.5%; Average loss: 3.5065
# Iteration: 38610; Percent complete: 96.5%; Average loss: 3.2878
# Iteration: 38620; Percent complete: 96.5%; Average loss: 3.9936
# Iteration: 38630; Percent complete: 96.6%; Average loss: 3.2798
# Iteration: 38640; Percent complete: 96.6%; Average loss: 3.3761
# Iteration: 38650; Percent complete: 96.6%; Average loss: 3.6452
# Iteration: 38660; Percent complete: 96.7%; Average loss: 3.5137
# Iteration: 38670; Percent complete: 96.7%; Average loss: 2.5015
# Iteration: 38680; Percent complete: 96.7%; Average loss: 3.4390
# Iteration: 38690; Percent complete: 96.7%; Average loss: 3.6591
# Iteration: 38700; Percent complete: 96.8%; Average loss: 4.4078
# Iteration: 38710; Percent complete: 96.8%; Average loss: 3.5975
# Iteration: 38720; Percent complete: 96.8%; Average loss: 3.5278
# Iteration: 38730; Percent complete: 96.8%; Average loss: 4.0195
# Iteration: 38740; Percent complete: 96.9%; Average loss: 5.0308
# Iteration: 38750; Percent complete: 96.9%; Average loss: 3.0936
# Iteration: 38760; Percent complete: 96.9%; Average loss: 3.5170
# Iteration: 38770; Percent complete: 96.9%; Average loss: 3.6264
# Iteration: 38780; Percent complete: 97.0%; Average loss: 3.5145
# Iteration: 38790; Percent complete: 97.0%; Average loss: 3.7954
# Iteration: 38800; Percent complete: 97.0%; Average loss: 3.3194
# Iteration: 38810; Percent complete: 97.0%; Average loss: 3.3398
# Iteration: 38820; Percent complete: 97.0%; Average loss: 4.0670
# Iteration: 38830; Percent complete: 97.1%; Average loss: 3.7235
# Iteration: 38840; Percent complete: 97.1%; Average loss: 3.1586
# Iteration: 38850; Percent complete: 97.1%; Average loss: 3.9786
# Iteration: 38860; Percent complete: 97.2%; Average loss: 3.7700
# Iteration: 38870; Percent complete: 97.2%; Average loss: 3.5494
# Iteration: 38880; Percent complete: 97.2%; Average loss: 3.4860
# Iteration: 38890; Percent complete: 97.2%; Average loss: 3.4517
# Iteration: 38900; Percent complete: 97.2%; Average loss: 3.5645
# Iteration: 38910; Percent complete: 97.3%; Average loss: 3.5330
# Iteration: 38920; Percent complete: 97.3%; Average loss: 3.1218
# Iteration: 38930; Percent complete: 97.3%; Average loss: 3.1795
# Iteration: 38940; Percent complete: 97.4%; Average loss: 3.3179
# Iteration: 38950; Percent complete: 97.4%; Average loss: 3.2283
# Iteration: 38960; Percent complete: 97.4%; Average loss: 3.5624
# Iteration: 38970; Percent complete: 97.4%; Average loss: 3.6255
# Iteration: 38980; Percent complete: 97.5%; Average loss: 4.6636
# Iteration: 38990; Percent complete: 97.5%; Average loss: 2.6813
# Iteration: 39000; Percent complete: 97.5%; Average loss: 3.0508
# Iteration: 39010; Percent complete: 97.5%; Average loss: 4.2611
# Iteration: 39020; Percent complete: 97.5%; Average loss: 3.9641
# Iteration: 39030; Percent complete: 97.6%; Average loss: 3.4693
# Iteration: 39040; Percent complete: 97.6%; Average loss: 3.5675
# Iteration: 39050; Percent complete: 97.6%; Average loss: 3.5656
# Iteration: 39060; Percent complete: 97.7%; Average loss: 5.1837
# Iteration: 39070; Percent complete: 97.7%; Average loss: 2.9751
# Iteration: 39080; Percent complete: 97.7%; Average loss: 4.0855
# Iteration: 39090; Percent complete: 97.7%; Average loss: 4.0028
# Iteration: 39100; Percent complete: 97.8%; Average loss: 4.1583
# Iteration: 39110; Percent complete: 97.8%; Average loss: 3.7462
# Iteration: 39120; Percent complete: 97.8%; Average loss: 3.6512
# Iteration: 39130; Percent complete: 97.8%; Average loss: 3.2182
# Iteration: 39140; Percent complete: 97.9%; Average loss: 3.6222
# Iteration: 39150; Percent complete: 97.9%; Average loss: 2.9095
# Iteration: 39160; Percent complete: 97.9%; Average loss: 4.1820
# Iteration: 39170; Percent complete: 97.9%; Average loss: 3.5783
# Iteration: 39180; Percent complete: 98.0%; Average loss: 3.2673
# Iteration: 39190; Percent complete: 98.0%; Average loss: 4.4440
# Iteration: 39200; Percent complete: 98.0%; Average loss: 3.5552
# Iteration: 39210; Percent complete: 98.0%; Average loss: 3.8812
# Iteration: 39220; Percent complete: 98.0%; Average loss: 3.5373
# Iteration: 39230; Percent complete: 98.1%; Average loss: 4.0337
# Iteration: 39240; Percent complete: 98.1%; Average loss: 4.0823
# Iteration: 39250; Percent complete: 98.1%; Average loss: 4.2666
# Iteration: 39260; Percent complete: 98.2%; Average loss: 4.6640
# Iteration: 39270; Percent complete: 98.2%; Average loss: 3.4959
# Iteration: 39280; Percent complete: 98.2%; Average loss: 3.4051
# Iteration: 39290; Percent complete: 98.2%; Average loss: 3.9527
# Iteration: 39300; Percent complete: 98.2%; Average loss: 3.8937
# Iteration: 39310; Percent complete: 98.3%; Average loss: 3.0774
# Iteration: 39320; Percent complete: 98.3%; Average loss: 3.3872
# Iteration: 39330; Percent complete: 98.3%; Average loss: 3.2222
# Iteration: 39340; Percent complete: 98.4%; Average loss: 3.3091
# Iteration: 39350; Percent complete: 98.4%; Average loss: 3.6876
# Iteration: 39360; Percent complete: 98.4%; Average loss: 4.1621
# Iteration: 39370; Percent complete: 98.4%; Average loss: 3.7310
# Iteration: 39380; Percent complete: 98.5%; Average loss: 3.3217
# Iteration: 39390; Percent complete: 98.5%; Average loss: 2.7205
# Iteration: 39400; Percent complete: 98.5%; Average loss: 3.7854
# Iteration: 39410; Percent complete: 98.5%; Average loss: 3.0468
# Iteration: 39420; Percent complete: 98.6%; Average loss: 2.3821
# Iteration: 39430; Percent complete: 98.6%; Average loss: 3.6763
# Iteration: 39440; Percent complete: 98.6%; Average loss: 3.8356
# Iteration: 39450; Percent complete: 98.6%; Average loss: 3.3989
# Iteration: 39460; Percent complete: 98.7%; Average loss: 3.0027
# Iteration: 39470; Percent complete: 98.7%; Average loss: 3.4701
# Iteration: 39480; Percent complete: 98.7%; Average loss: 4.1118
# Iteration: 39490; Percent complete: 98.7%; Average loss: 3.2391
# Iteration: 39500; Percent complete: 98.8%; Average loss: 3.2703
# Iteration: 39510; Percent complete: 98.8%; Average loss: 3.8897
# Iteration: 39520; Percent complete: 98.8%; Average loss: 3.0943
# Iteration: 39530; Percent complete: 98.8%; Average loss: 3.3307
# Iteration: 39540; Percent complete: 98.9%; Average loss: 2.9403
# Iteration: 39550; Percent complete: 98.9%; Average loss: 3.2139
# Iteration: 39560; Percent complete: 98.9%; Average loss: 2.5887
# Iteration: 39570; Percent complete: 98.9%; Average loss: 3.0568
# Iteration: 39580; Percent complete: 99.0%; Average loss: 2.9271
# Iteration: 39590; Percent complete: 99.0%; Average loss: 4.0333
# Iteration: 39600; Percent complete: 99.0%; Average loss: 3.2918
# Iteration: 39610; Percent complete: 99.0%; Average loss: 3.7509
# Iteration: 39620; Percent complete: 99.1%; Average loss: 3.0425
# Iteration: 39630; Percent complete: 99.1%; Average loss: 3.3631
# Iteration: 39640; Percent complete: 99.1%; Average loss: 3.2772
# Iteration: 39650; Percent complete: 99.1%; Average loss: 3.7710
# Iteration: 39660; Percent complete: 99.2%; Average loss: 3.8352
# Iteration: 39670; Percent complete: 99.2%; Average loss: 3.2145
# Iteration: 39680; Percent complete: 99.2%; Average loss: 3.2830
# Iteration: 39690; Percent complete: 99.2%; Average loss: 3.4211
# Iteration: 39700; Percent complete: 99.2%; Average loss: 2.5083
# Iteration: 39710; Percent complete: 99.3%; Average loss: 3.5801
# Iteration: 39720; Percent complete: 99.3%; Average loss: 4.0130
# Iteration: 39730; Percent complete: 99.3%; Average loss: 3.3570
# Iteration: 39740; Percent complete: 99.4%; Average loss: 3.8453
# Iteration: 39750; Percent complete: 99.4%; Average loss: 3.3206
# Iteration: 39760; Percent complete: 99.4%; Average loss: 3.5384
# Iteration: 39770; Percent complete: 99.4%; Average loss: 3.0523
# Iteration: 39780; Percent complete: 99.5%; Average loss: 2.7398
# Iteration: 39790; Percent complete: 99.5%; Average loss: 3.5598
# Iteration: 39800; Percent complete: 99.5%; Average loss: 3.2494
# Iteration: 39810; Percent complete: 99.5%; Average loss: 2.7653
# Iteration: 39820; Percent complete: 99.6%; Average loss: 3.6885
# Iteration: 39830; Percent complete: 99.6%; Average loss: 4.1081
# Iteration: 39840; Percent complete: 99.6%; Average loss: 4.0452
# Iteration: 39850; Percent complete: 99.6%; Average loss: 5.0211
# Iteration: 39860; Percent complete: 99.7%; Average loss: 3.8447
# Iteration: 39870; Percent complete: 99.7%; Average loss: 3.7011
# Iteration: 39880; Percent complete: 99.7%; Average loss: 3.8077
# Iteration: 39890; Percent complete: 99.7%; Average loss: 2.9740
# Iteration: 39900; Percent complete: 99.8%; Average loss: 3.8738
# Iteration: 39910; Percent complete: 99.8%; Average loss: 3.7442
# Iteration: 39920; Percent complete: 99.8%; Average loss: 3.5065
# Iteration: 39930; Percent complete: 99.8%; Average loss: 3.8769
# Iteration: 39940; Percent complete: 99.9%; Average loss: 3.6176
# Iteration: 39950; Percent complete: 99.9%; Average loss: 3.6918
# Iteration: 39960; Percent complete: 99.9%; Average loss: 3.1589
# Iteration: 39970; Percent complete: 99.9%; Average loss: 3.3018
# Iteration: 39980; Percent complete: 100.0%; Average loss: 4.2273
# Iteration: 39990; Percent complete: 100.0%; Average loss: 2.8542
# Iteration: 40000; Percent complete: 100.0%; Average loss: 2.8946

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores


def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to("cpu")
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            print(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            print(output_words)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

searcher = GreedySearchDecoder(encoder, decoder)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# hello
# ['what', 'are', 'you', 'doing', 'here', '?', 'EOS', '?', 'EOS', '?']
# Bot: what are you doing here ? ? ?
# what s up ?
# ['nothing', '.', 'EOS', '.', 'EOS', '.', 'EOS', '.', 'EOS', '.']
# Bot: nothing . . . . .
# what s your name ?
# ['nothing', '.', 'EOS', '.', 'EOS', '.', 'EOS', '.', 'EOS', '.']
# Bot: nothing . . . . .
# where am i ?
# ['i', 'don', 't', 'know', '.', 'EOS', '.', 'EOS', '.', 'EOS']
# Bot: i don t know . . .
# where are you from ?
# ['i', 'm', 'sorry', '.', 'EOS', '.', 'EOS', '.', 'EOS', '.']
# Bot: i m sorry . . . .
# who are you ?
# ['i', 'm', 'sorry', '.', 'EOS', '.', 'EOS', '.', 'EOS', '.']
# Bot: i m sorry . . . .
# hello
# ['what', 'are', 'you', 'doing', 'here', '?', 'EOS', '?', 'EOS', '?']
# Bot: what are you doing here ? ? ?
# how do you do
# ['what', 'do', 'you', 'do', 'with', 'you', '?', 'EOS', '?', 'EOS']
# Bot: what do you do with you ? ?
# hi
# ['hi', '.', 'EOS', '.', 'EOS', '.', 'EOS', '.', 'EOS', '.']
# Bot: hi . . . . .
# are you a robot ?
# Error: Encountered unknown word.
# where am i ?
# ['i', 'don', 't', 'know', '.', 'EOS', '.', 'EOS', '.', 'EOS']
# Bot: i don t know . . .
# hi
# ['hi', '.', 'EOS', '.', 'EOS', '.', 'EOS', '.', 'EOS', '.']
# Bot: hi . . . . .
# hello
# ['what', 'are', 'you', 'doing', 'here', '?', 'EOS', '?', 'EOS', '?']
# Bot: what are you doing here ? ? ?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_5_1.ipynb Cell 4 in <cell line: 72>()
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_5_1.ipynb#W3sZmlsZQ%3D%3D?line=68'>69</a>             print("Error: Encountered unknown word.")
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_5_1.ipynb#W3sZmlsZQ%3D%3D?line=70'>71</a> searcher = GreedySearchDecoder(encoder, decoder)
# ---> <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_5_1.ipynb#W3sZmlsZQ%3D%3D?line=71'>72</a> evaluateInput(encoder, decoder, searcher, voc)
#
# /Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_5_1.ipynb Cell 4 in evaluateInput(encoder, decoder, searcher, voc)
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_5_1.ipynb#W3sZmlsZQ%3D%3D?line=51'>52</a> while(1):
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_5_1.ipynb#W3sZmlsZQ%3D%3D?line=52'>53</a>     try:
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_5_1.ipynb#W3sZmlsZQ%3D%3D?line=53'>54</a>         # Get input sentence
# ---> <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_5_1.ipynb#W3sZmlsZQ%3D%3D?line=54'>55</a>         input_sentence = input('> ')
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_5_1.ipynb#W3sZmlsZQ%3D%3D?line=55'>56</a>         # Check if it is quit case
#      <a href='vscode-notebook-cell:/Users/kinbunhua/cds522/groupproject/chatbot_tutorial1_5_1.ipynb#W3sZmlsZQ%3D%3D?line=56'>57</a>         if input_sentence == 'q' or input_sentence == 'quit': break
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ipykernel/kernelbase.py:1161, in Kernel.raw_input(self, prompt)
#    1157 if not self._allow_stdin:
#    1158     raise StdinNotImplementedError(
#    1159         "raw_input was called, but this frontend does not support input requests."
#    1160     )
# -> 1161 return self._input_request(
#    1162     str(prompt),
#    1163     self._parent_ident["shell"],
#    1164     self.get_parent("shell"),
#    1165     password=False,
#    1166 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ipykernel/kernelbase.py:1205, in Kernel._input_request(self, prompt, ident, parent, password)
#    1202             break
#    1203 except KeyboardInterrupt:
#    1204     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1205     raise KeyboardInterrupt("Interrupted by user") from None
#    1206 except Exception:
#    1207     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
import torch.nn as nn
import re
import os
import unicodedata
import numpy as np
from model import EncoderRNN, Attn, LuongAttnDecoderRNN
from Voc import *

device = torch.device("cpu")
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder, decoder_n_layers):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self._device = device
        self._SOS_token = SOS_token
        self._decoder_n_layers = decoder_n_layers

    __constants__ = ['_device', '_SOS_token', '_decoder_n_layers']

    def forward(self, input_seq : torch.Tensor, input_length : torch.Tensor, max_length : int):
        # Forward input through encoder model
        #print(input_seq.shape)
        #print(len(input_seq.shape))
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        #print(encoder_outputs)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:self._decoder_n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=self._device, dtype=torch.long) * self._SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=self._device, dtype=torch.long)
        all_scores = torch.zeros([0], device=self._device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores
def evaluate(searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to(device)
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    #print(tokens)
    #print(scores)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    #print(decoded_words)
    return decoded_words


# Evaluate inputs from user input (stdin)
def evaluateInput(searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# Normalize input sentence and call evaluate()
def evaluateExample(sentence, searcher, voc):
    print("> " + sentence)
    # Normalize sentence
    input_sentence = normalizeString(sentence)
    #print(input_sentence)
    # Evaluate sentence
    output_words = evaluate(searcher, voc, input_sentence)
    output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
    print('Bot:', ' '.join(output_words))

save_dir = os.path.join("data", "save")
corpus_name = "movie-corpus"

# Configure models
model_name = 'cb_model'
attn_model = 'dot'
#attn_model = 'general'
#attn_model = 'concat'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# If you're loading your own model
# Set checkpoint to load from

# If you're loading the hosted model
#loadFilename = 'data/4000_checkpoint.tar'




### Compile the whole greedy search model to TorchScript model
# Create artificial inputs
test_seq = torch.LongTensor(MAX_LENGTH, 1).random_(0, voc.num_words).to(device)
test_seq_length = torch.LongTensor([test_seq.size()[0]]).to(device)
# Trace the model
traced_encoder = torch.jit.trace(encoder, (test_seq, test_seq_length))

### Convert decoder model
# Create and generate artificial inputs
test_encoder_outputs, test_encoder_hidden = traced_encoder(test_seq, test_seq_length)
test_decoder_hidden = test_encoder_hidden[:decoder.n_layers]
test_decoder_input = torch.LongTensor(1, 1).random_(0, voc.num_words)
# Trace the model
traced_decoder = torch.jit.trace(decoder, (test_decoder_input, test_decoder_hidden, test_encoder_outputs))

### Initialize searcher module by wrapping ``torch.jit.script`` call
scripted_searcher = torch.jit.script(GreedySearchDecoder(traced_encoder, traced_decoder, decoder.n_layers))


# Use appropriate device
scripted_searcher.to(device)
# Set dropout layers to eval mode
scripted_searcher.eval()

# Evaluate examples
sentences = ["hello", "what's up?", "who are you?", "where am I?", "where are you from?"]
#sentences = ["hello"]
for s in sentences:
    evaluateExample(s, scripted_searcher, voc)
# Out:
# /var/folders/rk/rb0btt_x2mxgsj16ky_t07tr0000gn/T/ipykernel_1880/785277366.py:122: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if input_seq[t, i] > 0:
# /var/folders/rk/rb0btt_x2mxgsj16ky_t07tr0000gn/T/ipykernel_1880/785277366.py:123: TracerWarning: Converting a tensor to a Python float might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   cell_id = math.floor(input_seq[t, i] / 88) * self.num_layers
# /var/folders/rk/rb0btt_x2mxgsj16ky_t07tr0000gn/T/ipykernel_1880/785277366.py:151: TracerWarning: Converting a tensor to a NumPy array might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   output = torch.tensor([item.detach().numpy() for item in outs])
# /var/folders/rk/rb0btt_x2mxgsj16ky_t07tr0000gn/T/ipykernel_1880/785277366.py:151: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   output = torch.tensor([item.detach().numpy() for item in outs])
# /var/folders/rk/rb0btt_x2mxgsj16ky_t07tr0000gn/T/ipykernel_1880/785277366.py:160: TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
#   h0[layer] = torch.tensor([item.detach().numpy() for item in hidden_forward[layer]])
# /var/folders/rk/rb0btt_x2mxgsj16ky_t07tr0000gn/T/ipykernel_1880/785277366.py:160: TracerWarning: Converting a tensor to a NumPy array might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   h0[layer] = torch.tensor([item.detach().numpy() for item in hidden_forward[layer]])
# /var/folders/rk/rb0btt_x2mxgsj16ky_t07tr0000gn/T/ipykernel_1880/785277366.py:160: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   h0[layer] = torch.tensor([item.detach().numpy() for item in hidden_forward[layer]])
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/jit/_trace.py:1001: TracerWarning: Output nr 1. of the traced function does not match the corresponding output of the Python function. Detailed error:
# Tensor-likes are not close!
#
# Mismatched elements: 1738 / 7836 (22.2%)
# Greatest absolute difference: 0.18297117948532104 at index (0, 28) (up to 1e-05 allowed)
# Greatest relative difference: 10.388463264285868 at index (0, 1012) (up to 1e-05 allowed)
#   _check_trace(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/jit/_trace.py:1001: TracerWarning: Output nr 2. of the traced function does not match the corresponding output of the Python function. Detailed error:
# Tensor-likes are not close!
#
# Mismatched elements: 999 / 1000 (99.9%)
# Greatest absolute difference: 1.6459234356880188 at index (0, 0, 170) (up to 1e-05 allowed)
# Greatest relative difference: 1128.9989401968205 at index (1, 0, 411) (up to 1e-05 allowed)
#   _check_trace(
# > hello
# Bot: are you now ? ? ? ?
# > what's up?
# Bot: are you now ? ? ? ?
# > who are you?
# Bot: . . ? ? ?
# > where am I?
# Bot: have you ever heard ? ? ?
# > where are you from?
# Bot: . . . . .
